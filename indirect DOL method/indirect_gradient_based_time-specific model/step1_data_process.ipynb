# %%
import csv
import random

input_file = 'Y_train.csv'
with open(input_file, 'r') as f:
    reader = csv.reader(f)
    data = list(reader)

title = data[0]

rows = data[1:]

for i in range(24):
    extracted_rows = [rows[j] for j in range(len(rows)) if (j - i) % 24 == 0]
    
    output_file = f'./generated_data/output_{i+1}.csv'
    with open(output_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(title)
        writer.writerows(extracted_rows)

    with open(output_file, 'r') as f:
        reader = csv.reader(f)
        data = list(reader)
    
    title_row = data[0]
    rows_data = data[1:]
    
    for row in rows_data:
        original_value = float(row[0])
        for j in range(1, 2):
            random_factor = random.uniform(-0.15, 0.15)
            new_value = original_value * (1 + random_factor)
            row.append(f"{new_value:.2f}")
    
    with open(output_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(title_row + ['Change1'])
        writer.writerows(rows_data)

# %%
import csv
import numpy as np
import os

mpc_bus = [
    [1, 51], [2, 20], [3, 39], [4, 39], [5, 0], [6, 52], [7, 19], [8, 28], [9, 0], [10, 0],
    [11, 70], [12, 47], [13, 34], [14, 14], [15, 90], [16, 25], [17, 11], [18, 60], [19, 45], [20, 18],
    [21, 14], [22, 10], [23, 7], [24, 13], [25, 0], [26, 0], [27, 71], [28, 17], [29, 24], [30, 0],
    [31, 43], [32, 59], [33, 23], [34, 59], [35, 33], [36, 31], [37, 0], [38, 0], [39, 27], [40, 66],
    [41, 37], [42, 96], [43, 18], [44, 16], [45, 53], [46, 28], [47, 34], [48, 20], [49, 87], [50, 17],
    [51, 17], [52, 18], [53, 23], [54, 113], [55, 63], [56, 84], [57, 12], [58, 12], [59, 277], [60, 78],
    [61, 0], [62, 77], [63, 0], [64, 0], [65, 0], [66, 39], [67, 28], [68, 0], [69, 0], [70, 66],
    [71, 0], [72, 12], [73, 6], [74, 68], [75, 47], [76, 68], [77, 61], [78, 71], [79, 39], [80, 130],
    [81, 0], [82, 54], [83, 20], [84, 11], [85, 24], [86, 21], [87, 0], [88, 48], [89, 0], [90, 163],
    [91, 10], [92, 65], [93, 12], [94, 30], [95, 42], [96, 38], [97, 15], [98, 34], [99, 42], [100, 37],
    [101, 22], [102, 5], [103, 23], [104, 38], [105, 31], [106, 43], [107, 50], [108, 2], [109, 8], [110, 39],
    [111, 0], [112, 68], [113, 6], [114, 8], [115, 22], [116, 184], [117, 20], [118, 33]
]

ratio_bus = np.zeros(118)
for i in range(118):
    ratio_bus[i] = mpc_bus[i][1] / sum(mpc_bus[j][1] for j in range(118))

parent_folder = './hour'
if not os.path.exists(parent_folder):
    os.makedirs(parent_folder)

for file_num in range(1, 25):
    input_file = f'./generated_data/output_{file_num}.csv'
    with open(input_file, 'r') as f:
        reader = csv.reader(f)
        data = list(reader)

    title = data[0]
    rows = data[1:]

    folder_path = f'{parent_folder}/{file_num}'
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    allocated_data = []
    for row in rows:
        total_value = float(row[0]) 
        allocated_row = [total_value * ratio_bus[i] for i in range(118)]
        allocated_data.append(allocated_row)

    output_file = f'{folder_path}/allocated_output_perfect.csv'
    with open(output_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['Node_' + str(i+1) for i in range(118)])  
        writer.writerows(allocated_data)

    for col in range(1, 2):
        allocated_data = []
        for row in rows:
            total_value = float(row[col])  
            allocated_row = [total_value * ratio_bus[i] for i in range(118)]
            allocated_data.append(allocated_row)

        output_file = f'{folder_path}/allocated_output_change{col}.csv'
        with open(output_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['Node_' + str(i+1) for i in range(118)])  
            writer.writerows(allocated_data)

# %%
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB
import os
import csv
from concurrent.futures import ThreadPoolExecutor, as_completed
def calculate_optimization_cost_two_stage(P_l_predict, Y_real, topo, unit, reserve_up=150, reserve_down=150, c=9000, c_s=1750):
   
    P_l_predict = np.array(P_l_predict).T    
    Y_real = np.array(Y_real).T
    
    nodes = topo.shape[0]
    
    model_DA = gp.Model()
    
    
    P_c = model_DA.addVars(nodes,  lb=0, name='P_c')       
    R_U = model_DA.addVars(nodes,  lb=0, name='R_U')       
    R_D = model_DA.addVars(nodes,  lb=0, name='R_D')       
    delta_DA = model_DA.addVars(nodes,  lb=-180, ub=180, name='delta_DA') 
    
    
    obj_DA = gp.quicksum(
        R_U[i]*unit.iloc[i,5] + 
        R_D[i]*unit.iloc[i,6] + 
        P_c[i]*unit.iloc[i,2] 
        for i in range(nodes) 
    )
    model_DA.setObjective(obj_DA, GRB.MINIMIZE)
    
    
    model_DA.addConstr(gp.quicksum(R_U[i] for i in range(nodes)) == reserve_up)
    model_DA.addConstr(gp.quicksum(R_D[i] for i in range(nodes)) == reserve_down)
        
    for i in range(nodes):
        model_DA.addConstr(R_U[i] <= unit.iloc[i,3])  
        model_DA.addConstr(R_D[i] <= unit.iloc[i,4])  
        
    for t in range(nodes):
        model_DA.addConstr(
            P_c[t] - P_l_predict[t] - 
            gp.quicksum(topo.iloc[t,j]*(delta_DA[t]-delta_DA[j]) for j in range(nodes)) == 0
        )
    model_DA.addConstr(delta_DA[0] == 0)  
        
    for i in range(nodes):
        model_DA.addConstr(P_c[i] <= unit.iloc[i,1] - R_U[i])  
        model_DA.addConstr(P_c[i] >= R_D[i])                   
        
    for i in range(nodes):
        for j in range(nodes):
            if i != j and topo.iloc[i,j] < -0.01:
                model_DA.addConstr(topo.iloc[i,j] * (delta_DA[i] - delta_DA[j]) <= 175)
                model_DA.addConstr(topo.iloc[i,j] * (delta_DA[i] - delta_DA[j]) >= -175)
    
    model_DA.optimize()
    
    model_RT = gp.Model()
    
    
    r_U = model_RT.addVars(nodes,  lb=0, name='r_U')       
    r_D = model_RT.addVars(nodes,  lb=0, name='r_D')       
    P_lsh = model_RT.addVars(nodes,  lb=0, name='P_lsh')   
    delta_RT = model_RT.addVars(nodes,  lb=-180, ub=180, name='delta_RT') 
    s = model_RT.addVars(nodes,  lb=0, name='s')           
    
    
    obj_RT = gp.quicksum(
        (r_U[i]-r_D[i])*unit.iloc[i,2] 
        for i in range(nodes) 
    )
    obj_RT += gp.quicksum(P_lsh[i]*c for i in range(nodes) )
    obj_RT += gp.quicksum(s[i]*c_s for i in range(nodes) )
    model_RT.setObjective(obj_RT, GRB.MINIMIZE)
    
    
        
    for t in range(nodes):
        model_RT.addConstr(
            r_U[t] - r_D[t] - s[t] - Y_real[t] + P_l_predict[t] + P_lsh[t] - 
            gp.quicksum(
                topo.iloc[t,j]*(delta_RT[t]-delta_RT[j]) - 
                topo.iloc[t,j]*(delta_DA[t].X-delta_DA[j].X) 
                for j in range(nodes)
            ) == 0
        )
        
    for i in range(nodes):
        model_RT.addConstr(r_U[i] <= R_U[i].X)  
        model_RT.addConstr(r_D[i] <= R_D[i].X)  
    model_RT.addConstr(delta_RT[0] == 0)  
        
    for i in range(nodes):
        for j in range(nodes):
            if i != j and topo.iloc[i,j] < -0.01:
                model_RT.addConstr(topo.iloc[i,j] * (delta_RT[i] - delta_RT[j]) <= 175)
                model_RT.addConstr(topo.iloc[i,j] * (delta_RT[i] - delta_RT[j]) >= -175)
    
    model_RT.optimize()
    
    
    total_cost = model_DA.ObjVal + model_RT.ObjVal
    
    
    
    model_DA.dispose()
    model_RT.dispose()
    
    return total_cost
# System parameters (topology data and generator unit data)
topo = pd.read_excel('118nodes_system.xlsx', sheet_name='topology', index_col=None, header=None) 
unit = pd.read_excel('118nodes_system.xlsx', sheet_name='unit')

hour_folder = './hour'
for hour in range(1, 25):
    hour_dir = os.path.join(hour_folder, str(hour))
    if not os.path.exists(hour_dir):
        continue
    
    perfect_file = os.path.join(hour_dir, 'allocated_output_perfect.csv')
    if not os.path.exists(perfect_file):
        continue
    
    with open(perfect_file, 'r') as f_perfect:
        reader_perfect = csv.reader(f_perfect)
        next(reader_perfect)  
        perfect_data = [list(map(float, row)) for row in reader_perfect]
    
    perfect_costs = []
    with ThreadPoolExecutor() as executor:
        
        perfect_costs = list(executor.map(lambda x: calculate_optimization_cost_two_stage(x, x, topo, unit), perfect_data))
    
    
    perfect_cost_file = os.path.join(hour_dir, 'perfect_costs.csv')
    with open(perfect_cost_file, 'w', newline='') as f_perfect_cost:
        writer = csv.writer(f_perfect_cost)
        writer.writerow(['Perfect_Cost'])
        writer.writerows([[cost] for cost in perfect_costs])
    
    
    cost_differences = []  
    for file_prefix in ['allocated_output_change1']:
        input_file = os.path.join(hour_dir, f'{file_prefix}.csv')
        if not os.path.exists(input_file):
            continue
        
       
        with open(input_file, 'r') as f_in:
            reader = csv.reader(f_in)
            next(reader)  
            data = [list(map(float, row)) for row in reader]
        
        
        if len(data) != len(perfect_data):
            print(f"error:{input_file} ")
            continue
        
        
        total_costs = []
        with ThreadPoolExecutor() as executor:
            
            total_costs = list(executor.map(lambda x: calculate_optimization_cost_two_stage(x[0], x[1], topo, unit), zip(data, perfect_data)))
        
        
        cost_diff = [total_costs[i] - perfect_costs[i] for i in range(len(total_costs))]
        cost_differences.append(cost_diff)
    
    
    if cost_differences:
        output_file = os.path.join(hour_dir, 'cost_differences.csv')
        with open(output_file, 'w', newline='') as f_out:
            writer = csv.writer(f_out)
            writer.writerow(['Change1'])
            writer.writerows(zip(*cost_differences))
# Out:
# Set parameter Username
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-30
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-30
# Academic license - for non-commercial use only - expires 2025-03-30
# Academic license - for non-commercial use only - expires 2025-03-30
# Academic license - for non-commercial use only - expires 2025-03-30
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#
#
#
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
#
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
#
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0xb82057a1
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x9e434d54
#
# Model fingerprint: 0xf850100f
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
# Coefficient statistics:
#
# Model fingerprint: 0xaa9ed968
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Coefficient statistics:
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Coefficient statistics:
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x042a0504
# Model fingerprint: 0x36e3bb9a
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x22bff24a
# Model fingerprint: 0x8a075ce6
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0xe85f5ca0
# Coefficient statistics:
# Model fingerprint: 0x7592dae7
# Model fingerprint: 0x5f9c33b5
# Model fingerprint: 0xb204bf52
# Coefficient statistics:
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x5c7efbbf
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0xd4095f26
# Model fingerprint: 0x1c70feeb
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0xb35cac66
# Coefficient statistics:
# Coefficient statistics:
# Model fingerprint: 0x7a6359c7
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0xb58ccbcb
#   Objective range  [4e+01, 2e+02]
# Model fingerprint: 0x93e212d1
# Coefficient statistics:
# Model fingerprint: 0x9e6237c8
# Coefficient statistics:
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
# Coefficient statistics:
#   Objective range  [4e+01, 2e+02]
# Coefficient statistics:
#   Objective range  [4e+01, 2e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
# Coefficient statistics:
#   Bounds range     [2e+02, 2e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [9e-01, 8e+02]
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   RHS range        [5e-01, 8e+02]
#   RHS range        [5e-01, 8e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [6e-01, 8e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [1e+00, 8e+02]
#   Objective range  [4e+01, 2e+02]
#   RHS range        [9e-01, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 1059 rows and 293 columns
#   RHS range        [6e-01, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [7e-01, 8e+02]
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
#   RHS range        [7e-01, 8e+02]
#   RHS range        [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [1e+00, 8e+02]
#   RHS range        [9e-01, 8e+02]
# Presolve removed 1059 rows and 293 columns
#   RHS range        [7e-01, 8e+02]
#   RHS range        [9e-01, 8e+02]
# Presolve time: 0.03s
#   RHS range        [6e-01, 8e+02]
#   RHS range        [7e-01, 8e+02]
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
#   RHS range        [1e+00, 8e+02]
# Presolve removed 1059 rows and 293 columns
# Presolve time: 0.03s
# Presolve time: 0.03s
#   RHS range        [9e-01, 8e+02]
#   RHS range        [8e-01, 8e+02]
# Presolve removed 1059 rows and 293 columns
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
# Presolve time: 0.03s
# Presolve time: 0.03s
# Presolve time: 0.03s
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
# Presolve time: 0.03s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
#
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve time: 0.03s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve time: 0.03s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve time: 0.03s
# Presolve time: 0.03s
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
#
# Presolve time: 0.03s
# Presolve removed 1059 rows and 293 columns
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#
# Presolve time: 0.03s
# Presolve time: 0.03s
# Presolve time: 0.03s
# Presolve time: 0.03s
#
#
# Presolve time: 0.03s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve time: 0.03s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#
# Presolve time: 0.03s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve time: 0.03s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#
#
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.6001720e+08   2.655840e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
#
#        0   -7.6329254e+08   2.667303e+06   0.000000e+00      0s
#
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#        0   -7.6352421e+08   2.668114e+06   0.000000e+00      0s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#
#        0   -7.6251942e+08   2.664598e+06   0.000000e+00      0s
#        0   -7.5887711e+08   2.651850e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.5950333e+08   2.654042e+06   0.000000e+00      0s
#
#        0   -7.6235058e+08   2.664007e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.5881894e+08   2.651646e+06   0.000000e+00      0s
#
#        0   -7.5743188e+08   2.646792e+06   0.000000e+00      0s
#        0   -7.6139994e+08   2.660680e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      144    1.0703184e+05   0.000000e+00   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.6153955e+08   2.661168e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.5975827e+08   2.654934e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.5861153e+08   2.650920e+06   0.000000e+00      0s
#      133    6.7625000e+04   0.000000e+00   0.000000e+00      0s
#      137    1.2154955e+05   0.000000e+00   0.000000e+00      0s
#      134    7.6431934e+04   0.000000e+00   0.000000e+00      0s
#        0   -7.6136670e+08   2.660563e+06   0.000000e+00      0s
#      145    1.1357187e+05   0.000000e+00   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.6132848e+08   2.660429e+06   0.000000e+00      0s
#        0   -7.6209796e+08   2.663123e+06   0.000000e+00      0s
#      132    6.5011250e+04   0.000000e+00   0.000000e+00      0s
#
#        0   -7.6081793e+08   2.658643e+06   0.000000e+00      0s
#        0   -7.5979118e+08   2.655049e+06   0.000000e+00      0s
#        0   -7.5845963e+08   2.650389e+06   0.000000e+00      0s
#      133    7.8443436e+04   0.000000e+00   0.000000e+00      0s
#      136    1.2230672e+05   0.000000e+00   0.000000e+00      0s
#
#        0   -7.5955020e+08   2.654206e+06   0.000000e+00      0s
#
#
#
#      142    1.4057429e+05   0.000000e+00   0.000000e+00      0s
#      137    8.9836676e+04   0.000000e+00   0.000000e+00      0s
#      145    1.1032724e+05   0.000000e+00   0.000000e+00      0s
#
#      136    1.2503172e+05   0.000000e+00   0.000000e+00      0s
# Solved in 144 iterations and 0.05 seconds (0.00 work units)
#      137    9.0248126e+04   0.000000e+00   0.000000e+00      0s
#      139    8.8147166e+04   0.000000e+00   0.000000e+00      0s
#
#
#      137    9.0721295e+04   0.000000e+00   0.000000e+00      0s
#      145    1.0990844e+05   0.000000e+00   0.000000e+00      0s
#      137    1.2702744e+05   0.000000e+00   0.000000e+00      0s
#      147    9.7041178e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 133 iterations and 0.05 seconds (0.00 work units)
# Solved in 145 iterations and 0.05 seconds (0.00 work units)
# Solved in 134 iterations and 0.05 seconds (0.00 work units)
# Solved in 137 iterations and 0.05 seconds (0.00 work units)
#
#
# Solved in 132 iterations and 0.05 seconds (0.00 work units)
#
# Solved in 136 iterations and 0.05 seconds (0.00 work units)
#      133    8.1465909e+04   0.000000e+00   0.000000e+00      0s
#
#      145    1.1297540e+05   0.000000e+00   0.000000e+00      0s
# Optimal objective  1.070318390e+05
#
# Solved in 133 iterations and 0.05 seconds (0.00 work units)
#
# Optimal objective  6.762500003e+04
#
#
# Optimal objective  7.643193446e+04
# Solved in 142 iterations and 0.05 seconds (0.00 work units)
#
# Optimal objective  1.135718690e+05
# Solved in 137 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.223067188e+05
# Solved in 145 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  6.501125000e+04
#
# Solved in 137 iterations and 0.05 seconds (0.00 work units)
# Solved in 147 iterations and 0.05 seconds (0.00 work units)
# Solved in 139 iterations and 0.05 seconds (0.00 work units)
# Solved in 137 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  7.844343593e+04
# Solved in 136 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.215495513e+05
#
# Solved in 145 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  1.405742898e+05
# Solved in 137 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  8.983667561e+04
# Optimal objective  1.103272358e+05
# Optimal objective  9.024812635e+04
# Optimal objective  8.814716615e+04
# Solved in 145 iterations and 0.07 seconds (0.00 work units)
# Optimal objective  1.270274417e+05
# Optimal objective  1.250317244e+05
# Optimal objective  9.704117835e+04
# Solved in 133 iterations and 0.10 seconds (0.00 work units)
# Optimal objective  1.099084369e+05
# Optimal objective  9.072129470e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Optimal objective  1.129753980e+05
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Optimal objective  8.146590930e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# Model fingerprint: 0xc499ffbc
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# Model fingerprint: 0x7a187208
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Model fingerprint: 0x336b128f
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
# Model fingerprint: 0xcd946b1b
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Coefficient statistics:
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
# Coefficient statistics:
# Coefficient statistics:
#
#
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Model fingerprint: 0x86a473d6
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Model fingerprint: 0xa49cb5d0
# Model fingerprint: 0x2a2b0119
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Coefficient statistics:
# Model fingerprint: 0x6e1889cd
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#   Matrix range     [1e+00, 4e+02]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0x7113fe3d
#
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Model fingerprint: 0x8b54adc3
#
# Coefficient statistics:
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
# Coefficient statistics:
# Coefficient statistics:
# Model fingerprint: 0x2d28d38b
# Coefficient statistics:
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 9e+03]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#   Objective range  [4e+01, 9e+03]
# Model fingerprint: 0x1d7a7f78
#   Objective range  [4e+01, 9e+03]
#
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Model fingerprint: 0xe3fa58ee
# Coefficient statistics:
# Model fingerprint: 0xdb45111f
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#   Objective range  [4e+01, 9e+03]
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#
# Model fingerprint: 0x02beff48
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 9e+03]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Model fingerprint: 0xc6a435eb
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
# Model fingerprint: 0xa7b1984c
# Coefficient statistics:
# Model fingerprint: 0xa9298b5b
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 9e+03]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 9e+03]
#   Objective range  [4e+01, 9e+03]
# Coefficient statistics:
#   RHS range        [2e-13, 3e+02]
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 9e+03]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#   RHS range        [2e-13, 3e+02]
#   Objective range  [4e+01, 9e+03]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0x5bc911b2
#   RHS range        [7e-14, 3e+02]
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
# Coefficient statistics:
#   RHS range        [9e-14, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   RHS range        [1e-13, 3e+02]
#   Objective range  [4e+01, 9e+03]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 9e+03]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
# Coefficient statistics:
# Model fingerprint: 0x490ebb78
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 9e+03]
#   Objective range  [4e+01, 9e+03]
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
# Presolve removed 782 rows and 240 columns
# Presolve removed 782 rows and 240 columns
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [2e-13, 3e+02]
#   Objective range  [4e+01, 9e+03]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [3e-14, 2e+02]
#   RHS range        [6e-14, 3e+02]
# Presolve removed 782 rows and 240 columns
# Presolve removed 782 rows and 240 columns
#   RHS range        [3e-14, 3e+02]
# Coefficient statistics:
#   RHS range        [6e-14, 3e+02]
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 782 rows and 240 columns
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 9e+03]
#   Objective range  [4e+01, 9e+03]
# Presolve time: 0.40s
#   Objective range  [4e+01, 9e+03]
#   Matrix range     [1e+00, 4e+02]
#   RHS range        [7e-14, 3e+02]
# Presolve time: 0.03s
# Presolve time: 0.17s
#   RHS range        [2e-13, 3e+02]
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 782 rows and 240 columns
# Presolve time: 0.17s
#   RHS range        [3e-13, 3e+02]
# Presolve removed 782 rows and 240 columns
#   RHS range        [3e-14, 3e+02]
# Presolve removed 782 rows and 240 columns
#   Objective range  [4e+01, 9e+03]
# Presolve removed 782 rows and 240 columns
# Presolve time: 0.03s
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 782 rows and 240 columns
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#   Bounds range     [2e+02, 2e+02]
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Presolve time: 0.03s
#   Bounds range     [2e+02, 2e+02]
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#   RHS range        [1e-13, 3e+02]
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [3e-14, 3e+02]
# Presolve time: 0.03s
#   Objective range  [4e+01, 9e+03]
# Presolve time: 0.03s
# Presolve removed 782 rows and 240 columns
# Presolve removed 782 rows and 240 columns
# Presolve removed 782 rows and 240 columns
# Presolve removed 782 rows and 240 columns
# Presolve time: 0.03s
#
#
#
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
#   RHS range        [6e-14, 3e+02]
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
#   RHS range        [1e-14, 3e+02]
# Presolve time: 0.02s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Presolve removed 782 rows and 240 columns
#   RHS range        [9e-14, 3e+02]
# Presolve time: 0.02s
# Presolve time: 0.03s
# Presolve time: 0.03s
# Presolve time: 0.03s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 782 rows and 240 columns
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Presolve time: 0.03s
#
# Presolve removed 782 rows and 240 columns
#
#   RHS range        [1e-13, 3e+02]
#
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolve removed 782 rows and 240 columns
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Presolve removed 782 rows and 240 columns
#
#
#
#        0   -5.9075000e+03   2.842327e+03   0.000000e+00      0s
# Presolve time: 0.03s
#        0   -5.9075000e+03   2.814594e+03   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#        0   -5.9075000e+03   2.842010e+03   0.000000e+00      0s
#
#
# Presolve time: 0.03s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.9075000e+03   2.841750e+03   0.000000e+00      0s
#        0   -5.9075000e+03   2.811992e+03   0.000000e+00      0s
# Presolve removed 782 rows and 240 columns
# Presolve time: 0.03s
# Presolve time: 0.03s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.9075000e+03   2.842285e+03   0.000000e+00      0s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#        0   -5.9075000e+03   2.843307e+03   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -5.9075000e+03   2.816309e+03   0.000000e+00      0s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#        0   -5.9075000e+03   2.841881e+03   0.000000e+00      0s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
#        0   -5.9075000e+03   2.839338e+03   0.000000e+00      0s
#       97   -6.4803203e+01   0.000000e+00   0.000000e+00      0s
#       99   -6.2914337e+01   0.000000e+00   0.000000e+00      0s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#        0   -5.9075000e+03   2.839600e+03   0.000000e+00      0s
#
#        0   -5.9075000e+03   2.842181e+03   0.000000e+00      0s
#        0   -5.9075000e+03   2.816223e+03   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       97   -6.2914337e+01   0.000000e+00   0.000000e+00      0s
#      100   -6.2914337e+01   0.000000e+00   0.000000e+00      0s
#       94   -7.1925980e+01   0.000000e+00   0.000000e+00      0s
# Presolve time: 0.03s
#       97   -6.2914337e+01   0.000000e+00   0.000000e+00      0s
#        0   -5.9075000e+03   2.839478e+03   0.000000e+00      0s
#
#
#
#       94   -6.4803203e+01   0.000000e+00   0.000000e+00      0s
#        0   -5.9075000e+03   2.837464e+03   0.000000e+00      0s
#
#
#      103   -6.2914337e+01   0.000000e+00   0.000000e+00      0s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       99   -6.2914337e+01   0.000000e+00   0.000000e+00      0s
#       97   -6.4803203e+01   0.000000e+00   0.000000e+00      0s
# Solved in 97 iterations and 0.06 seconds (0.00 work units)
#
#
# Solved in 97 iterations and 0.06 seconds (0.00 work units)
#       95   -6.4803203e+01   0.000000e+00   0.000000e+00      0s
#
#
#       95   -6.4803203e+01   0.000000e+00   0.000000e+00      0s
#       95   -6.4803203e+01   0.000000e+00   0.000000e+00      0s
#        0   -5.9075000e+03   2.841864e+03   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Solved in 94 iterations and 0.43 seconds (0.00 work units)
#       98   -6.2914337e+01   0.000000e+00   0.000000e+00      0s
# Optimal objective -6.291433687e+01
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Solved in 100 iterations and 0.20 seconds (0.00 work units)
#
#        0   -5.9075000e+03   2.837750e+03   0.000000e+00      0s
# Solved in 99 iterations and 0.20 seconds (0.00 work units)
# Solved in 103 iterations and 0.06 seconds (0.00 work units)
# Solved in 97 iterations and 0.06 seconds (0.00 work units)
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       99   -6.4803203e+01   0.000000e+00   0.000000e+00      0s
#
# Optimal objective -6.291433687e+01
# Solved in 94 iterations and 0.06 seconds (0.00 work units)
#
#
#        0   -5.9075000e+03   2.822987e+03   0.000000e+00      0s
#
#
# Optimal objective -6.291433687e+01
# Optimal objective -6.291433687e+01
# Solved in 99 iterations and 0.05 seconds (0.00 work units)
#        0   -5.9075000e+03   2.841930e+03   0.000000e+00      0s
# Optimal objective -6.480320288e+01
#        0   -5.9075000e+03   2.841986e+03   0.000000e+00      0s
# 日前调度成本: 121549.55126665559
# 实时调度成本: -62.914336874330274
# 总成本: 121486.63692978126
# Solved in 97 iterations and 0.06 seconds (0.00 work units)
#       94   -6.4803203e+01   0.000000e+00   0.000000e+00      0s
# Optimal objective -6.291433687e+01
# Optimal objective -7.192598023e+01
#       99   -6.2914337e+01   0.000000e+00   0.000000e+00      0s
# 日前调度成本: 122306.71883878754Solved in 95 iterations and 0.06 seconds (0.00 work units)
#
# 实时调度成本: -62.91433687459721
# 总成本: 122243.80450191293
# Optimal objective -6.480320288e+01
#
# 日前调度成本: 140574.2898102863
# 实时调度成本: -62.91433687478684
# 总成本: 140511.37547341152
# 日前调度成本: 67625.00003000023
# 实时调度成本: -64.80320287958352
# 总成本: 67560.19682712064
# Freeing default Gurobi environment
#       98   -6.2914337e+01   0.000000e+00   0.000000e+00      1s
# Optimal objective -6.291433687e+01
# Solved in 99 iterations and 0.05 seconds (0.00 work units)
# 日前调度成本: 113571.86902597091
# 实时调度成本: -62.914336874634955
# 总成本: 113508.95468909628
#       96   -6.4803203e+01   0.000000e+00   0.000000e+00      1s
#
# 日前调度成本: 107031.8389995193
# 实时调度成本: -62.914336874651326
# 总成本: 106968.92466264465
# Solved in 98 iterations and 0.06 seconds (0.00 work units)
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Optimal objective -6.480320288e+01
# Solved in 95 iterations and 0.06 seconds (0.00 work units)
# Solved in 95 iterations and 0.06 seconds (0.00 work units)
#       99   -6.2914337e+01   0.000000e+00   0.000000e+00      1s
# 日前调度成本: 76431.93446262018
# 实时调度成本: -71.9259802304532
# 总成本: 76360.00848238972
# Optimal objective -6.480320288e+01
# 日前调度成本: 78443.43592622413
# 实时调度成本: -64.8032028778673
# 总成本: 78378.63272334627
# Freeing default Gurobi environment
#
# Optimal objective -6.291433687e+01
# Solved in 99 iterations and 0.71 seconds (0.00 work units)
#
# Optimal objective -6.480320288e+01
# Solved in 94 iterations and 0.70 seconds (0.00 work units)
# Optimal objective -6.480320288e+01
# Optimal objective -6.480320288e+01
# 日前调度成本: 65011.25000000014
# 实时调度成本: -64.80320288091843
# 总成本: 64946.44679711922
# Freeing default Gurobi environment
# 日前调度成本: 110327.23575915933
# 实时调度成本: -62.9143368747134
# 总成本: 110264.32142228461
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# 日前调度成本: 90721.29470329652
# 实时调度成本: -64.8032028794837
# 总成本: 90656.49150041703
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Optimal objective -6.291433687e+01
# Solved in 98 iterations and 1.90 seconds (0.00 work units)
# 日前调度成本: 97041.17834634247
# 实时调度成本: -64.80320288236362
# 总成本: 96976.3751434601
# 日前调度成本: 127027.44165424004
# 实时调度成本: -62.91433687465201
# 总成本: 126964.52731736538
# 日前调度成本: 89836.67560649042
# 实时调度成本: -64.80320287985182
# 总成本: 89771.87240361057
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Solved in 99 iterations and 1.93 seconds (0.00 work units)
# 日前调度成本: 90248.12634804251
# 实时调度成本: -64.80320288233702
# 总成本: 90183.32314516018
# Optimal objective -6.480320288e+01
# Solved in 96 iterations and 2.00 seconds (0.00 work units)
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#
# 日前调度成本: 109908.4369433309
# 实时调度成本: -62.9143368744642
# 总成本: 109845.52260645643
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# 日前调度成本: 88147.16614784038
# 实时调度成本: -64.80320288027951
# 总成本: 88082.3629449601
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Optimal objective -6.291433687e+01
# Optimal objective -6.291433687e+01
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Optimal objective -6.480320288e+01
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# 日前调度成本: 125031.72443336884Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# 实时调度成本: -62.91433687443623
# 总成本: 124968.8100964944
# Freeing default Gurobi environment
#
# 日前调度成本: 112975.39798524795
# 实时调度成本: -62.9143368745265
# 总成本: 112912.48364837343
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# 日前调度成本: 81465.90929584675
# 实时调度成本: -64.80320287870927
# 总成本: 81401.10609296804
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Model fingerprint: 0x5b37200b
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
# Coefficient statistics:
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
#
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x4df7e58e
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Model fingerprint: 0x2f160a78
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0xb7d199c9
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0xcf3bca8e
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Model fingerprint: 0x9674a366
# Model fingerprint: 0x9d97d337
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x2b602f54
# Coefficient statistics:
#
# Model fingerprint: 0x340eb904
# Coefficient statistics:
# Model fingerprint: 0x61c8cea2
# Coefficient statistics:
# Model fingerprint: 0x693d8f5b
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Coefficient statistics:
# Model fingerprint: 0x1a0f7c33
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#   Objective range  [4e+01, 2e+02]
# Model fingerprint: 0x65759d1f
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Coefficient statistics:
# Coefficient statistics:
# Model fingerprint: 0xbc55fe95
# Coefficient statistics:
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x5a4df869
#
# Coefficient statistics:
# Coefficient statistics:
# Coefficient statistics:
#   Bounds range     [2e+02, 2e+02]
#
#
# Model fingerprint: 0x64e8a7a3
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0xea6e930b
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   RHS range        [1e+00, 8e+02]
#   Matrix range     [1e+00, 4e+02]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
# Coefficient statistics:
# Model fingerprint: 0x0279fc4d
# Model fingerprint: 0xbc89b8ad
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   RHS range        [1e+00, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
# Model fingerprint: 0xde02bc5c
#   Objective range  [4e+01, 2e+02]
#   RHS range        [8e-01, 8e+02]
#   RHS range        [6e-01, 8e+02]
# Presolve removed 1059 rows and 293 columns
#   RHS range        [9e-01, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
#   RHS range        [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   RHS range        [1e+00, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
# Coefficient statistics:
# Coefficient statistics:
#   RHS range        [8e-01, 8e+02]
# Presolve removed 1059 rows and 293 columns
# Presolve time: 1.21s
#   RHS range        [8e-01, 8e+02]
#   RHS range        [1e+00, 8e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
# Presolve removed 1059 rows and 293 columns
#   RHS range        [9e-01, 8e+02]
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 1059 rows and 293 columns
#   RHS range        [1e+00, 8e+02]
#   RHS range        [8e-01, 8e+02]
# Presolve removed 1059 rows and 293 columns
# Presolve time: 0.02s
# Presolve removed 1059 rows and 293 columns
#   RHS range        [8e-01, 8e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
# Presolve time: 0.02s
# ...
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Optimal objective  8.964766778e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Optimal objective  1.096832162e+05
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Solved in 146 iterations and 3.77 seconds (0.00 work units)
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve removed 1059 rows and 293 columns
# Optimal objective  8.436350673e+04
#
# Optimal objective  1.009047839e+05
#        0   -7.6132605e+08   2.660421e+06   0.000000e+00      4s
# Presolve time: 5.49s
# Model fingerprint: 0xf5512d0f
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Coefficient statistics:
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#       75   -1.7872181e+05   2.005218e+03   0.000000e+00      7s
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#        0   -7.6258650e+08   2.664832e+06   0.000000e+00      6s
#
#   Matrix range     [1e+00, 4e+02]
#      137    9.0751413e+04   0.000000e+00   0.000000e+00      9s
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#      135    7.5647930e+04   0.000000e+00   0.000000e+00     10s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#   Objective range  [4e+01, 9e+03]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#
#
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#   Bounds range     [2e+02, 2e+02]
#        0   -7.6187333e+08   2.662336e+06   0.000000e+00     10s
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Model fingerprint: 0x17ef764a
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Solved in 137 iterations and 10.68 seconds (0.00 work units)
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#   RHS range        [1e-14, 3e+02]
#
#
# Solved in 135 iterations and 10.77 seconds (0.00 work units)
#
#       76   -2.0879277e+05   1.586935e+03   0.000000e+00     11s
# Coefficient statistics:
# Optimal objective  9.075141290e+04
#
# Model fingerprint: 0x91824e59
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# Optimal objective  7.564793044e+04
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
#
# Presolve removed 782 rows and 240 columns
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#      136    8.4153524e+04   0.000000e+00   0.000000e+00     11s
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Model fingerprint: 0xc71f44db
# Presolve time: 7.39s
# Model fingerprint: 0xe63330ac
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Model fingerprint: 0x8b916c45
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 9e+03]
# Model fingerprint: 0xfa2304ed
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#
# Coefficient statistics:
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Coefficient statistics:
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
# Model fingerprint: 0x61661589
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#   Bounds range     [2e+02, 2e+02]
# Coefficient statistics:
#   Objective range  [4e+01, 9e+03]
# Coefficient statistics:
# Model fingerprint: 0x5831c7c2
# Model fingerprint: 0x19027372
# Model fingerprint: 0xeb45c4de
#
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Model fingerprint: 0xa27500f7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Coefficient statistics:
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#
#   RHS range        [2e-13, 3e+02]
# Model fingerprint: 0x75ad2e07
#
# Solved in 136 iterations and 12.03 seconds (0.00 work units)
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
#
# Model fingerprint: 0x8a85ee72
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Coefficient statistics:
# Coefficient statistics:
# Coefficient statistics:
# Coefficient statistics:
# Model fingerprint: 0x05ad10d9
#
#   Objective range  [4e+01, 9e+03]
#   Objective range  [4e+01, 9e+03]
#   Objective range  [4e+01, 9e+03]
#   RHS range        [1e-14, 3e+02]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Optimal objective  8.415352437e+04
#   Objective range  [4e+01, 9e+03]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#   Matrix range     [1e+00, 4e+02]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Coefficient statistics:
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0x41ab0587
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
# Presolve removed 782 rows and 240 columns
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
# Model fingerprint: 0xadde4b60
#   Bounds range     [2e+02, 2e+02]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#        0   -5.9075000e+03   2.838772e+03   0.000000e+00      9s
#   Objective range  [4e+01, 9e+03]
# Presolve removed 782 rows and 240 columns
# Coefficient statistics:
#   Bounds range     [2e+02, 2e+02]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#   Bounds range     [2e+02, 2e+02]
# Presolve time: 2.04s
#   Objective range  [4e+01, 9e+03]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 9e+03]
#   Objective range  [4e+01, 9e+03]
#   Objective range  [4e+01, 9e+03]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [2e-13, 3e+02]
# Coefficient statistics:
# Presolve time: 1.87s
#       94   -1.4564167e+03   0.000000e+00   0.000000e+00      9s
#   RHS range        [3e-14, 3e+02]
#   Matrix range     [1e+00, 4e+02]
#   RHS range        [1e-13, 3e+02]
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#   RHS range        [7e-14, 3e+02]
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 9e+03]
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 9e+03]
#   Bounds range     [2e+02, 2e+02]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   RHS range        [2e-13, 3e+02]
#
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
#   Objective range  [4e+01, 9e+03]
# Presolve removed 782 rows and 240 columns
# Presolve removed 782 rows and 240 columns
#   RHS range        [6e-14, 3e+02]
#   RHS range        [1e-13, 3e+02]
#   Objective range  [4e+01, 9e+03]
#
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 782 rows and 240 columns
# Presolve removed 782 rows and 240 columns
#
#   Bounds range     [2e+02, 2e+02]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
#   RHS range        [4e-14, 3e+02]
#   Objective range  [4e+01, 9e+03]
#   RHS range        [4e-14, 3e+02]
#
# Solved in 94 iterations and 9.25 seconds (0.00 work units)
#   Bounds range     [2e+02, 2e+02]
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Presolve time: 2.04s
# Presolve removed 782 rows and 240 columns
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Model fingerprint: 0x3fed31f2
#   RHS range        [3e-14, 3e+02]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#   Bounds range     [2e+02, 2e+02]
# Presolve time: 2.04s
#   RHS range        [3e-14, 3e+02]
# Presolve removed 782 rows and 240 columns
# Presolve time: 2.04s
# Presolve removed 782 rows and 240 columns
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 782 rows and 240 columns
# Presolve time: 2.04s
# Model fingerprint: 0x2ec1bf69
# Optimal objective -1.456416654e+03
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#   RHS range        [2e-13, 3e+02]
# Presolve time: 1.87s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Presolve removed 782 rows and 240 columns
# Coefficient statistics:
# Presolve time: 1.87s
#   RHS range        [9e-14, 3e+02]
#   RHS range        [2e-13, 3e+02]
#        0   -5.9075000e+03   2.842159e+03   0.000000e+00      3s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Presolve removed 782 rows and 240 columns
# Coefficient statistics:
# Presolve removed 782 rows and 240 columns
# 日前调度成本: 92242.0167049047
# 实时调度成本: -1456.4166537498809
# 总成本: 90785.60005115482
# Presolve time: 1.75s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
# Presolve time: 1.78s
#        0   -5.9075000e+03   2.839442e+03   0.000000e+00      2s
#
# Presolve removed 782 rows and 240 columns
#
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Presolve time: 2.00s
# Presolve removed 782 rows and 240 columns
# Presolve removed 782 rows and 240 columns
#   Matrix range     [1e+00, 4e+02]
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#       97   -2.2579992e+03   0.000000e+00   0.000000e+00      3s
#
# Presolve time: 1.37s
# Presolve time: 1.09s
#
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#   Matrix range     [1e+00, 4e+02]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#       95   -2.6041876e+02   0.000000e+00   0.000000e+00      3s
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 289 rows, 527 columns, 1231 nonzeros
# Optimize a model with 1071 rows, 590 columns and 2617 nonzeros
# Presolve time: 1.19s
#
# Presolve time: 1.19s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolve time: 1.20s
#
#   Objective range  [4e+01, 9e+03]
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
#
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#        0   -5.9075000e+03   2.837411e+03   0.000000e+00      2s
#   Objective range  [4e+01, 9e+03]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
#
#        0   -5.9075000e+03   2.839529e+03   0.000000e+00      3s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
# Model fingerprint: 0x3680c903
#   Bounds range     [2e+02, 2e+02]
# Solved in 97 iterations and 3.08 seconds (0.00 work units)
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#        0   -5.9075000e+03   2.839799e+03   0.000000e+00      3s
# Presolved: 289 rows, 527 columns, 1231 nonzeros
#
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Solved in 95 iterations and 2.72 seconds (0.00 work units)
#        0   -5.9075000e+03   2.841717e+03   0.000000e+00      3s
#   Bounds range     [2e+02, 2e+02]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   RHS range        [1e-14, 3e+02]
# Optimal objective -2.257999176e+03
#
#
#        0   -5.9075000e+03   2.838047e+03   0.000000e+00      2s
# Coefficient statistics:
#
#       98   -1.4845750e+03   0.000000e+00   0.000000e+00      3s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      107    1.5649175e+06   0.000000e+00   0.000000e+00      3s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   RHS range        [1e-14, 3e+02]
#        0   -5.9075000e+03   2.818588e+03   0.000000e+00      2s
#        0   -5.9075000e+03   2.817864e+03   0.000000e+00      2s
#        0   -5.9075000e+03   2.828048e+03   0.000000e+00      2s
# Optimal objective -2.604187594e+02
#       99    1.9242098e+05   0.000000e+00   0.000000e+00      3s
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#        0   -5.9075000e+03   2.839638e+03   0.000000e+00      2s
# 日前调度成本: 121889.40640330958
# 实时调度成本: -2257.999176112663
# 总成本: 119631.40722719692
#       99   -2.1333782e+03   0.000000e+00   0.000000e+00      3s
#   Matrix range     [1e+00, 4e+02]
# Presolve removed 782 rows and 240 columns
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       94   -3.5073250e+03   0.000000e+00   0.000000e+00      2s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time

# %%
import os
import pandas as pd


input_folder = './generated_data'  
output_folder = 'load_variation'  


if not os.path.exists(output_folder):
    os.makedirs(output_folder)


for i in range(1, 25):
    input_file = os.path.join(input_folder, f'output_{i}.csv')
    output_file = os.path.join(output_folder, f'load_variation_{i}.csv')
    
    
    if os.path.exists(input_file):
        df = pd.read_csv(input_file)
        
        
        required_columns = ['load (MW)', 'Change1']
        if all(col in df.columns for col in required_columns):
            
            load_variation = df[['Change1']].sub(df['load (MW)'], axis=0)
            
            
            load_variation.to_csv(output_file, index=False)
            print(f" {input_file} complete, save to {output_file}")
        else:
            print(f" {input_file} skip")
    else:
        print(f" {input_file} not exist")
# Out:
#  ./generated_data\output_1.csv complete, save to load_variation\load_variation_1.csv
#  ./generated_data\output_2.csv complete, save to load_variation\load_variation_2.csv
#  ./generated_data\output_3.csv complete, save to load_variation\load_variation_3.csv
#  ./generated_data\output_4.csv complete, save to load_variation\load_variation_4.csv
#  ./generated_data\output_5.csv complete, save to load_variation\load_variation_5.csv
#  ./generated_data\output_6.csv complete, save to load_variation\load_variation_6.csv
#  ./generated_data\output_7.csv complete, save to load_variation\load_variation_7.csv
#  ./generated_data\output_8.csv complete, save to load_variation\load_variation_8.csv
#  ./generated_data\output_9.csv complete, save to load_variation\load_variation_9.csv
#  ./generated_data\output_10.csv complete, save to load_variation\load_variation_10.csv
#  ./generated_data\output_11.csv complete, save to load_variation\load_variation_11.csv
#  ./generated_data\output_12.csv complete, save to load_variation\load_variation_12.csv
#  ./generated_data\output_13.csv complete, save to load_variation\load_variation_13.csv
#  ./generated_data\output_14.csv complete, save to load_variation\load_variation_14.csv
#  ./generated_data\output_15.csv complete, save to load_variation\load_variation_15.csv
#  ./generated_data\output_16.csv complete, save to load_variation\load_variation_16.csv
#  ./generated_data\output_17.csv complete, save to load_variation\load_variation_17.csv
#  ./generated_data\output_18.csv complete, save to load_variation\load_variation_18.csv
#  ./generated_data\output_19.csv complete, save to load_variation\load_variation_19.csv
#  ./generated_data\output_20.csv complete, save to load_variation\load_variation_20.csv
#  ./generated_data\output_21.csv complete, save to load_variation\load_variation_21.csv
#  ./generated_data\output_22.csv complete, save to load_variation\load_variation_22.csv
#  ./generated_data\output_23.csv complete, save to load_variation\load_variation_23.csv
#  ./generated_data\output_24.csv complete, save to load_variation\load_variation_24.csv

# %%
import os
import pandas as pd

def split_and_save_data(X_train_file, Y_train_file, output_dir):
    
    X_train = pd.read_csv(X_train_file)
    Y_train = pd.read_csv(Y_train_file)

    
    if len(X_train) != len(Y_train):
        raise ValueError("X_train和Y_train的行数不一致，请检查数据。")

    
    os.makedirs(output_dir, exist_ok=True)

    
    for i in range(24):
        
        extracted_X = X_train[(X_train.index - i) % 24 == 0]
        extracted_Y = Y_train[(Y_train.index - i) % 24 == 0]

        
        if len(extracted_X) != len(extracted_Y):
            raise ValueError(f"{i}hour error")

        
        X_output_file = os.path.join(output_dir, f'X_train_hour_{i + 1}.csv')
        Y_output_file = os.path.join(output_dir, f'Y_train_hour_{i + 1}.csv')
        extracted_X.to_csv(X_output_file, index=False)
        extracted_Y.to_csv(Y_output_file, index=False)


X_train_file = './X_train.csv'  
Y_train_file = './Y_train.csv'  
output_dir = './hourly_data'    


split_and_save_data(X_train_file, Y_train_file, output_dir)

# %%
import pandas as pd
import os


def split_test_data_by_hour(X_test_file, Y_test_file, output_folder, start_hour=7):
    
    X_test = pd.read_csv(X_test_file)
    Y_test = pd.read_csv(Y_test_file)

    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    
    for hour in range(24):
        
        actual_hour = (start_hour - 1 + hour) % 24 + 1

        
        extracted_X = X_test.iloc[hour::24, :]
        extracted_Y = Y_test.iloc[hour::24, :]

        
        extracted_X.to_csv(f'{output_folder}/X_test_hour_{actual_hour}.csv', index=False)
        extracted_Y.to_csv(f'{output_folder}/Y_test_hour_{actual_hour}.csv', index=False)


def main():
    
    X_test_file = 'X_test.csv'
    Y_test_file = 'Y_test.csv'

    
    output_folder = './test_split'

    
    split_test_data_by_hour(X_test_file, Y_test_file, output_folder, start_hour=7)


main()

# %%
import os
import pandas as pd


base_dir = './hour'


for folder_num in range(1, 25):
    folder_path = os.path.join(base_dir, str(folder_num))
    
    
    cost_diff_path = os.path.join(folder_path, 'cost_differences.csv')
    cost_diff_df = pd.read_csv(cost_diff_path)
    
    
    perfect_cost_path = os.path.join(folder_path, 'perfect_costs.csv')
    perfect_cost_df = pd.read_csv(perfect_cost_path)
    
    
    result_df = cost_diff_df.div(perfect_cost_df['Perfect_Cost'], axis=0)
    
    
    result_path = os.path.join(folder_path, 'divided_costs.csv')
    result_df.to_csv(result_path, index=False)
    
    print(f"complete: {folder_path}")
# Out:
# complete: ./hour\1
# complete: ./hour\2
# complete: ./hour\3
# complete: ./hour\4
# complete: ./hour\5
# complete: ./hour\6
# complete: ./hour\7
# complete: ./hour\8
# complete: ./hour\9
# complete: ./hour\10
# complete: ./hour\11
# complete: ./hour\12
# complete: ./hour\13
# complete: ./hour\14
# complete: ./hour\15
# complete: ./hour\16
# complete: ./hour\17
# complete: ./hour\18
# complete: ./hour\19
# complete: ./hour\20
# complete: ./hour\21
# complete: ./hour\22
# complete: ./hour\23
# complete: ./hour\24

# %%
import os
import pandas as pd


load_variation_dir = './load_variation'
hourly_data_dir = './hourly_data'


for i in range(1, 25):
    
    load_variation_file = os.path.join(load_variation_dir, f'load_variation_{i}.csv')
    y_train_file = os.path.join(hourly_data_dir, f'Y_train_hour_{i}.csv')
    
    
    load_variation_df = pd.read_csv(load_variation_file)
    
    
    y_train_df = pd.read_csv(y_train_file)
    y_train_column = y_train_df.iloc[:, 0] 
    
    
    result_df = load_variation_df.div(y_train_column, axis=0)
    
    
    result_file = os.path.join(load_variation_dir, f'load_variation_divided_{i}.csv')
    result_df.to_csv(result_file, index=False)
    
    print(f"complete: {load_variation_file} -> {result_file}")
# Out:
# complete: ./load_variation\load_variation_1.csv -> ./load_variation\load_variation_divided_1.csv
# complete: ./load_variation\load_variation_2.csv -> ./load_variation\load_variation_divided_2.csv
# complete: ./load_variation\load_variation_3.csv -> ./load_variation\load_variation_divided_3.csv
# complete: ./load_variation\load_variation_4.csv -> ./load_variation\load_variation_divided_4.csv
# complete: ./load_variation\load_variation_5.csv -> ./load_variation\load_variation_divided_5.csv
# complete: ./load_variation\load_variation_6.csv -> ./load_variation\load_variation_divided_6.csv
# complete: ./load_variation\load_variation_7.csv -> ./load_variation\load_variation_divided_7.csv
# complete: ./load_variation\load_variation_8.csv -> ./load_variation\load_variation_divided_8.csv
# complete: ./load_variation\load_variation_9.csv -> ./load_variation\load_variation_divided_9.csv
# complete: ./load_variation\load_variation_10.csv -> ./load_variation\load_variation_divided_10.csv
# complete: ./load_variation\load_variation_11.csv -> ./load_variation\load_variation_divided_11.csv
# complete: ./load_variation\load_variation_12.csv -> ./load_variation\load_variation_divided_12.csv
# complete: ./load_variation\load_variation_13.csv -> ./load_variation\load_variation_divided_13.csv
# complete: ./load_variation\load_variation_14.csv -> ./load_variation\load_variation_divided_14.csv
# complete: ./load_variation\load_variation_15.csv -> ./load_variation\load_variation_divided_15.csv
# complete: ./load_variation\load_variation_16.csv -> ./load_variation\load_variation_divided_16.csv
# complete: ./load_variation\load_variation_17.csv -> ./load_variation\load_variation_divided_17.csv
# complete: ./load_variation\load_variation_18.csv -> ./load_variation\load_variation_divided_18.csv
# complete: ./load_variation\load_variation_19.csv -> ./load_variation\load_variation_divided_19.csv
# complete: ./load_variation\load_variation_20.csv -> ./load_variation\load_variation_divided_20.csv
# complete: ./load_variation\load_variation_21.csv -> ./load_variation\load_variation_divided_21.csv
# complete: ./load_variation\load_variation_22.csv -> ./load_variation\load_variation_divided_22.csv
# complete: ./load_variation\load_variation_23.csv -> ./load_variation\load_variation_divided_23.csv
# complete: ./load_variation\load_variation_24.csv -> ./load_variation\load_variation_divided_24.csv
