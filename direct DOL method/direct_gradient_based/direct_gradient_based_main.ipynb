# %%
import csv
import random

input_file = 'Y_train.csv'
with open(input_file, 'r') as f:
    reader = csv.reader(f)
    data = list(reader)

title = data[0]

rows = data[1:]

for i in range(24):
    extracted_rows = [rows[j] for j in range(len(rows)) if (j - i) % 24 == 0]
    
    output_file = f'./generated_data/output_{i+1}.csv'
    with open(output_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(title)
        writer.writerows(extracted_rows)

    with open(output_file, 'r') as f:
        reader = csv.reader(f)
        data = list(reader)
    
    title_row = data[0]
    rows_data = data[1:]
    
    for row in rows_data:
        original_value = float(row[0])
        for j in range(1, 2):
            random_factor = random.uniform(-0.15, 0.15)
            new_value = original_value * (1 + random_factor)
            row.append(f"{new_value:.2f}")
    
    with open(output_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(title_row + ['Change1'])
        writer.writerows(rows_data)

# %%
import csv
import numpy as np
import os

mpc_bus = [
    [1, 51], [2, 20], [3, 39], [4, 39], [5, 0], [6, 52], [7, 19], [8, 28], [9, 0], [10, 0],
    [11, 70], [12, 47], [13, 34], [14, 14], [15, 90], [16, 25], [17, 11], [18, 60], [19, 45], [20, 18],
    [21, 14], [22, 10], [23, 7], [24, 13], [25, 0], [26, 0], [27, 71], [28, 17], [29, 24], [30, 0],
    [31, 43], [32, 59], [33, 23], [34, 59], [35, 33], [36, 31], [37, 0], [38, 0], [39, 27], [40, 66],
    [41, 37], [42, 96], [43, 18], [44, 16], [45, 53], [46, 28], [47, 34], [48, 20], [49, 87], [50, 17],
    [51, 17], [52, 18], [53, 23], [54, 113], [55, 63], [56, 84], [57, 12], [58, 12], [59, 277], [60, 78],
    [61, 0], [62, 77], [63, 0], [64, 0], [65, 0], [66, 39], [67, 28], [68, 0], [69, 0], [70, 66],
    [71, 0], [72, 12], [73, 6], [74, 68], [75, 47], [76, 68], [77, 61], [78, 71], [79, 39], [80, 130],
    [81, 0], [82, 54], [83, 20], [84, 11], [85, 24], [86, 21], [87, 0], [88, 48], [89, 0], [90, 163],
    [91, 10], [92, 65], [93, 12], [94, 30], [95, 42], [96, 38], [97, 15], [98, 34], [99, 42], [100, 37],
    [101, 22], [102, 5], [103, 23], [104, 38], [105, 31], [106, 43], [107, 50], [108, 2], [109, 8], [110, 39],
    [111, 0], [112, 68], [113, 6], [114, 8], [115, 22], [116, 184], [117, 20], [118, 33]
]

ratio_bus = np.zeros(118)
for i in range(118):
    ratio_bus[i] = mpc_bus[i][1] / sum(mpc_bus[j][1] for j in range(118))

parent_folder = './hour'
if not os.path.exists(parent_folder):
    os.makedirs(parent_folder)

for file_num in range(1, 25):
    input_file = f'./generated_data/output_{file_num}.csv'
    with open(input_file, 'r') as f:
        reader = csv.reader(f)
        data = list(reader)

    title = data[0]
    rows = data[1:]

    folder_path = f'{parent_folder}/{file_num}'
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    allocated_data = []
    for row in rows:
        total_value = float(row[0]) 
        allocated_row = [total_value * ratio_bus[i] for i in range(118)]
        allocated_data.append(allocated_row)

    output_file = f'{folder_path}/allocated_output_perfect.csv'
    with open(output_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['Node_' + str(i+1) for i in range(118)])  
        writer.writerows(allocated_data)

    for col in range(1, 2):
        allocated_data = []
        for row in rows:
            total_value = float(row[col])  
            allocated_row = [total_value * ratio_bus[i] for i in range(118)]
            allocated_data.append(allocated_row)

        output_file = f'{folder_path}/allocated_output_change{col}.csv'
        with open(output_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['Node_' + str(i+1) for i in range(118)])  
            writer.writerows(allocated_data)

# %%
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB
import os
import csv
from concurrent.futures import ThreadPoolExecutor, as_completed

def calculate_optimization_variables(P_l_predict, Y_real, topo, unit, reserve_up=150, reserve_down=150):
    P_l_predict = np.array(P_l_predict).T    
    Y_real = np.array(Y_real).T
    
    nodes = topo.shape[0]
    
    model_DA = gp.Model()
    
    P_c = model_DA.addVars(nodes, lb=0, name='P_c')       
    R_U = model_DA.addVars(nodes, lb=0, name='R_U')       
    R_D = model_DA.addVars(nodes, lb=0, name='R_D')       
    delta_DA = model_DA.addVars(nodes, lb=-180, ub=180, name='delta_DA') 
    
    obj_DA = gp.quicksum(
        R_U[i] * unit.iloc[i, 5] + 
        R_D[i] * unit.iloc[i, 6] + 
        P_c[i] * unit.iloc[i, 2] 
        for i in range(nodes) 
    )
    model_DA.setObjective(obj_DA, GRB.MINIMIZE)
    
    model_DA.addConstr(gp.quicksum(R_U[i] for i in range(nodes)) == reserve_up)
    model_DA.addConstr(gp.quicksum(R_D[i] for i in range(nodes)) == reserve_down)
        
    for i in range(nodes):
        model_DA.addConstr(R_U[i] <= unit.iloc[i, 3])  
        model_DA.addConstr(R_D[i] <= unit.iloc[i, 4])  
        
    for t in range(nodes):
        model_DA.addConstr(
            P_c[t] - P_l_predict[t] - 
            gp.quicksum(topo.iloc[t, j] * (delta_DA[t] - delta_DA[j]) for j in range(nodes)) == 0
        )
    model_DA.addConstr(delta_DA[0] == 0)  
        
    for i in range(nodes):
        model_DA.addConstr(P_c[i] <= unit.iloc[i, 1] - R_U[i])  
        model_DA.addConstr(P_c[i] >= R_D[i])                   
        
    for i in range(nodes):
        for j in range(nodes):
            if i != j and topo.iloc[i, j] < -0.01:
                model_DA.addConstr(topo.iloc[i, j] * (delta_DA[i] - delta_DA[j]) <= 175)
                model_DA.addConstr(topo.iloc[i, j] * (delta_DA[i] - delta_DA[j]) >= -175)
    
    model_DA.optimize()
    
    P_c_values = [P_c[i].X for i in range(nodes)]
    R_U_values = [R_U[i].X for i in range(nodes)]
    R_D_values = [R_D[i].X for i in range(nodes)]
    delta_DA_values = [delta_DA[i].X for i in range(nodes)]
    
    decision_variables = {
        'P_c': P_c_values,
        'R_U': R_U_values,
        'R_D': R_D_values,
        'delta_DA': delta_DA_values
    }
    
    model_DA.dispose()
    
    return decision_variables

topo = pd.read_excel('118nodes_system.xlsx', sheet_name='topology', index_col=None, header=None) 
unit = pd.read_excel('118nodes_system.xlsx', sheet_name='unit')
hour_folder = './hour'

for hour in range(2, 25):
    hour_dir = os.path.join(hour_folder, str(hour))
    if not os.path.exists(hour_dir):
        continue
    
    perfect_file = os.path.join(hour_dir, 'allocated_output_perfect.csv')
    if not os.path.exists(perfect_file):
        continue
    
    with open(perfect_file, 'r') as f_perfect:
        reader_perfect = csv.reader(f_perfect)
        next(reader_perfect)  
        perfect_data = [list(map(float, row)) for row in reader_perfect]
    
    decision_variables_list = []
    with ThreadPoolExecutor() as executor:
        decision_variables_list = list(executor.map(lambda x: calculate_optimization_variables(x, x, topo, unit), perfect_data))
    
    decision_variables_file = os.path.join(hour_dir, 'decision_variables.csv')
    with open(decision_variables_file, 'w', newline='') as f_decision:
        writer = csv.writer(f_decision)

        writer.writerow(['P_c', 'R_U', 'R_D', 'delta_DA'])

        for dv in decision_variables_list:
            writer.writerow([dv['P_c'], dv['R_U'], dv['R_D'], dv['delta_DA']])
    

    print(f"Hour {hour}: Decision variables calculated and saved to {decision_variables_file}")
# Out:
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-03-30
# Set parameter Username
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-03-30
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-03-30
# Academic license - for non-commercial use only - expires 2026-03-30
# Academic license - for non-commercial use only - expires 2026-03-30
# Academic license - for non-commercial use only - expires 2026-03-30
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
# Model fingerprint: 0xbb7d7fd7
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Coefficient statistics:
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Model fingerprint: 0x0f9fe120
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x254a04ab
#
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#
#
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Model fingerprint: 0x48704850
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#   Matrix range     [1e+00, 4e+02]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x2d7f78dc
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
#
#
#
# Model fingerprint: 0x92ea1195
# Model fingerprint: 0x7aa34b89
# Coefficient statistics:
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0x6ef930d1
# Coefficient statistics:
# Coefficient statistics:
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#   Objective range  [4e+01, 2e+02]
# Coefficient statistics:
# Model fingerprint: 0x38caade1
#
#
#
# Model fingerprint: 0x4ed2ed83
# Model fingerprint: 0xfdf1c5b1
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0x3ddb646a
# Coefficient statistics:
# Coefficient statistics:
# Coefficient statistics:
# Model fingerprint: 0x495b92ec
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#   Matrix range     [1e+00, 4e+02]
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0x50ed30c8
# Coefficient statistics:
#   Objective range  [4e+01, 2e+02]
# Model fingerprint: 0xcc0c8097
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   RHS range        [1e+00, 8e+02]
# Coefficient statistics:
# Coefficient statistics:
# Model fingerprint: 0x0768f6c3
# Model fingerprint: 0x3ed505f0
#   Matrix range     [1e+00, 4e+02]
# Model fingerprint: 0xe52030e1
# Optimize a model with 1309 rows, 472 columns and 2971 nonzeros
# Model fingerprint: 0xdff183e7
#   Bounds range     [2e+02, 2e+02]
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
# Coefficient statistics:
# Model fingerprint: 0xf6d70ffc
# Coefficient statistics:
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
# Coefficient statistics:
# Coefficient statistics:
# Coefficient statistics:
# Presolve removed 1059 rows and 293 columns
#   RHS range        [7e-01, 8e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [6e-01, 8e+02]
#   RHS range        [4e-01, 8e+02]
#   RHS range        [8e-01, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   Matrix range     [1e+00, 4e+02]
# Presolve time: 0.49s
#   Objective range  [4e+01, 2e+02]
# Coefficient statistics:
#   RHS range        [1e+00, 8e+02]
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 2e+02]
#   RHS range        [7e-01, 8e+02]
#   Matrix range     [1e+00, 4e+02]
# Presolve removed 1059 rows and 293 columns
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
#   Objective range  [4e+01, 2e+02]
# Presolve removed 1059 rows and 293 columns
#   Objective range  [4e+01, 2e+02]
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#   RHS range        [1e+00, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Matrix range     [1e+00, 4e+02]
#   RHS range        [6e-01, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Objective range  [4e+01, 2e+02]
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 1059 rows and 293 columns
#
# Presolve time: 0.02s
#   RHS range        [9e-01, 8e+02]
# Presolve time: 0.02s
# Presolve time: 0.02s
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [9e-01, 8e+02]
# Presolve time: 0.02s
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [6e-01, 8e+02]
#   Bounds range     [2e+02, 2e+02]
# Presolve removed 1059 rows and 293 columns
#   RHS range        [9e-01, 8e+02]
#   Bounds range     [2e+02, 2e+02]
#   Bounds range     [2e+02, 2e+02]
#   Objective range  [4e+01, 2e+02]
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#   RHS range        [4e-01, 8e+02]
# Presolve time: 0.02s
#   RHS range        [6e-01, 8e+02]
# Presolve removed 1059 rows and 293 columns
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolve removed 1059 rows and 293 columns
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [8e-01, 8e+02]
#   RHS range        [1e+00, 8e+02]
#   RHS range        [7e-01, 8e+02]
# Presolve time: 0.02s
# Presolve removed 1059 rows and 293 columns
#
#
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#        0   -7.5907189e+08   2.652532e+06   0.000000e+00      0s
#   RHS range        [7e-01, 8e+02]
#
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve removed 1059 rows and 293 columns
#
# Presolve removed 1059 rows and 293 columns
# Presolve time: 0.02s
# Presolve time: 0.02s
# Presolve time: 0.02s
# Presolve removed 1059 rows and 293 columns
#   RHS range        [9e-01, 8e+02]
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
# Presolve removed 1059 rows and 293 columns
#
# Presolve removed 1059 rows and 293 columns
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolve removed 1059 rows and 293 columns
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve time: 0.02s
#
# Presolve time: 0.02s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve time: 0.02s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolve time: 0.02s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolve time: 0.02s
# Presolve removed 1059 rows and 293 columns
# Presolve time: 0.02s
#        0   -7.6142653e+08   2.660773e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolve time: 0.02s
# Presolve time: 0.02s
#        0   -7.6399152e+08   2.669749e+06   0.000000e+00      0s
#      145    1.1906279e+05   0.000000e+00   0.000000e+00      1s
# Presolve removed 1059 rows and 293 columns
#
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
#
#        0   -7.6220964e+08   2.663513e+06   0.000000e+00      0s
#        0   -7.6042338e+08   2.657262e+06   0.000000e+00      0s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#        0   -7.5863147e+08   2.650990e+06   0.000000e+00      0s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve time: 0.02s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#
# Presolved: 250 rows, 301 columns, 1131 nonzeros
# Presolve time: 0.02s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
#
#
#        0   -7.6188989e+08   2.662394e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#
#      138    8.9510053e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 145 iterations and 0.50 seconds (0.00 work units)
#
#      132    5.9738750e+04   0.000000e+00   0.000000e+00      0s
#      133    8.0129658e+04   0.000000e+00   0.000000e+00      0s
#        0   -7.5960870e+08   2.654410e+06   0.000000e+00      0s
# Presolved: 250 rows, 301 columns, 1131 nonzeros
#        0   -7.5703567e+08   2.645405e+06   0.000000e+00      0s
#
#
#
#        0   -7.6195437e+08   2.662620e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      147    1.0195415e+05   0.000000e+00   0.000000e+00      0s
#      136    1.2476970e+05   0.000000e+00   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
# Optimal objective  1.190627868e+05
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
#        0   -7.6267830e+08   2.665153e+06   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
#        0   -7.6275608e+08   2.665426e+06   0.000000e+00      0s
# Solved in 138 iterations and 0.03 seconds (0.00 work units)
#      136    8.3955473e+04   0.000000e+00   0.000000e+00      0s
#
#      145    1.1223087e+05   0.000000e+00   0.000000e+00      0s
#        0   -7.5978553e+08   2.655029e+06   0.000000e+00      0s
#        0   -7.6396029e+08   2.669640e+06   0.000000e+00      0s
#        0   -7.5849719e+08   2.650520e+06   0.000000e+00      0s
#        0   -7.6000225e+08   2.655788e+06   0.000000e+00      0s
#      142    1.4585964e+05   0.000000e+00   0.000000e+00      0s
#        0   -7.6093161e+08   2.659040e+06   0.000000e+00      0s
# Solved in 133 iterations and 0.03 seconds (0.00 work units)
# Solved in 132 iterations and 0.03 seconds (0.00 work units)
#        0   -7.6169078e+08   2.661698e+06   0.000000e+00      0s
#      133    8.3183947e+04   0.000000e+00   0.000000e+00      0s
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -7.6174330e+08   2.661881e+06   0.000000e+00      0s
# Solved in 147 iterations and 0.03 seconds (0.00 work units)
#      134    7.4576586e+04   0.000000e+00   0.000000e+00      0s
#
#
#      135    7.3677500e+04   0.000000e+00   0.000000e+00      0s
#
# Optimal objective  8.951005254e+04
# Solved in 136 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  8.012965793e+04
# Optimal objective  5.973875001e+04
# Solved in 145 iterations and 0.04 seconds (0.00 work units)
# Solved in 136 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  1.019541505e+05
# Optimal objective  1.247697047e+05
#
#        0   -7.5977755e+08   2.655001e+06   0.000000e+00      0s
#
#
#      144    1.0722220e+05   0.000000e+00   0.000000e+00      0s
#      132    6.0091250e+04   0.000000e+00   0.000000e+00      0s
#      145    1.0998035e+05   0.000000e+00   0.000000e+00      0s
#      137    1.2653397e+05   0.000000e+00   0.000000e+00      0s
#      137    8.6337659e+04   0.000000e+00   0.000000e+00      0s
#      147    9.5634017e+04   0.000000e+00   0.000000e+00      0s
# Solved in 142 iterations and 0.04 seconds (0.00 work units)
#      137    8.5709303e+04   0.000000e+00   0.000000e+00      0s
# Optimal objective  1.122308667e+05
# Solved in 133 iterations and 0.04 seconds (0.00 work units)
# Solved in 134 iterations and 0.04 seconds (0.00 work units)
# Solved in 135 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  8.395547283e+04
#      145    1.1008188e+05   0.000000e+00   0.000000e+00      0s
#
#
#
#
#
#
# Optimal objective  1.458596377e+05
# Optimal objective  8.318394677e+04
# Optimal objective  7.457658624e+04
#
# Optimal objective  7.367750003e+04
#
# Solved in 137 iterations and 0.05 seconds (0.00 work units)
# Solved in 147 iterations and 0.05 seconds (0.00 work units)
# Solved in 144 iterations and 0.05 seconds (0.00 work units)
# Solved in 132 iterations and 0.05 seconds (0.00 work units)
# Solved in 145 iterations and 0.05 seconds (0.00 work units)
# Solved in 137 iterations and 0.05 seconds (0.00 work units)
# Solved in 145 iterations and 0.05 seconds (0.00 work units)
# Freeing default Gurobi environment
# Freeing default Gurobi environment
# Solved in 137 iterations and 0.05 seconds (0.00 work units)
# Freeing default Gurobi environment
# Optimal objective  9.563401675e+04
# Optimal objective  8.633765907e+04
# Optimal objective  1.072222021e+05
# Optimal objective  6.009124999e+04
# Optimal objective  1.099803519e+05
# Optimal objective  1.265339711e+05
# Optimal objective  8.570930275e+04
# Optimal objective  1.100818789e+05
# Freeing default Gurobi environment
# Freeing default Gurobi environment
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 92
#      90 decision_variables_list = []
#      91 with ThreadPoolExecutor() as executor:
# ---> 92     decision_variables_list = list(executor.map(lambda x: calculate_optimization_variables(x, x, topo, unit), perfect_data))
#      94 decision_variables_file = os.path.join(hour_dir, 'decision_variables.csv')
#      95 with open(decision_variables_file, 'w', newline='') as f_decision:
#
# File d:\Conda\envs\NNLLL\lib\concurrent\futures\_base.py:598, in Executor.map(self, fn, timeout, chunksize, *iterables)
#     595 if timeout is not None:
#     596     end_time = timeout + time.monotonic()
# --> 598 fs = [self.submit(fn, *args) for args in zip(*iterables)]
#     600 # Yield must be hidden in closure so that the futures are submitted
#     601 # before the first iterator value is required.
#     602 def result_iterator():
#
# File d:\Conda\envs\NNLLL\lib\concurrent\futures\_base.py:598, in <listcomp>(.0)
#     595 if timeout is not None:
#     596     end_time = timeout + time.monotonic()
# --> 598 fs = [self.submit(fn, *args) for args in zip(*iterables)]
#     600 # Yield must be hidden in closure so that the futures are submitted
#     601 # before the first iterator value is required.
#     602 def result_iterator():
#
# File d:\Conda\envs\NNLLL\lib\concurrent\futures\thread.py:176, in ThreadPoolExecutor.submit(self, fn, *args, **kwargs)
#     173 w = _WorkItem(f, fn, args, kwargs)
#     175 self._work_queue.put(w)
# --> 176 self._adjust_thread_count()
#     177 return f
#
# File d:\Conda\envs\NNLLL\lib\concurrent\futures\thread.py:199, in ThreadPoolExecutor._adjust_thread_count(self)
#     192 thread_name = '%s_%d' % (self._thread_name_prefix or self,
#     193                          num_threads)
#     194 t = threading.Thread(name=thread_name, target=_worker,
#     195                      args=(weakref.ref(self, weakref_cb),
#     196                            self._work_queue,
#     197                            self._initializer,
#     198                            self._initargs))
# --> 199 t.start()
#     200 self._threads.add(t)
#     201 _threads_queues[t] = self._work_queue
#
# File d:\Conda\envs\NNLLL\lib\threading.py:904, in Thread.start(self)
#     902         del _limbo[self]
#     903     raise
# --> 904 self._started.wait()
#
# File d:\Conda\envs\NNLLL\lib\threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File d:\Conda\envs\NNLLL\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd

def split_and_save_data(X_train_file, Y_train_file, output_dir):
    
    X_train = pd.read_csv(X_train_file)
    Y_train = pd.read_csv(Y_train_file)

    
    if len(X_train) != len(Y_train):
        raise ValueError("error, check")

    
    os.makedirs(output_dir, exist_ok=True)

    
    for i in range(24):
        
        extracted_X = X_train[(X_train.index - i) % 24 == 0]
        extracted_Y = Y_train[(Y_train.index - i) % 24 == 0]

        
        if len(extracted_X) != len(extracted_Y):
            raise ValueError(f"{i}hour error")

        
        X_output_file = os.path.join(output_dir, f'X_train_hour_{i + 1}.csv')
        Y_output_file = os.path.join(output_dir, f'Y_train_hour_{i + 1}.csv')
        extracted_X.to_csv(X_output_file, index=False)
        extracted_Y.to_csv(Y_output_file, index=False)


X_train_file = './X_train.csv'  
Y_train_file = './Y_train.csv'  
output_dir = './hourly_data'    


split_and_save_data(X_train_file, Y_train_file, output_dir)

# %%
import pandas as pd
import os


def split_test_data_by_hour(X_test_file, Y_test_file, output_folder, start_hour=7):
    
    X_test = pd.read_csv(X_test_file)
    Y_test = pd.read_csv(Y_test_file)

    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    
    for hour in range(24):
        
        actual_hour = (start_hour - 1 + hour) % 24 + 1

        
        extracted_X = X_test.iloc[hour::24, :]
        extracted_Y = Y_test.iloc[hour::24, :]

        
        extracted_X.to_csv(f'{output_folder}/X_test_hour_{actual_hour}.csv', index=False)
        extracted_Y.to_csv(f'{output_folder}/Y_test_hour_{actual_hour}.csv', index=False)


def main():
    
    X_test_file = 'X_test.csv'
    Y_test_file = 'Y_test.csv'

    
    output_folder = './test_split'

    
    split_test_data_by_hour(X_test_file, Y_test_file, output_folder, start_hour=7)


main()

# %%
import os
import pandas as pd
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
import joblib
import ast  
import numpy as np


hourly_data_dir = './hourly_data'  
decision_variables_dir = './hour'   
model_output_dir = './hourly_models_scaler'  
scaler_output_dir = './hourly_scalers'  


os.makedirs(model_output_dir, exist_ok=True)
os.makedirs(scaler_output_dir, exist_ok=True)


for hour in range(1, 25):
    
    X_train_file = os.path.join(hourly_data_dir, f'X_train_hour_{hour}.csv')
    if not os.path.exists(X_train_file):
        print(f"file {X_train_file} not exist, skip")
        continue
    X_train = pd.read_csv(X_train_file)
    
    
    decision_variables_file = os.path.join(decision_variables_dir, str(hour), 'decision_variables.csv')
    if not os.path.exists(decision_variables_file):
        print(f"file {decision_variables_file} not exist, skip")
        continue
    decision_variables = pd.read_csv(decision_variables_file)
    
    
    if len(X_train) != len(decision_variables):
        print(f"hour {hour} skip")
        continue
    
    
    try:
        decision_variables['P_c'] = decision_variables['P_c'].apply(ast.literal_eval)
        decision_variables['R_U'] = decision_variables['R_U'].apply(ast.literal_eval)
        decision_variables['R_D'] = decision_variables['R_D'].apply(ast.literal_eval)
    except (ValueError, SyntaxError) as e:
        print(f"hour {hour} wrong{e}")
        continue
    
    
    P_c = np.array(decision_variables['P_c'].tolist())
    R_U = np.array(decision_variables['R_U'].tolist())
    R_D = np.array(decision_variables['R_D'].tolist())
    
    
    scaler_X = StandardScaler()
    X_train_scaled = scaler_X.fit_transform(X_train)
    
    scaler_P_c = StandardScaler()
    P_c_scaled = scaler_P_c.fit_transform(P_c)
    
    scaler_R_U = StandardScaler()
    R_U_scaled = scaler_R_U.fit_transform(R_U)
    
    scaler_R_D = StandardScaler()
    R_D_scaled = scaler_R_D.fit_transform(R_D)
    
    
    print(f"training hour {hour}  P_c ...")
    model_P_c = MLPRegressor(hidden_layer_sizes=(100, 50), max_iter=10000, random_state=42, verbose=True)
    model_P_c.fit(X_train_scaled, P_c_scaled)
    
    print(f"traing hour {hour}  R_U ...")
    model_R_U = MLPRegressor(hidden_layer_sizes=(100, 50), max_iter=10000, random_state=42, verbose=True)
    model_R_U.fit(X_train_scaled, R_U_scaled)
    
    print(f"traing hour {hour}  R_D ...")
    model_R_D = MLPRegressor(hidden_layer_sizes=(100, 50), max_iter=10000, random_state=42, verbose=True)
    model_R_D.fit(X_train_scaled, R_D_scaled)
    
    
    model_P_c_file = os.path.join(model_output_dir, f'model_P_c_hour_{hour}.pkl')
    model_R_U_file = os.path.join(model_output_dir, f'model_R_U_hour_{hour}.pkl')
    model_R_D_file = os.path.join(model_output_dir, f'model_R_D_hour_{hour}.pkl')
    
    scaler_X_file = os.path.join(scaler_output_dir, f'scaler_X_hour_{hour}.pkl')
    scaler_P_c_file = os.path.join(scaler_output_dir, f'scaler_P_c_hour_{hour}.pkl')
    scaler_R_U_file = os.path.join(scaler_output_dir, f'scaler_R_U_hour_{hour}.pkl')
    scaler_R_D_file = os.path.join(scaler_output_dir, f'scaler_R_D_hour_{hour}.pkl')
    
    joblib.dump(model_P_c, model_P_c_file)
    joblib.dump(model_R_U, model_R_U_file)
    joblib.dump(model_R_D, model_R_D_file)
    
    joblib.dump(scaler_X, scaler_X_file)
    joblib.dump(scaler_P_c, scaler_P_c_file)
    joblib.dump(scaler_R_U, scaler_R_U_file)
    joblib.dump(scaler_R_D, scaler_R_D_file)
# Out:
# training hour 1  P_c ...
# Iteration 1, loss = 0.10933198
# Iteration 2, loss = 0.10322447
# Iteration 3, loss = 0.09803545
# Iteration 4, loss = 0.09360381
# Iteration 5, loss = 0.08984536
# Iteration 6, loss = 0.08663228
# Iteration 7, loss = 0.08391077
# Iteration 8, loss = 0.08162524
# Iteration 9, loss = 0.07967028
# Iteration 10, loss = 0.07797374
# Iteration 11, loss = 0.07650276
# Iteration 12, loss = 0.07521468
# Iteration 13, loss = 0.07406924
# Iteration 14, loss = 0.07302310
# Iteration 15, loss = 0.07204761
# Iteration 16, loss = 0.07111320
# Iteration 17, loss = 0.07020593
# Iteration 18, loss = 0.06933085
# Iteration 19, loss = 0.06846747
# Iteration 20, loss = 0.06760295
# Iteration 21, loss = 0.06673791
# Iteration 22, loss = 0.06586352
# Iteration 23, loss = 0.06497491
# Iteration 24, loss = 0.06408059
# Iteration 25, loss = 0.06317339
# Iteration 26, loss = 0.06225054
# Iteration 27, loss = 0.06130824
# Iteration 28, loss = 0.06034693
# Iteration 29, loss = 0.05936254
# Iteration 30, loss = 0.05835229
# Iteration 31, loss = 0.05731870
# Iteration 32, loss = 0.05625792
# Iteration 33, loss = 0.05517124
# Iteration 34, loss = 0.05406527
# Iteration 35, loss = 0.05294434
# Iteration 36, loss = 0.05181146
# Iteration 37, loss = 0.05067219
# Iteration 38, loss = 0.04953756
# Iteration 39, loss = 0.04841051
# Iteration 40, loss = 0.04730058
# Iteration 41, loss = 0.04621553
# Iteration 42, loss = 0.04515919
# Iteration 43, loss = 0.04413988
# Iteration 44, loss = 0.04315880
# Iteration 45, loss = 0.04221624
# Iteration 46, loss = 0.04131889
# Iteration 47, loss = 0.04047024
# Iteration 48, loss = 0.03966626
# Iteration 49, loss = 0.03890435
# Iteration 50, loss = 0.03818470
# Iteration 51, loss = 0.03750600
# Iteration 52, loss = 0.03686074
# Iteration 53, loss = 0.03624555
# Iteration 54, loss = 0.03565990
# Iteration 55, loss = 0.03510358
# Iteration 56, loss = 0.03457541
# Iteration 57, loss = 0.03407508
# Iteration 58, loss = 0.03360499
# Iteration 59, loss = 0.03315614
# Iteration 60, loss = 0.03272554
# Iteration 61, loss = 0.03231155
# Iteration 62, loss = 0.03191468
# Iteration 63, loss = 0.03153393
# Iteration 64, loss = 0.03116593
# Iteration 65, loss = 0.03081168
# Iteration 66, loss = 0.03046827
# Iteration 67, loss = 0.03013195
# Iteration 68, loss = 0.02980402
# Iteration 69, loss = 0.02948309
# Iteration 70, loss = 0.02916515
# Iteration 71, loss = 0.02886502
# Iteration 72, loss = 0.02858183
# Iteration 73, loss = 0.02830098
# Iteration 74, loss = 0.02802343
# Iteration 75, loss = 0.02775244
# Iteration 76, loss = 0.02748701
# Iteration 77, loss = 0.02723245
# Iteration 78, loss = 0.02698916
# Iteration 79, loss = 0.02675498
# Iteration 80, loss = 0.02652575
# Iteration 81, loss = 0.02630414
# Iteration 82, loss = 0.02609167
# Iteration 83, loss = 0.02588266
# Iteration 84, loss = 0.02567401
# Iteration 85, loss = 0.02547221
# Iteration 86, loss = 0.02527578
# Iteration 87, loss = 0.02508449
# Iteration 88, loss = 0.02489984
# Iteration 89, loss = 0.02471511
# Iteration 90, loss = 0.02453470
# Iteration 91, loss = 0.02435816
# Iteration 92, loss = 0.02418914
# Iteration 93, loss = 0.02402747
# Iteration 94, loss = 0.02387017
# Iteration 95, loss = 0.02371521
# Iteration 96, loss = 0.02356073
# Iteration 97, loss = 0.02340512
# Iteration 98, loss = 0.02325671
# Iteration 99, loss = 0.02311016
# Iteration 100, loss = 0.02296590
# Iteration 101, loss = 0.02282386
# Iteration 102, loss = 0.02268599
# Iteration 103, loss = 0.02255105
# Iteration 104, loss = 0.02241584
# Iteration 105, loss = 0.02228463
# Iteration 106, loss = 0.02215264
# Iteration 107, loss = 0.02202438
# Iteration 108, loss = 0.02190012
# Iteration 109, loss = 0.02177338
# Iteration 110, loss = 0.02164680
# Iteration 111, loss = 0.02152062
# Iteration 112, loss = 0.02139579
# Iteration 113, loss = 0.02127325
# Iteration 114, loss = 0.02114903
# Iteration 115, loss = 0.02102553
# Iteration 116, loss = 0.02090230
# Iteration 117, loss = 0.02077574
# Iteration 118, loss = 0.02065178
# Iteration 119, loss = 0.02052946
# Iteration 120, loss = 0.02040729
# Iteration 121, loss = 0.02028323
# Iteration 122, loss = 0.02016340
# Iteration 123, loss = 0.02004006
# Iteration 124, loss = 0.01991553
# Iteration 125, loss = 0.01979317
# Iteration 126, loss = 0.01967056
# Iteration 127, loss = 0.01954823
# Iteration 128, loss = 0.01942219
# Iteration 129, loss = 0.01929737
# Iteration 130, loss = 0.01917172
# Iteration 131, loss = 0.01904443
# Iteration 132, loss = 0.01891667
# Iteration 133, loss = 0.01879210
# Iteration 134, loss = 0.01866739
# Iteration 135, loss = 0.01853992
# Iteration 136, loss = 0.01841659
# Iteration 137, loss = 0.01829348
# Iteration 138, loss = 0.01816519
# Iteration 139, loss = 0.01803593
# Iteration 140, loss = 0.01791324
# Iteration 141, loss = 0.01778635
# Iteration 142, loss = 0.01766066
# Iteration 143, loss = 0.01753556
# Iteration 144, loss = 0.01741010
# Iteration 145, loss = 0.01728681
# Iteration 146, loss = 0.01716639
# Iteration 147, loss = 0.01704402
# Iteration 148, loss = 0.01692237
# Iteration 149, loss = 0.01680142
# Iteration 150, loss = 0.01667960
# Iteration 151, loss = 0.01655887
# Iteration 152, loss = 0.01643849
# Iteration 153, loss = 0.01631733
# Iteration 154, loss = 0.01619826
# Iteration 155, loss = 0.01607943
# Iteration 156, loss = 0.01595642
# Iteration 157, loss = 0.01583844
# Iteration 158, loss = 0.01571753
# Iteration 159, loss = 0.01559630
# Iteration 160, loss = 0.01547374
# Iteration 161, loss = 0.01535785
# Iteration 162, loss = 0.01523838
# Iteration 163, loss = 0.01512174
# Iteration 164, loss = 0.01500188
# Iteration 165, loss = 0.01488322
# Iteration 166, loss = 0.01476641
# Iteration 167, loss = 0.01464762
# Iteration 168, loss = 0.01452915
# Iteration 169, loss = 0.01441526
# Iteration 170, loss = 0.01430164
# Iteration 171, loss = 0.01418323
# Iteration 172, loss = 0.01406999
# Iteration 173, loss = 0.01396013
# Iteration 174, loss = 0.01384882
# Iteration 175, loss = 0.01373699
# Iteration 176, loss = 0.01362662
# Iteration 177, loss = 0.01351689
# Iteration 178, loss = 0.01340889
# Iteration 179, loss = 0.01329995
# Iteration 180, loss = 0.01319528
# Iteration 181, loss = 0.01308916
# Iteration 182, loss = 0.01298124
# Iteration 183, loss = 0.01287437
# Iteration 184, loss = 0.01277287
# Iteration 185, loss = 0.01266951
# Iteration 186, loss = 0.01256800
# Iteration 187, loss = 0.01246502
# Iteration 188, loss = 0.01236539
# Iteration 189, loss = 0.01226909
# Iteration 190, loss = 0.01217255
# Iteration 191, loss = 0.01207395
# Iteration 192, loss = 0.01197621
# Iteration 193, loss = 0.01188236
# Iteration 194, loss = 0.01178913
# Iteration 195, loss = 0.01169347
# Iteration 196, loss = 0.01160312
# Iteration 197, loss = 0.01151444
# Iteration 198, loss = 0.01142418
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 1  R_U ...
# Iteration 1, loss = 0.03858799
# Iteration 2, loss = 0.03349070
# Iteration 3, loss = 0.02925460
# Iteration 4, loss = 0.02577699
# Iteration 5, loss = 0.02294981
# Iteration 6, loss = 0.02065181
# Iteration 7, loss = 0.01876567
# Iteration 8, loss = 0.01724362
# Iteration 9, loss = 0.01601620
# Iteration 10, loss = 0.01501283
# Iteration 11, loss = 0.01418423
# Iteration 12, loss = 0.01349316
# Iteration 13, loss = 0.01290883
# Iteration 14, loss = 0.01240870
# Iteration 15, loss = 0.01196865
# Iteration 16, loss = 0.01157477
# Iteration 17, loss = 0.01122036
# Iteration 18, loss = 0.01089015
# Iteration 19, loss = 0.01058063
# Iteration 20, loss = 0.01029266
# Iteration 21, loss = 0.01002453
# Iteration 22, loss = 0.00976747
# Iteration 23, loss = 0.00951751
# Iteration 24, loss = 0.00925937
# Iteration 25, loss = 0.00900754
# Iteration 26, loss = 0.00876079
# Iteration 27, loss = 0.00851591
# Iteration 28, loss = 0.00827099
# Iteration 29, loss = 0.00803294
# Iteration 30, loss = 0.00779702
# Iteration 31, loss = 0.00756684
# Iteration 32, loss = 0.00734792
# Iteration 33, loss = 0.00714002
# Iteration 34, loss = 0.00693536
# Iteration 35, loss = 0.00673436
# Iteration 36, loss = 0.00653778
# Iteration 37, loss = 0.00634204
# Iteration 38, loss = 0.00614599
# Iteration 39, loss = 0.00595013
# Iteration 40, loss = 0.00575361
# Iteration 41, loss = 0.00555647
# Iteration 42, loss = 0.00535977
# Iteration 43, loss = 0.00516434
# Iteration 44, loss = 0.00497075
# Iteration 45, loss = 0.00478052
# Iteration 46, loss = 0.00459457
# Iteration 47, loss = 0.00441300
# Iteration 48, loss = 0.00423564
# Iteration 49, loss = 0.00406314
# Iteration 50, loss = 0.00389433
# Iteration 51, loss = 0.00373079
# Iteration 52, loss = 0.00357406
# Iteration 53, loss = 0.00342381
# Iteration 54, loss = 0.00327930
# Iteration 55, loss = 0.00314236
# Iteration 56, loss = 0.00301474
# Iteration 57, loss = 0.00289899
# Iteration 58, loss = 0.00279082
# Iteration 59, loss = 0.00269171
# Iteration 60, loss = 0.00259865
# Iteration 61, loss = 0.00251194
# Iteration 62, loss = 0.00243155
# Iteration 63, loss = 0.00235686
# Iteration 64, loss = 0.00228712
# Iteration 65, loss = 0.00222315
# Iteration 66, loss = 0.00216389
# Iteration 67, loss = 0.00210844
# Iteration 68, loss = 0.00205686
# Iteration 69, loss = 0.00200870
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 1  R_D ...
# Iteration 1, loss = 0.04346643
# Iteration 2, loss = 0.03807410
# Iteration 3, loss = 0.03355859
# Iteration 4, loss = 0.02980378
# Iteration 5, loss = 0.02670656
# Iteration 6, loss = 0.02415763
# Iteration 7, loss = 0.02206977
# Iteration 8, loss = 0.02034155
# Iteration 9, loss = 0.01892211
# Iteration 10, loss = 0.01776308
# Iteration 11, loss = 0.01682363
# Iteration 12, loss = 0.01604531
# Iteration 13, loss = 0.01539142
# Iteration 14, loss = 0.01484367
# Iteration 15, loss = 0.01436314
# Iteration 16, loss = 0.01393547
# Iteration 17, loss = 0.01355346
# Iteration 18, loss = 0.01320635
# Iteration 19, loss = 0.01288684
# Iteration 20, loss = 0.01259210
# Iteration 21, loss = 0.01231847
# Iteration 22, loss = 0.01206343
# Iteration 23, loss = 0.01182701
# Iteration 24, loss = 0.01160599
# Iteration 25, loss = 0.01139970
# Iteration 26, loss = 0.01120560
# Iteration 27, loss = 0.01102534
# Iteration 28, loss = 0.01085793
# Iteration 29, loss = 0.01070278
# Iteration 30, loss = 0.01055539
# Iteration 31, loss = 0.01041870
# Iteration 32, loss = 0.01028750
# Iteration 33, loss = 0.01016017
# Iteration 34, loss = 0.01003267
# Iteration 35, loss = 0.00990566
# Iteration 36, loss = 0.00978096
# Iteration 37, loss = 0.00965930
# Iteration 38, loss = 0.00954808
# Iteration 39, loss = 0.00944765
# Iteration 40, loss = 0.00934359
# Iteration 41, loss = 0.00924568
# Iteration 42, loss = 0.00915067
# Iteration 43, loss = 0.00905752
# Iteration 44, loss = 0.00896722
# Iteration 45, loss = 0.00887767
# Iteration 46, loss = 0.00879289
# Iteration 47, loss = 0.00871065
# Iteration 48, loss = 0.00863108
# Iteration 49, loss = 0.00855303
# Iteration 50, loss = 0.00847332
# Iteration 51, loss = 0.00839518
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# training hour 2  P_c ...
# Iteration 1, loss = 0.10895070
# Iteration 2, loss = 0.10284168
# Iteration 3, loss = 0.09765762
# Iteration 4, loss = 0.09325628
# Iteration 5, loss = 0.08951282
# Iteration 6, loss = 0.08633117
# Iteration 7, loss = 0.08365944
# Iteration 8, loss = 0.08140391
# Iteration 9, loss = 0.07944496
# Iteration 10, loss = 0.07777849
# Iteration 11, loss = 0.07632212
# Iteration 12, loss = 0.07501719
# Iteration 13, loss = 0.07385893
# Iteration 14, loss = 0.07280087
# Iteration 15, loss = 0.07181838
# Iteration 16, loss = 0.07088989
# Iteration 17, loss = 0.06998466
# Iteration 18, loss = 0.06910490
# Iteration 19, loss = 0.06823581
# Iteration 20, loss = 0.06737153
# Iteration 21, loss = 0.06649725
# Iteration 22, loss = 0.06561664
# Iteration 23, loss = 0.06472520
# Iteration 24, loss = 0.06382353
# Iteration 25, loss = 0.06291119
# Iteration 26, loss = 0.06198149
# Iteration 27, loss = 0.06101870
# Iteration 28, loss = 0.06003166
# Iteration 29, loss = 0.05902191
# Iteration 30, loss = 0.05798753
# Iteration 31, loss = 0.05692561
# Iteration 32, loss = 0.05583816
# Iteration 33, loss = 0.05472569
# Iteration 34, loss = 0.05359477
# Iteration 35, loss = 0.05244619
# Iteration 36, loss = 0.05128310
# Iteration 37, loss = 0.05011023
# Iteration 38, loss = 0.04893484
# Iteration 39, loss = 0.04777162
# Iteration 40, loss = 0.04662957
# Iteration 41, loss = 0.04551283
# Iteration 42, loss = 0.04442673
# Iteration 43, loss = 0.04337960
# Iteration 44, loss = 0.04237549
# Iteration 45, loss = 0.04141887
# Iteration 46, loss = 0.04051303
# Iteration 47, loss = 0.03965942
# Iteration 48, loss = 0.03885725
# Iteration 49, loss = 0.03810695
# Iteration 50, loss = 0.03740292
# Iteration 51, loss = 0.03674063
# Iteration 52, loss = 0.03611689
# Iteration 53, loss = 0.03552763
# Iteration 54, loss = 0.03497269
# Iteration 55, loss = 0.03444738
# Iteration 56, loss = 0.03394950
# Iteration 57, loss = 0.03348015
# Iteration 58, loss = 0.03303534
# Iteration 59, loss = 0.03261384
# Iteration 60, loss = 0.03221125
# Iteration 61, loss = 0.03182449
# Iteration 62, loss = 0.03145717
# Iteration 63, loss = 0.03110391
# Iteration 64, loss = 0.03076858
# Iteration 65, loss = 0.03045502
# Iteration 66, loss = 0.03014683
# Iteration 67, loss = 0.02984113
# Iteration 68, loss = 0.02953921
# Iteration 69, loss = 0.02924280
# Iteration 70, loss = 0.02895262
# Iteration 71, loss = 0.02867124
# Iteration 72, loss = 0.02839659
# Iteration 73, loss = 0.02812215
# Iteration 74, loss = 0.02785493
# Iteration 75, loss = 0.02760426
# Iteration 76, loss = 0.02736005
# Iteration 77, loss = 0.02711908
# Iteration 78, loss = 0.02688060
# Iteration 79, loss = 0.02664757
# Iteration 80, loss = 0.02642568
# Iteration 81, loss = 0.02621261
# Iteration 82, loss = 0.02600674
# Iteration 83, loss = 0.02580980
# Iteration 84, loss = 0.02562116
# Iteration 85, loss = 0.02543109
# Iteration 86, loss = 0.02524390
# Iteration 87, loss = 0.02506193
# Iteration 88, loss = 0.02488160
# Iteration 89, loss = 0.02470311
# Iteration 90, loss = 0.02452765
# Iteration 91, loss = 0.02435746
# Iteration 92, loss = 0.02419144
# Iteration 93, loss = 0.02402953
# Iteration 94, loss = 0.02386836
# Iteration 95, loss = 0.02371432
# Iteration 96, loss = 0.02356387
# Iteration 97, loss = 0.02341750
# Iteration 98, loss = 0.02327095
# Iteration 99, loss = 0.02312531
# Iteration 100, loss = 0.02298394
# Iteration 101, loss = 0.02284493
# Iteration 102, loss = 0.02270922
# Iteration 103, loss = 0.02257385
# Iteration 104, loss = 0.02244043
# Iteration 105, loss = 0.02230745
# Iteration 106, loss = 0.02217839
# Iteration 107, loss = 0.02205082
# Iteration 108, loss = 0.02192278
# Iteration 109, loss = 0.02179323
# Iteration 110, loss = 0.02166575
# Iteration 111, loss = 0.02154370
# Iteration 112, loss = 0.02142050
# Iteration 113, loss = 0.02129749
# Iteration 114, loss = 0.02117774
# Iteration 115, loss = 0.02105919
# Iteration 116, loss = 0.02093733
# Iteration 117, loss = 0.02081597
# Iteration 118, loss = 0.02069963
# Iteration 119, loss = 0.02058248
# Iteration 120, loss = 0.02046540
# Iteration 121, loss = 0.02034650
# Iteration 122, loss = 0.02022913
# Iteration 123, loss = 0.02011350
# Iteration 124, loss = 0.01999888
# Iteration 125, loss = 0.01988389
# Iteration 126, loss = 0.01976887
# Iteration 127, loss = 0.01965556
# Iteration 128, loss = 0.01954062
# Iteration 129, loss = 0.01942612
# Iteration 130, loss = 0.01931189
# Iteration 131, loss = 0.01919569
# Iteration 132, loss = 0.01907948
# Iteration 133, loss = 0.01896304
# Iteration 134, loss = 0.01884678
# Iteration 135, loss = 0.01872897
# Iteration 136, loss = 0.01861004
# Iteration 137, loss = 0.01849608
# Iteration 138, loss = 0.01838234
# Iteration 139, loss = 0.01826493
# Iteration 140, loss = 0.01815520
# Iteration 141, loss = 0.01804478
# Iteration 142, loss = 0.01793211
# Iteration 143, loss = 0.01782312
# Iteration 144, loss = 0.01771145
# Iteration 145, loss = 0.01759777
# Iteration 146, loss = 0.01748721
# Iteration 147, loss = 0.01737835
# Iteration 148, loss = 0.01727000
# Iteration 149, loss = 0.01715623
# Iteration 150, loss = 0.01704465
# Iteration 151, loss = 0.01693392
# Iteration 152, loss = 0.01682501
# Iteration 153, loss = 0.01671330
# Iteration 154, loss = 0.01660408
# Iteration 155, loss = 0.01649320
# Iteration 156, loss = 0.01638350
# Iteration 157, loss = 0.01627635
# Iteration 158, loss = 0.01616856
# Iteration 159, loss = 0.01606078
# Iteration 160, loss = 0.01595296
# Iteration 161, loss = 0.01584460
# Iteration 162, loss = 0.01574087
# Iteration 163, loss = 0.01563330
# Iteration 164, loss = 0.01552082
# Iteration 165, loss = 0.01541739
# Iteration 166, loss = 0.01531220
# Iteration 167, loss = 0.01520461
# Iteration 168, loss = 0.01509670
# Iteration 169, loss = 0.01499347
# Iteration 170, loss = 0.01488800
# Iteration 171, loss = 0.01478033
# Iteration 172, loss = 0.01467899
# Iteration 173, loss = 0.01457685
# Iteration 174, loss = 0.01447094
# Iteration 175, loss = 0.01437152
# Iteration 176, loss = 0.01427227
# Iteration 177, loss = 0.01417059
# Iteration 178, loss = 0.01406949
# Iteration 179, loss = 0.01397061
# Iteration 180, loss = 0.01387602
# Iteration 181, loss = 0.01378074
# Iteration 182, loss = 0.01368514
# Iteration 183, loss = 0.01359131
# Iteration 184, loss = 0.01349693
# Iteration 185, loss = 0.01340384
# Iteration 186, loss = 0.01331221
# Iteration 187, loss = 0.01322253
# Iteration 188, loss = 0.01313053
# Iteration 189, loss = 0.01304284
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 2  R_U ...
# Iteration 1, loss = 0.03856916
# Iteration 2, loss = 0.03347543
# Iteration 3, loss = 0.02922746
# Iteration 4, loss = 0.02574902
# Iteration 5, loss = 0.02292956
# Iteration 6, loss = 0.02063367
# Iteration 7, loss = 0.01875990
# Iteration 8, loss = 0.01723429
# Iteration 9, loss = 0.01599475
# Iteration 10, loss = 0.01498366
# Iteration 11, loss = 0.01415953
# Iteration 12, loss = 0.01348047
# Iteration 13, loss = 0.01291883
# Iteration 14, loss = 0.01243204
# Iteration 15, loss = 0.01200060
# Iteration 16, loss = 0.01161273
# Iteration 17, loss = 0.01125696
# Iteration 18, loss = 0.01093212
# Iteration 19, loss = 0.01063110
# Iteration 20, loss = 0.01035344
# Iteration 21, loss = 0.01009418
# Iteration 22, loss = 0.00984639
# Iteration 23, loss = 0.00959865
# Iteration 24, loss = 0.00935878
# Iteration 25, loss = 0.00912498
# Iteration 26, loss = 0.00889351
# Iteration 27, loss = 0.00866894
# Iteration 28, loss = 0.00845055
# Iteration 29, loss = 0.00823883
# Iteration 30, loss = 0.00802802
# Iteration 31, loss = 0.00782444
# Iteration 32, loss = 0.00762807
# Iteration 33, loss = 0.00743567
# Iteration 34, loss = 0.00724279
# Iteration 35, loss = 0.00705441
# Iteration 36, loss = 0.00686871
# Iteration 37, loss = 0.00668538
# Iteration 38, loss = 0.00650270
# Iteration 39, loss = 0.00631841
# Iteration 40, loss = 0.00613344
# Iteration 41, loss = 0.00594749
# Iteration 42, loss = 0.00576250
# Iteration 43, loss = 0.00558059
# Iteration 44, loss = 0.00540187
# Iteration 45, loss = 0.00522641
# Iteration 46, loss = 0.00505491
# Iteration 47, loss = 0.00488685
# Iteration 48, loss = 0.00472216
# Iteration 49, loss = 0.00455949
# Iteration 50, loss = 0.00439850
# Iteration 51, loss = 0.00423780
# Iteration 52, loss = 0.00407968
# Iteration 53, loss = 0.00392524
# Iteration 54, loss = 0.00377582
# Iteration 55, loss = 0.00363144
# Iteration 56, loss = 0.00349458
# Iteration 57, loss = 0.00336396
# Iteration 58, loss = 0.00323990
# Iteration 59, loss = 0.00312464
# Iteration 60, loss = 0.00301995
# Iteration 61, loss = 0.00292132
# Iteration 62, loss = 0.00282662
# Iteration 63, loss = 0.00273705
# Iteration 64, loss = 0.00265380
# Iteration 65, loss = 0.00257781
# Iteration 66, loss = 0.00250867
# Iteration 67, loss = 0.00244515
# Iteration 68, loss = 0.00238648
# Iteration 69, loss = 0.00233144
# Iteration 70, loss = 0.00228022
# Iteration 71, loss = 0.00223271
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 2  R_D ...
# Iteration 1, loss = 0.04345525
# Iteration 2, loss = 0.03803259
# Iteration 3, loss = 0.03349298
# Iteration 4, loss = 0.02972525
# Iteration 5, loss = 0.02661280
# Iteration 6, loss = 0.02405490
# Iteration 7, loss = 0.02195301
# Iteration 8, loss = 0.02022615
# Iteration 9, loss = 0.01878837
# Iteration 10, loss = 0.01760604
# Iteration 11, loss = 0.01663804
# Iteration 12, loss = 0.01584581
# Iteration 13, loss = 0.01517798
# Iteration 14, loss = 0.01460765
# Iteration 15, loss = 0.01411226
# Iteration 16, loss = 0.01367029
# Iteration 17, loss = 0.01327014
# Iteration 18, loss = 0.01290747
# Iteration 19, loss = 0.01257330
# Iteration 20, loss = 0.01226402
# Iteration 21, loss = 0.01197700
# Iteration 22, loss = 0.01171286
# Iteration 23, loss = 0.01146915
# Iteration 24, loss = 0.01124807
# Iteration 25, loss = 0.01104473
# Iteration 26, loss = 0.01085668
# Iteration 27, loss = 0.01068067
# Iteration 28, loss = 0.01051647
# Iteration 29, loss = 0.01036123
# Iteration 30, loss = 0.01021429
# Iteration 31, loss = 0.01007113
# Iteration 32, loss = 0.00993270
# Iteration 33, loss = 0.00979716
# Iteration 34, loss = 0.00966381
# Iteration 35, loss = 0.00953303
# Iteration 36, loss = 0.00940637
# Iteration 37, loss = 0.00928218
# Iteration 38, loss = 0.00916393
# Iteration 39, loss = 0.00905340
# Iteration 40, loss = 0.00894725
# Iteration 41, loss = 0.00884538
# Iteration 42, loss = 0.00874589
# Iteration 43, loss = 0.00864860
# Iteration 44, loss = 0.00855385
# Iteration 45, loss = 0.00846057
# Iteration 46, loss = 0.00836806
# Iteration 47, loss = 0.00827647
# Iteration 48, loss = 0.00818357
# Iteration 49, loss = 0.00809215
# Iteration 50, loss = 0.00800265
# Iteration 51, loss = 0.00791166
# Iteration 52, loss = 0.00781907
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# training hour 3  P_c ...
# Iteration 1, loss = 0.11287601
# Iteration 2, loss = 0.10680186
# Iteration 3, loss = 0.10163983
# Iteration 4, loss = 0.09723704
# Iteration 5, loss = 0.09350002
# Iteration 6, loss = 0.09031574
# Iteration 7, loss = 0.08762580
# Iteration 8, loss = 0.08534661
# Iteration 9, loss = 0.08337135
# Iteration 10, loss = 0.08168931
# Iteration 11, loss = 0.08020951
# Iteration 12, loss = 0.07889600
# Iteration 13, loss = 0.07772329
# Iteration 14, loss = 0.07665359
# Iteration 15, loss = 0.07565846
# Iteration 16, loss = 0.07471331
# Iteration 17, loss = 0.07378735
# Iteration 18, loss = 0.07287368
# Iteration 19, loss = 0.07196806
# Iteration 20, loss = 0.07105599
# Iteration 21, loss = 0.07013425
# Iteration 22, loss = 0.06920024
# Iteration 23, loss = 0.06825898
# Iteration 24, loss = 0.06730929
# Iteration 25, loss = 0.06634902
# Iteration 26, loss = 0.06537160
# Iteration 27, loss = 0.06436864
# Iteration 28, loss = 0.06334474
# Iteration 29, loss = 0.06229675
# Iteration 30, loss = 0.06122063
# Iteration 31, loss = 0.06011722
# Iteration 32, loss = 0.05898939
# Iteration 33, loss = 0.05783589
# Iteration 34, loss = 0.05666265
# Iteration 35, loss = 0.05547724
# Iteration 36, loss = 0.05427556
# Iteration 37, loss = 0.05306487
# Iteration 38, loss = 0.05185651
# Iteration 39, loss = 0.05065602
# Iteration 40, loss = 0.04947726
# Iteration 41, loss = 0.04832946
# Iteration 42, loss = 0.04721887
# Iteration 43, loss = 0.04614811
# Iteration 44, loss = 0.04512484
# Iteration 45, loss = 0.04415556
# Iteration 46, loss = 0.04324127
# Iteration 47, loss = 0.04238234
# Iteration 48, loss = 0.04157992
# Iteration 49, loss = 0.04082974
# Iteration 50, loss = 0.04012608
# Iteration 51, loss = 0.03946451
# Iteration 52, loss = 0.03884414
# Iteration 53, loss = 0.03826729
# Iteration 54, loss = 0.03772534
# Iteration 55, loss = 0.03720756
# Iteration 56, loss = 0.03671170
# Iteration 57, loss = 0.03623892
# Iteration 58, loss = 0.03578967
# Iteration 59, loss = 0.03536308
# Iteration 60, loss = 0.03496208
# Iteration 61, loss = 0.03458617
# Iteration 62, loss = 0.03422351
# Iteration 63, loss = 0.03387852
# Iteration 64, loss = 0.03354849
# Iteration 65, loss = 0.03322380
# Iteration 66, loss = 0.03290826
# Iteration 67, loss = 0.03260341
# Iteration 68, loss = 0.03230565
# Iteration 69, loss = 0.03201785
# Iteration 70, loss = 0.03174267
# Iteration 71, loss = 0.03147347
# Iteration 72, loss = 0.03120810
# Iteration 73, loss = 0.03096516
# Iteration 74, loss = 0.03072423
# Iteration 75, loss = 0.03049023
# Iteration 76, loss = 0.03025553
# Iteration 77, loss = 0.03002173
# Iteration 78, loss = 0.02979577
# Iteration 79, loss = 0.02958166
# Iteration 80, loss = 0.02937353
# Iteration 81, loss = 0.02917481
# Iteration 82, loss = 0.02898368
# Iteration 83, loss = 0.02879434
# Iteration 84, loss = 0.02860526
# Iteration 85, loss = 0.02841775
# Iteration 86, loss = 0.02824380
# Iteration 87, loss = 0.02807394
# Iteration 88, loss = 0.02790551
# Iteration 89, loss = 0.02773784
# Iteration 90, loss = 0.02757030
# Iteration 91, loss = 0.02740395
# Iteration 92, loss = 0.02724038
# Iteration 93, loss = 0.02708244
# Iteration 94, loss = 0.02692505
# Iteration 95, loss = 0.02676810
# Iteration 96, loss = 0.02661714
# Iteration 97, loss = 0.02646741
# Iteration 98, loss = 0.02632216
# Iteration 99, loss = 0.02617678
# Iteration 100, loss = 0.02603252
# Iteration 101, loss = 0.02588713
# Iteration 102, loss = 0.02574407
# Iteration 103, loss = 0.02560678
# Iteration 104, loss = 0.02547012
# Iteration 105, loss = 0.02533084
# Iteration 106, loss = 0.02519121
# Iteration 107, loss = 0.02505976
# Iteration 108, loss = 0.02492293
# Iteration 109, loss = 0.02478751
# Iteration 110, loss = 0.02465267
# Iteration 111, loss = 0.02451908
# Iteration 112, loss = 0.02438516
# Iteration 113, loss = 0.02425265
# Iteration 114, loss = 0.02411965
# Iteration 115, loss = 0.02398380
# Iteration 116, loss = 0.02385051
# Iteration 117, loss = 0.02371787
# Iteration 118, loss = 0.02358581
# Iteration 119, loss = 0.02345304
# Iteration 120, loss = 0.02332275
# Iteration 121, loss = 0.02319251
# Iteration 122, loss = 0.02306329
# Iteration 123, loss = 0.02293217
# Iteration 124, loss = 0.02279835
# Iteration 125, loss = 0.02266615
# Iteration 126, loss = 0.02253474
# Iteration 127, loss = 0.02240104
# Iteration 128, loss = 0.02226485
# Iteration 129, loss = 0.02213109
# Iteration 130, loss = 0.02199336
# Iteration 131, loss = 0.02185560
# Iteration 132, loss = 0.02171563
# Iteration 133, loss = 0.02157389
# Iteration 134, loss = 0.02143543
# Iteration 135, loss = 0.02129959
# Iteration 136, loss = 0.02116436
# Iteration 137, loss = 0.02103183
# Iteration 138, loss = 0.02089890
# Iteration 139, loss = 0.02076874
# Iteration 140, loss = 0.02063802
# Iteration 141, loss = 0.02050931
# Iteration 142, loss = 0.02037619
# Iteration 143, loss = 0.02024428
# Iteration 144, loss = 0.02011560
# Iteration 145, loss = 0.01998747
# Iteration 146, loss = 0.01985551
# Iteration 147, loss = 0.01972323
# Iteration 148, loss = 0.01959328
# Iteration 149, loss = 0.01946379
# Iteration 150, loss = 0.01933600
# Iteration 151, loss = 0.01920719
# Iteration 152, loss = 0.01907787
# Iteration 153, loss = 0.01895310
# Iteration 154, loss = 0.01882612
# Iteration 155, loss = 0.01870004
# Iteration 156, loss = 0.01857296
# Iteration 157, loss = 0.01844774
# Iteration 158, loss = 0.01832276
# Iteration 159, loss = 0.01819615
# Iteration 160, loss = 0.01807219
# Iteration 161, loss = 0.01794894
# Iteration 162, loss = 0.01782342
# Iteration 163, loss = 0.01770299
# Iteration 164, loss = 0.01758160
# Iteration 165, loss = 0.01745967
# Iteration 166, loss = 0.01734101
# Iteration 167, loss = 0.01722224
# Iteration 168, loss = 0.01710772
# Iteration 169, loss = 0.01698958
# Iteration 170, loss = 0.01687228
# Iteration 171, loss = 0.01675332
# Iteration 172, loss = 0.01664003
# Iteration 173, loss = 0.01652720
# Iteration 174, loss = 0.01641511
# Iteration 175, loss = 0.01630422
# Iteration 176, loss = 0.01618944
# Iteration 177, loss = 0.01607862
# Iteration 178, loss = 0.01596953
# Iteration 179, loss = 0.01586452
# Iteration 180, loss = 0.01575641
# Iteration 181, loss = 0.01564727
# Iteration 182, loss = 0.01554228
# Iteration 183, loss = 0.01543847
# Iteration 184, loss = 0.01533654
# Iteration 185, loss = 0.01523762
# Iteration 186, loss = 0.01514027
# Iteration 187, loss = 0.01504494
# Iteration 188, loss = 0.01494661
# Iteration 189, loss = 0.01485482
# Iteration 190, loss = 0.01476125
# Iteration 191, loss = 0.01466986
# Iteration 192, loss = 0.01457776
# Iteration 193, loss = 0.01448760
# Iteration 194, loss = 0.01439666
# Iteration 195, loss = 0.01430916
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 3  R_U ...
# Iteration 1, loss = 0.03869239
# Iteration 2, loss = 0.03362493
# Iteration 3, loss = 0.02939010
# Iteration 4, loss = 0.02589873
# Iteration 5, loss = 0.02306326
# Iteration 6, loss = 0.02075214
# Iteration 7, loss = 0.01887666
# Iteration 8, loss = 0.01735721
# Iteration 9, loss = 0.01612924
# Iteration 10, loss = 0.01512262
# Iteration 11, loss = 0.01428775
# Iteration 12, loss = 0.01359843
# Iteration 13, loss = 0.01302569
# Iteration 14, loss = 0.01253446
# Iteration 15, loss = 0.01211046
# Iteration 16, loss = 0.01173268
# Iteration 17, loss = 0.01139124
# Iteration 18, loss = 0.01108001
# Iteration 19, loss = 0.01079491
# Iteration 20, loss = 0.01053424
# Iteration 21, loss = 0.01028653
# Iteration 22, loss = 0.01004672
# Iteration 23, loss = 0.00981504
# Iteration 24, loss = 0.00959003
# Iteration 25, loss = 0.00936655
# Iteration 26, loss = 0.00914954
# Iteration 27, loss = 0.00893777
# Iteration 28, loss = 0.00872667
# Iteration 29, loss = 0.00851596
# Iteration 30, loss = 0.00830639
# Iteration 31, loss = 0.00810232
# Iteration 32, loss = 0.00790508
# Iteration 33, loss = 0.00771416
# Iteration 34, loss = 0.00752860
# Iteration 35, loss = 0.00734656
# Iteration 36, loss = 0.00716745
# Iteration 37, loss = 0.00699040
# Iteration 38, loss = 0.00681551
# Iteration 39, loss = 0.00664273
# Iteration 40, loss = 0.00647163
# Iteration 41, loss = 0.00630209
# Iteration 42, loss = 0.00613400
# Iteration 43, loss = 0.00596723
# Iteration 44, loss = 0.00580158
# Iteration 45, loss = 0.00563817
# Iteration 46, loss = 0.00547629
# Iteration 47, loss = 0.00531537
# Iteration 48, loss = 0.00515717
# Iteration 49, loss = 0.00500026
# Iteration 50, loss = 0.00484351
# Iteration 51, loss = 0.00468853
# Iteration 52, loss = 0.00453645
# Iteration 53, loss = 0.00438796
# Iteration 54, loss = 0.00424337
# Iteration 55, loss = 0.00410405
# Iteration 56, loss = 0.00396990
# Iteration 57, loss = 0.00384024
# Iteration 58, loss = 0.00371605
# Iteration 59, loss = 0.00359709
# Iteration 60, loss = 0.00348319
# Iteration 61, loss = 0.00337618
# Iteration 62, loss = 0.00328147
# Iteration 63, loss = 0.00318947
# Iteration 64, loss = 0.00310030
# Iteration 65, loss = 0.00301809
# Iteration 66, loss = 0.00294466
# Iteration 67, loss = 0.00287868
# Iteration 68, loss = 0.00281767
# Iteration 69, loss = 0.00275996
# Iteration 70, loss = 0.00270582
# Iteration 71, loss = 0.00265557
# Iteration 72, loss = 0.00260942
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 3  R_D ...
# Iteration 1, loss = 0.04305680
# Iteration 2, loss = 0.03767736
# Iteration 3, loss = 0.03318192
# Iteration 4, loss = 0.02943270
# Iteration 5, loss = 0.02633417
# Iteration 6, loss = 0.02377593
# Iteration 7, loss = 0.02168120
# Iteration 8, loss = 0.01997059
# Iteration 9, loss = 0.01854711
# Iteration 10, loss = 0.01738503
# Iteration 11, loss = 0.01645598
# Iteration 12, loss = 0.01568857
# Iteration 13, loss = 0.01503138
# Iteration 14, loss = 0.01446970
# Iteration 15, loss = 0.01397501
# Iteration 16, loss = 0.01353256
# Iteration 17, loss = 0.01313983
# Iteration 18, loss = 0.01278322
# Iteration 19, loss = 0.01246129
# Iteration 20, loss = 0.01216431
# Iteration 21, loss = 0.01189406
# Iteration 22, loss = 0.01164648
# Iteration 23, loss = 0.01141952
# Iteration 24, loss = 0.01121234
# Iteration 25, loss = 0.01102098
# Iteration 26, loss = 0.01084295
# Iteration 27, loss = 0.01067997
# Iteration 28, loss = 0.01052571
# Iteration 29, loss = 0.01038137
# Iteration 30, loss = 0.01024244
# Iteration 31, loss = 0.01010441
# Iteration 32, loss = 0.00996745
# Iteration 33, loss = 0.00983062
# Iteration 34, loss = 0.00969656
# Iteration 35, loss = 0.00956851
# Iteration 36, loss = 0.00944102
# Iteration 37, loss = 0.00931958
# Iteration 38, loss = 0.00919667
# Iteration 39, loss = 0.00908419
# Iteration 40, loss = 0.00897993
# Iteration 41, loss = 0.00888077
# Iteration 42, loss = 0.00878290
# Iteration 43, loss = 0.00868589
# Iteration 44, loss = 0.00858909
# Iteration 45, loss = 0.00849295
# Iteration 46, loss = 0.00839938
# Iteration 47, loss = 0.00830733
# Iteration 48, loss = 0.00821532
# Iteration 49, loss = 0.00812443
# Iteration 50, loss = 0.00803801
# Iteration 51, loss = 0.00795468
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# training hour 4  P_c ...
# Iteration 1, loss = 0.11723102
# Iteration 2, loss = 0.11112150
# Iteration 3, loss = 0.10593713
# Iteration 4, loss = 0.10151162
# Iteration 5, loss = 0.09773563
# Iteration 6, loss = 0.09452790
# Iteration 7, loss = 0.09180832
# Iteration 8, loss = 0.08947448
# Iteration 9, loss = 0.08748856
# Iteration 10, loss = 0.08579004
# Iteration 11, loss = 0.08428326
# Iteration 12, loss = 0.08292707
# Iteration 13, loss = 0.08169521
# Iteration 14, loss = 0.08054615
# Iteration 15, loss = 0.07947522
# Iteration 16, loss = 0.07845319
# Iteration 17, loss = 0.07745569
# Iteration 18, loss = 0.07649596
# Iteration 19, loss = 0.07554166
# Iteration 20, loss = 0.07458520
# Iteration 21, loss = 0.07363249
# Iteration 22, loss = 0.07267472
# Iteration 23, loss = 0.07170712
# Iteration 24, loss = 0.07073133
# Iteration 25, loss = 0.06973699
# Iteration 26, loss = 0.06872164
# Iteration 27, loss = 0.06767519
# Iteration 28, loss = 0.06660374
# Iteration 29, loss = 0.06550443
# Iteration 30, loss = 0.06437644
# Iteration 31, loss = 0.06322814
# Iteration 32, loss = 0.06206300
# Iteration 33, loss = 0.06087941
# Iteration 34, loss = 0.05967913
# Iteration 35, loss = 0.05846487
# Iteration 36, loss = 0.05724255
# Iteration 37, loss = 0.05602028
# Iteration 38, loss = 0.05480314
# Iteration 39, loss = 0.05359899
# Iteration 40, loss = 0.05241813
# Iteration 41, loss = 0.05127016
# Iteration 42, loss = 0.05016411
# Iteration 43, loss = 0.04910373
# Iteration 44, loss = 0.04809136
# Iteration 45, loss = 0.04713381
# Iteration 46, loss = 0.04623321
# Iteration 47, loss = 0.04539270
# Iteration 48, loss = 0.04461194
# Iteration 49, loss = 0.04387981
# Iteration 50, loss = 0.04319638
# Iteration 51, loss = 0.04255773
# Iteration 52, loss = 0.04195139
# Iteration 53, loss = 0.04137353
# Iteration 54, loss = 0.04082429
# Iteration 55, loss = 0.04029871
# Iteration 56, loss = 0.03979679
# Iteration 57, loss = 0.03931325
# Iteration 58, loss = 0.03884897
# Iteration 59, loss = 0.03840585
# Iteration 60, loss = 0.03798321
# Iteration 61, loss = 0.03758395
# Iteration 62, loss = 0.03720441
# Iteration 63, loss = 0.03684074
# Iteration 64, loss = 0.03648796
# Iteration 65, loss = 0.03614441
# Iteration 66, loss = 0.03580896
# Iteration 67, loss = 0.03548188
# Iteration 68, loss = 0.03516852
# Iteration 69, loss = 0.03486322
# Iteration 70, loss = 0.03455951
# Iteration 71, loss = 0.03426402
# Iteration 72, loss = 0.03397234
# Iteration 73, loss = 0.03370496
# Iteration 74, loss = 0.03345999
# Iteration 75, loss = 0.03321240
# Iteration 76, loss = 0.03297067
# Iteration 77, loss = 0.03272841
# Iteration 78, loss = 0.03248940
# Iteration 79, loss = 0.03225427
# Iteration 80, loss = 0.03202636
# Iteration 81, loss = 0.03181338
# Iteration 82, loss = 0.03160763
# Iteration 83, loss = 0.03139687
# Iteration 84, loss = 0.03119659
# Iteration 85, loss = 0.03100435
# Iteration 86, loss = 0.03081955
# Iteration 87, loss = 0.03063675
# Iteration 88, loss = 0.03045333
# Iteration 89, loss = 0.03027400
# Iteration 90, loss = 0.03009964
# Iteration 91, loss = 0.02992899
# Iteration 92, loss = 0.02975893
# Iteration 93, loss = 0.02959285
# Iteration 94, loss = 0.02943033
# Iteration 95, loss = 0.02926663
# Iteration 96, loss = 0.02910325
# Iteration 97, loss = 0.02894649
# Iteration 98, loss = 0.02879415
# Iteration 99, loss = 0.02864056
# Iteration 100, loss = 0.02848625
# Iteration 101, loss = 0.02833722
# Iteration 102, loss = 0.02818743
# Iteration 103, loss = 0.02804180
# Iteration 104, loss = 0.02789572
# Iteration 105, loss = 0.02775060
# Iteration 106, loss = 0.02760734
# Iteration 107, loss = 0.02746528
# Iteration 108, loss = 0.02732930
# Iteration 109, loss = 0.02718638
# Iteration 110, loss = 0.02704711
# Iteration 111, loss = 0.02690633
# Iteration 112, loss = 0.02676765
# Iteration 113, loss = 0.02663250
# Iteration 114, loss = 0.02649561
# Iteration 115, loss = 0.02635963
# Iteration 116, loss = 0.02622445
# Iteration 117, loss = 0.02609140
# Iteration 118, loss = 0.02595649
# Iteration 119, loss = 0.02581805
# Iteration 120, loss = 0.02568658
# Iteration 121, loss = 0.02555216
# Iteration 122, loss = 0.02541818
# Iteration 123, loss = 0.02527949
# Iteration 124, loss = 0.02514738
# Iteration 125, loss = 0.02501422
# Iteration 126, loss = 0.02488168
# Iteration 127, loss = 0.02474414
# Iteration 128, loss = 0.02461347
# Iteration 129, loss = 0.02447757
# Iteration 130, loss = 0.02434094
# Iteration 131, loss = 0.02420563
# Iteration 132, loss = 0.02407014
# Iteration 133, loss = 0.02393393
# Iteration 134, loss = 0.02379706
# Iteration 135, loss = 0.02365743
# Iteration 136, loss = 0.02352021
# Iteration 137, loss = 0.02338252
# Iteration 138, loss = 0.02324375
# Iteration 139, loss = 0.02310452
# Iteration 140, loss = 0.02296481
# Iteration 141, loss = 0.02282536
# Iteration 142, loss = 0.02268505
# Iteration 143, loss = 0.02254313
# Iteration 144, loss = 0.02240614
# Iteration 145, loss = 0.02226831
# Iteration 146, loss = 0.02213173
# Iteration 147, loss = 0.02198560
# Iteration 148, loss = 0.02184257
# Iteration 149, loss = 0.02170624
# Iteration 150, loss = 0.02156753
# Iteration 151, loss = 0.02142246
# Iteration 152, loss = 0.02128629
# Iteration 153, loss = 0.02114641
# Iteration 154, loss = 0.02100540
# Iteration 155, loss = 0.02087121
# Iteration 156, loss = 0.02073314
# Iteration 157, loss = 0.02059805
# Iteration 158, loss = 0.02046222
# Iteration 159, loss = 0.02032970
# Iteration 160, loss = 0.02019467
# Iteration 161, loss = 0.02005907
# Iteration 162, loss = 0.01992542
# Iteration 163, loss = 0.01979331
# Iteration 164, loss = 0.01965949
# Iteration 165, loss = 0.01952351
# Iteration 166, loss = 0.01938897
# Iteration 167, loss = 0.01925728
# Iteration 168, loss = 0.01912565
# Iteration 169, loss = 0.01899428
# Iteration 170, loss = 0.01885940
# Iteration 171, loss = 0.01872744
# Iteration 172, loss = 0.01859593
# Iteration 173, loss = 0.01846356
# Iteration 174, loss = 0.01833534
# Iteration 175, loss = 0.01820296
# Iteration 176, loss = 0.01807213
# Iteration 177, loss = 0.01794610
# Iteration 178, loss = 0.01781979
# Iteration 179, loss = 0.01769242
# Iteration 180, loss = 0.01756620
# Iteration 181, loss = 0.01744065
# Iteration 182, loss = 0.01731221
# Iteration 183, loss = 0.01718587
# Iteration 184, loss = 0.01706401
# Iteration 185, loss = 0.01694052
# Iteration 186, loss = 0.01681392
# Iteration 187, loss = 0.01668981
# Iteration 188, loss = 0.01656400
# Iteration 189, loss = 0.01643888
# Iteration 190, loss = 0.01632237
# Iteration 191, loss = 0.01620487
# Iteration 192, loss = 0.01609126
# Iteration 193, loss = 0.01597619
# Iteration 194, loss = 0.01586325
# Iteration 195, loss = 0.01575245
# Iteration 196, loss = 0.01563630
# Iteration 197, loss = 0.01552549
# Iteration 198, loss = 0.01541085
# Iteration 199, loss = 0.01530114
# Iteration 200, loss = 0.01519522
# Iteration 201, loss = 0.01508472
# Iteration 202, loss = 0.01497194
# Iteration 203, loss = 0.01486527
# Iteration 204, loss = 0.01475742
# Iteration 205, loss = 0.01465051
# Iteration 206, loss = 0.01454658
# Iteration 207, loss = 0.01444399
# Iteration 208, loss = 0.01434230
# Iteration 209, loss = 0.01424117
# Iteration 210, loss = 0.01414065
# Iteration 211, loss = 0.01404288
# Iteration 212, loss = 0.01394661
# Iteration 213, loss = 0.01385116
# Iteration 214, loss = 0.01375874
# Iteration 215, loss = 0.01366177
# Iteration 216, loss = 0.01356761
# Iteration 217, loss = 0.01347870
# Iteration 218, loss = 0.01338698
# Iteration 219, loss = 0.01329404
# Iteration 220, loss = 0.01320461
# Iteration 221, loss = 0.01311743
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 4  R_U ...
# Iteration 1, loss = 0.03821643
# Iteration 2, loss = 0.03317828
# Iteration 3, loss = 0.02897660
# Iteration 4, loss = 0.02552863
# Iteration 5, loss = 0.02273115
# Iteration 6, loss = 0.02046375
# Iteration 7, loss = 0.01863331
# Iteration 8, loss = 0.01714049
# Iteration 9, loss = 0.01593649
# Iteration 10, loss = 0.01494475
# Iteration 11, loss = 0.01411997
# Iteration 12, loss = 0.01343435
# Iteration 13, loss = 0.01285989
# Iteration 14, loss = 0.01236974
# Iteration 15, loss = 0.01193840
# Iteration 16, loss = 0.01154426
# Iteration 17, loss = 0.01118392
# Iteration 18, loss = 0.01084912
# Iteration 19, loss = 0.01054512
# Iteration 20, loss = 0.01026041
# Iteration 21, loss = 0.00999303
# Iteration 22, loss = 0.00973996
# Iteration 23, loss = 0.00949731
# Iteration 24, loss = 0.00925646
# Iteration 25, loss = 0.00901854
# Iteration 26, loss = 0.00878758
# Iteration 27, loss = 0.00856203
# Iteration 28, loss = 0.00834155
# Iteration 29, loss = 0.00812113
# Iteration 30, loss = 0.00790181
# Iteration 31, loss = 0.00768621
# Iteration 32, loss = 0.00747651
# Iteration 33, loss = 0.00727347
# Iteration 34, loss = 0.00707854
# Iteration 35, loss = 0.00688847
# Iteration 36, loss = 0.00670421
# Iteration 37, loss = 0.00652472
# Iteration 38, loss = 0.00634777
# Iteration 39, loss = 0.00616860
# Iteration 40, loss = 0.00598842
# Iteration 41, loss = 0.00580787
# Iteration 42, loss = 0.00562611
# Iteration 43, loss = 0.00544417
# Iteration 44, loss = 0.00526357
# Iteration 45, loss = 0.00508386
# Iteration 46, loss = 0.00490686
# Iteration 47, loss = 0.00473346
# Iteration 48, loss = 0.00456327
# Iteration 49, loss = 0.00439541
# Iteration 50, loss = 0.00423036
# Iteration 51, loss = 0.00406849
# Iteration 52, loss = 0.00391168
# Iteration 53, loss = 0.00376188
# Iteration 54, loss = 0.00361942
# Iteration 55, loss = 0.00348334
# Iteration 56, loss = 0.00335573
# Iteration 57, loss = 0.00323692
# Iteration 58, loss = 0.00312176
# Iteration 59, loss = 0.00301046
# Iteration 60, loss = 0.00290653
# Iteration 61, loss = 0.00281230
# Iteration 62, loss = 0.00272642
# Iteration 63, loss = 0.00264859
# Iteration 64, loss = 0.00257788
# Iteration 65, loss = 0.00251300
# Iteration 66, loss = 0.00245264
# Iteration 67, loss = 0.00239522
# Iteration 68, loss = 0.00234111
# Iteration 69, loss = 0.00229028
# Iteration 70, loss = 0.00224243
# Iteration 71, loss = 0.00219752
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 4  R_D ...
# Iteration 1, loss = 0.04304180
# Iteration 2, loss = 0.03767022
# Iteration 3, loss = 0.03317638
# Iteration 4, loss = 0.02944686
# Iteration 5, loss = 0.02636305
# Iteration 6, loss = 0.02383251
# Iteration 7, loss = 0.02175673
# Iteration 8, loss = 0.02006068
# Iteration 9, loss = 0.01865220
# Iteration 10, loss = 0.01748941
# Iteration 11, loss = 0.01653629
# Iteration 12, loss = 0.01575509
# Iteration 13, loss = 0.01508214
# Iteration 14, loss = 0.01450560
# Iteration 15, loss = 0.01401172
# Iteration 16, loss = 0.01357542
# Iteration 17, loss = 0.01317979
# Iteration 18, loss = 0.01281875
# Iteration 19, loss = 0.01248835
# Iteration 20, loss = 0.01218533
# Iteration 21, loss = 0.01190546
# Iteration 22, loss = 0.01164830
# Iteration 23, loss = 0.01141335
# Iteration 24, loss = 0.01120212
# Iteration 25, loss = 0.01100508
# Iteration 26, loss = 0.01082099
# Iteration 27, loss = 0.01064739
# Iteration 28, loss = 0.01048324
# Iteration 29, loss = 0.01032918
# Iteration 30, loss = 0.01018189
# Iteration 31, loss = 0.01003624
# Iteration 32, loss = 0.00988684
# Iteration 33, loss = 0.00974583
# Iteration 34, loss = 0.00960788
# Iteration 35, loss = 0.00947177
# Iteration 36, loss = 0.00934048
# Iteration 37, loss = 0.00921508
# Iteration 38, loss = 0.00909257
# Iteration 39, loss = 0.00897754
# Iteration 40, loss = 0.00886640
# Iteration 41, loss = 0.00876109
# Iteration 42, loss = 0.00865871
# Iteration 43, loss = 0.00855741
# Iteration 44, loss = 0.00845486
# Iteration 45, loss = 0.00835556
# Iteration 46, loss = 0.00825499
# Iteration 47, loss = 0.00815615
# Iteration 48, loss = 0.00805828
# Iteration 49, loss = 0.00796173
# Iteration 50, loss = 0.00786689
# Iteration 51, loss = 0.00777357
# Iteration 52, loss = 0.00767914
# Iteration 53, loss = 0.00758404
# Iteration 54, loss = 0.00748897
# Iteration 55, loss = 0.00739367
# Iteration 56, loss = 0.00729472
# Iteration 57, loss = 0.00719158
# Iteration 58, loss = 0.00708470
# Iteration 59, loss = 0.00697727
# Iteration 60, loss = 0.00686897
# Iteration 61, loss = 0.00675899
# Iteration 62, loss = 0.00664788
# Iteration 63, loss = 0.00653502
# Iteration 64, loss = 0.00642219
# Iteration 65, loss = 0.00630801
# Iteration 66, loss = 0.00619381
# Iteration 67, loss = 0.00607692
# Iteration 68, loss = 0.00595908
# Iteration 69, loss = 0.00584127
# Iteration 70, loss = 0.00572319
# Iteration 71, loss = 0.00560589
# Iteration 72, loss = 0.00548880
# Iteration 73, loss = 0.00537235
# Iteration 74, loss = 0.00525888
# Iteration 75, loss = 0.00514587
# Iteration 76, loss = 0.00503583
# Iteration 77, loss = 0.00492679
# Iteration 78, loss = 0.00482055
# Iteration 79, loss = 0.00471634
# Iteration 80, loss = 0.00461957
# Iteration 81, loss = 0.00452283
# Iteration 82, loss = 0.00443203
# Iteration 83, loss = 0.00434531
# Iteration 84, loss = 0.00426091
# Iteration 85, loss = 0.00417770
# Iteration 86, loss = 0.00410094
# Iteration 87, loss = 0.00402659
# Iteration 88, loss = 0.00395652
# Iteration 89, loss = 0.00388877
# Iteration 90, loss = 0.00382335
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# training hour 5  P_c ...
# Iteration 1, loss = 0.12189932
# Iteration 2, loss = 0.11573798
# Iteration 3, loss = 0.11049697
# Iteration 4, loss = 0.10601701
# Iteration 5, loss = 0.10218738
# Iteration 6, loss = 0.09891745
# Iteration 7, loss = 0.09614072
# Iteration 8, loss = 0.09375365
# Iteration 9, loss = 0.09169009
# Iteration 10, loss = 0.08992622
# Iteration 11, loss = 0.08837198
# Iteration 12, loss = 0.08697155
# Iteration 13, loss = 0.08568369
# Iteration 14, loss = 0.08449699
# Iteration 15, loss = 0.08338567
# Iteration 16, loss = 0.08232817
# Iteration 17, loss = 0.08129616
# Iteration 18, loss = 0.08027940
# Iteration 19, loss = 0.07929092
# Iteration 20, loss = 0.07830575
# Iteration 21, loss = 0.07731866
# Iteration 22, loss = 0.07631909
# Iteration 23, loss = 0.07530550
# Iteration 24, loss = 0.07427551
# Iteration 25, loss = 0.07322513
# Iteration 26, loss = 0.07214339
# Iteration 27, loss = 0.07102141
# Iteration 28, loss = 0.06986850
# Iteration 29, loss = 0.06868948
# Iteration 30, loss = 0.06749041
# Iteration 31, loss = 0.06626787
# Iteration 32, loss = 0.06502479
# Iteration 33, loss = 0.06376279
# Iteration 34, loss = 0.06248371
# Iteration 35, loss = 0.06119455
# Iteration 36, loss = 0.05989322
# Iteration 37, loss = 0.05859949
# Iteration 38, loss = 0.05731842
# Iteration 39, loss = 0.05605524
# Iteration 40, loss = 0.05481919
# Iteration 41, loss = 0.05361251
# Iteration 42, loss = 0.05244932
# Iteration 43, loss = 0.05133655
# Iteration 44, loss = 0.05027927
# Iteration 45, loss = 0.04928107
# Iteration 46, loss = 0.04834262
# Iteration 47, loss = 0.04746906
# Iteration 48, loss = 0.04665498
# Iteration 49, loss = 0.04589615
# Iteration 50, loss = 0.04519108
# Iteration 51, loss = 0.04453064
# Iteration 52, loss = 0.04391062
# Iteration 53, loss = 0.04332403
# Iteration 54, loss = 0.04276754
# Iteration 55, loss = 0.04224204
# Iteration 56, loss = 0.04174214
# Iteration 57, loss = 0.04126664
# Iteration 58, loss = 0.04081713
# Iteration 59, loss = 0.04039401
# Iteration 60, loss = 0.03999991
# Iteration 61, loss = 0.03962362
# Iteration 62, loss = 0.03926401
# Iteration 63, loss = 0.03892516
# Iteration 64, loss = 0.03859366
# Iteration 65, loss = 0.03827021
# Iteration 66, loss = 0.03796076
# Iteration 67, loss = 0.03766119
# Iteration 68, loss = 0.03736924
# Iteration 69, loss = 0.03708291
# Iteration 70, loss = 0.03680578
# Iteration 71, loss = 0.03653424
# Iteration 72, loss = 0.03626417
# Iteration 73, loss = 0.03600239
# Iteration 74, loss = 0.03574754
# Iteration 75, loss = 0.03550641
# Iteration 76, loss = 0.03528123
# Iteration 77, loss = 0.03505368
# Iteration 78, loss = 0.03482413
# Iteration 79, loss = 0.03459906
# Iteration 80, loss = 0.03438096
# Iteration 81, loss = 0.03416719
# Iteration 82, loss = 0.03395456
# Iteration 83, loss = 0.03374931
# Iteration 84, loss = 0.03354220
# Iteration 85, loss = 0.03334460
# Iteration 86, loss = 0.03314828
# Iteration 87, loss = 0.03295454
# Iteration 88, loss = 0.03275881
# Iteration 89, loss = 0.03256140
# Iteration 90, loss = 0.03236696
# Iteration 91, loss = 0.03217424
# Iteration 92, loss = 0.03198158
# Iteration 93, loss = 0.03179121
# Iteration 94, loss = 0.03160413
# Iteration 95, loss = 0.03141486
# Iteration 96, loss = 0.03123550
# Iteration 97, loss = 0.03105512
# Iteration 98, loss = 0.03088018
# Iteration 99, loss = 0.03070880
# Iteration 100, loss = 0.03053754
# Iteration 101, loss = 0.03036623
# Iteration 102, loss = 0.03019354
# Iteration 103, loss = 0.03002279
# Iteration 104, loss = 0.02985345
# Iteration 105, loss = 0.02968405
# Iteration 106, loss = 0.02951503
# Iteration 107, loss = 0.02934449
# Iteration 108, loss = 0.02917846
# Iteration 109, loss = 0.02901468
# Iteration 110, loss = 0.02884619
# Iteration 111, loss = 0.02867864
# Iteration 112, loss = 0.02851011
# Iteration 113, loss = 0.02834317
# Iteration 114, loss = 0.02817795
# Iteration 115, loss = 0.02801068
# Iteration 116, loss = 0.02783996
# ...
# Iteration 101, loss = 0.02152015
# Iteration 102, loss = 0.02139535
# Iteration 103, loss = 0.02127550
# Iteration 104, loss = 0.02115629
# Iteration 105, loss = 0.02103714
# Iteration 106, loss = 0.02091648
# Iteration 107, loss = 0.02079732
# Iteration 108, loss = 0.02068347
# Iteration 109, loss = 0.02056806
# Iteration 110, loss = 0.02045398
# Iteration 111, loss = 0.02034125
# Iteration 112, loss = 0.02023325
# Iteration 113, loss = 0.02012231
# Iteration 114, loss = 0.02001241
# Iteration 115, loss = 0.01990597
# Iteration 116, loss = 0.01980267
# Iteration 117, loss = 0.01969722
# Iteration 118, loss = 0.01958807
# Iteration 119, loss = 0.01948412
# Iteration 120, loss = 0.01938438
# Iteration 121, loss = 0.01928149
# Iteration 122, loss = 0.01918068
# Iteration 123, loss = 0.01907974
# Iteration 124, loss = 0.01897880
# Iteration 125, loss = 0.01887642
# Iteration 126, loss = 0.01877747
# Iteration 127, loss = 0.01868312
# Iteration 128, loss = 0.01858437
# Iteration 129, loss = 0.01848732
# Iteration 130, loss = 0.01839172
# Iteration 131, loss = 0.01829492
# Iteration 132, loss = 0.01819931
# Iteration 133, loss = 0.01810463
# Iteration 134, loss = 0.01801013
# Iteration 135, loss = 0.01791214
# Iteration 136, loss = 0.01781515
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 23  R_U ...
# Iteration 1, loss = 0.03902333
# Iteration 2, loss = 0.03388450
# Iteration 3, loss = 0.02962487
# Iteration 4, loss = 0.02613550
# Iteration 5, loss = 0.02330707
# Iteration 6, loss = 0.02101448
# Iteration 7, loss = 0.01914766
# Iteration 8, loss = 0.01764208
# Iteration 9, loss = 0.01642979
# Iteration 10, loss = 0.01543804
# Iteration 11, loss = 0.01462782
# Iteration 12, loss = 0.01396097
# Iteration 13, loss = 0.01340600
# Iteration 14, loss = 0.01292537
# Iteration 15, loss = 0.01250422
# Iteration 16, loss = 0.01212451
# Iteration 17, loss = 0.01177999
# Iteration 18, loss = 0.01146644
# Iteration 19, loss = 0.01117712
# Iteration 20, loss = 0.01090959
# Iteration 21, loss = 0.01066163
# Iteration 22, loss = 0.01043273
# Iteration 23, loss = 0.01022029
# Iteration 24, loss = 0.01001521
# Iteration 25, loss = 0.00981536
# Iteration 26, loss = 0.00962259
# Iteration 27, loss = 0.00943489
# Iteration 28, loss = 0.00925161
# Iteration 29, loss = 0.00907403
# Iteration 30, loss = 0.00890202
# Iteration 31, loss = 0.00873597
# Iteration 32, loss = 0.00857578
# Iteration 33, loss = 0.00842014
# Iteration 34, loss = 0.00826567
# Iteration 35, loss = 0.00811398
# Iteration 36, loss = 0.00796545
# Iteration 37, loss = 0.00782050
# Iteration 38, loss = 0.00767856
# Iteration 39, loss = 0.00753860
# Iteration 40, loss = 0.00740039
# Iteration 41, loss = 0.00726526
# Iteration 42, loss = 0.00713294
# Iteration 43, loss = 0.00700360
# Iteration 44, loss = 0.00687622
# Iteration 45, loss = 0.00675059
# Iteration 46, loss = 0.00662639
# Iteration 47, loss = 0.00650317
# Iteration 48, loss = 0.00638072
# Iteration 49, loss = 0.00625986
# Iteration 50, loss = 0.00613981
# Iteration 51, loss = 0.00602013
# Iteration 52, loss = 0.00590049
# Iteration 53, loss = 0.00578311
# Iteration 54, loss = 0.00566607
# Iteration 55, loss = 0.00555011
# Iteration 56, loss = 0.00543767
# Iteration 57, loss = 0.00532567
# Iteration 58, loss = 0.00521496
# Iteration 59, loss = 0.00510937
# Iteration 60, loss = 0.00500690
# Iteration 61, loss = 0.00490697
# Iteration 62, loss = 0.00480778
# Iteration 63, loss = 0.00470993
# Iteration 64, loss = 0.00461503
# Iteration 65, loss = 0.00452339
# Iteration 66, loss = 0.00443353
# Iteration 67, loss = 0.00434894
# Iteration 68, loss = 0.00426806
# Iteration 69, loss = 0.00419072
# Iteration 70, loss = 0.00411769
# Iteration 71, loss = 0.00404713
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 23  R_D ...
# Iteration 1, loss = 0.03290115
# Iteration 2, loss = 0.02767715
# Iteration 3, loss = 0.02333452
# Iteration 4, loss = 0.01976258
# Iteration 5, loss = 0.01685410
# Iteration 6, loss = 0.01449170
# Iteration 7, loss = 0.01256359
# Iteration 8, loss = 0.01099469
# Iteration 9, loss = 0.00972597
# Iteration 10, loss = 0.00869679
# Iteration 11, loss = 0.00786292
# Iteration 12, loss = 0.00718662
# Iteration 13, loss = 0.00663109
# Iteration 14, loss = 0.00616328
# Iteration 15, loss = 0.00575740
# Iteration 16, loss = 0.00539993
# Iteration 17, loss = 0.00507627
# Iteration 18, loss = 0.00477891
# Iteration 19, loss = 0.00450693
# Iteration 20, loss = 0.00425730
# Iteration 21, loss = 0.00402862
# Iteration 22, loss = 0.00381749
# Iteration 23, loss = 0.00362207
# Iteration 24, loss = 0.00344405
# Iteration 25, loss = 0.00328049
# Iteration 26, loss = 0.00312790
# Iteration 27, loss = 0.00298511
# Iteration 28, loss = 0.00285054
# Iteration 29, loss = 0.00272321
# Iteration 30, loss = 0.00260249
# Iteration 31, loss = 0.00248808
# Iteration 32, loss = 0.00238205
# Iteration 33, loss = 0.00228232
# Iteration 34, loss = 0.00218756
# Iteration 35, loss = 0.00209666
# Iteration 36, loss = 0.00200899
# Iteration 37, loss = 0.00192478
# Iteration 38, loss = 0.00184365
# Iteration 39, loss = 0.00176624
# Iteration 40, loss = 0.00169307
# Iteration 41, loss = 0.00162405
# Iteration 42, loss = 0.00155874
# Iteration 43, loss = 0.00149683
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# training hour 24  P_c ...
# Iteration 1, loss = 0.10955543
# Iteration 2, loss = 0.10342979
# Iteration 3, loss = 0.09821305
# Iteration 4, loss = 0.09375981
# Iteration 5, loss = 0.08997975
# Iteration 6, loss = 0.08675524
# Iteration 7, loss = 0.08401056
# Iteration 8, loss = 0.08170042
# Iteration 9, loss = 0.07976922
# Iteration 10, loss = 0.07809604
# Iteration 11, loss = 0.07664779
# Iteration 12, loss = 0.07537482
# Iteration 13, loss = 0.07424067
# Iteration 14, loss = 0.07320754
# Iteration 15, loss = 0.07223918
# Iteration 16, loss = 0.07130817
# Iteration 17, loss = 0.07040530
# Iteration 18, loss = 0.06952845
# Iteration 19, loss = 0.06865758
# Iteration 20, loss = 0.06779943
# Iteration 21, loss = 0.06694119
# Iteration 22, loss = 0.06608475
# Iteration 23, loss = 0.06523453
# Iteration 24, loss = 0.06437766
# Iteration 25, loss = 0.06349749
# Iteration 26, loss = 0.06259063
# Iteration 27, loss = 0.06167139
# Iteration 28, loss = 0.06073329
# Iteration 29, loss = 0.05977327
# Iteration 30, loss = 0.05878969
# Iteration 31, loss = 0.05778191
# Iteration 32, loss = 0.05675157
# Iteration 33, loss = 0.05570061
# Iteration 34, loss = 0.05463082
# Iteration 35, loss = 0.05354512
# Iteration 36, loss = 0.05244705
# Iteration 37, loss = 0.05133919
# Iteration 38, loss = 0.05022878
# Iteration 39, loss = 0.04912426
# Iteration 40, loss = 0.04803091
# Iteration 41, loss = 0.04695485
# Iteration 42, loss = 0.04590097
# Iteration 43, loss = 0.04487794
# Iteration 44, loss = 0.04389060
# Iteration 45, loss = 0.04294387
# Iteration 46, loss = 0.04203256
# Iteration 47, loss = 0.04116579
# Iteration 48, loss = 0.04034511
# Iteration 49, loss = 0.03957309
# Iteration 50, loss = 0.03884830
# Iteration 51, loss = 0.03817027
# Iteration 52, loss = 0.03753363
# Iteration 53, loss = 0.03693565
# Iteration 54, loss = 0.03637397
# Iteration 55, loss = 0.03584971
# Iteration 56, loss = 0.03535368
# Iteration 57, loss = 0.03488708
# Iteration 58, loss = 0.03444868
# Iteration 59, loss = 0.03403088
# Iteration 60, loss = 0.03363304
# Iteration 61, loss = 0.03325153
# Iteration 62, loss = 0.03288538
# Iteration 63, loss = 0.03253579
# Iteration 64, loss = 0.03220128
# Iteration 65, loss = 0.03187898
# Iteration 66, loss = 0.03156696
# Iteration 67, loss = 0.03126168
# Iteration 68, loss = 0.03096584
# Iteration 69, loss = 0.03067712
# Iteration 70, loss = 0.03040060
# Iteration 71, loss = 0.03012759
# Iteration 72, loss = 0.02986386
# Iteration 73, loss = 0.02961441
# Iteration 74, loss = 0.02937063
# Iteration 75, loss = 0.02912551
# Iteration 76, loss = 0.02888538
# Iteration 77, loss = 0.02865026
# Iteration 78, loss = 0.02841817
# Iteration 79, loss = 0.02819441
# Iteration 80, loss = 0.02797775
# Iteration 81, loss = 0.02776567
# Iteration 82, loss = 0.02756140
# Iteration 83, loss = 0.02736390
# Iteration 84, loss = 0.02716922
# Iteration 85, loss = 0.02698045
# Iteration 86, loss = 0.02679477
# Iteration 87, loss = 0.02661295
# Iteration 88, loss = 0.02643718
# Iteration 89, loss = 0.02625908
# Iteration 90, loss = 0.02608173
# Iteration 91, loss = 0.02591082
# Iteration 92, loss = 0.02574421
# Iteration 93, loss = 0.02557730
# Iteration 94, loss = 0.02541551
# Iteration 95, loss = 0.02525626
# Iteration 96, loss = 0.02510140
# Iteration 97, loss = 0.02494672
# Iteration 98, loss = 0.02479416
# Iteration 99, loss = 0.02464581
# Iteration 100, loss = 0.02449959
# Iteration 101, loss = 0.02435695
# Iteration 102, loss = 0.02421185
# Iteration 103, loss = 0.02406911
# Iteration 104, loss = 0.02393131
# Iteration 105, loss = 0.02379281
# Iteration 106, loss = 0.02365353
# Iteration 107, loss = 0.02351741
# Iteration 108, loss = 0.02338069
# Iteration 109, loss = 0.02324232
# Iteration 110, loss = 0.02311044
# Iteration 111, loss = 0.02297810
# Iteration 112, loss = 0.02284482
# Iteration 113, loss = 0.02271393
# Iteration 114, loss = 0.02258275
# Iteration 115, loss = 0.02245676
# Iteration 116, loss = 0.02232778
# Iteration 117, loss = 0.02219745
# Iteration 118, loss = 0.02206947
# Iteration 119, loss = 0.02194347
# Iteration 120, loss = 0.02181440
# Iteration 121, loss = 0.02168807
# Iteration 122, loss = 0.02156042
# Iteration 123, loss = 0.02143560
# Iteration 124, loss = 0.02130952
# Iteration 125, loss = 0.02118258
# Iteration 126, loss = 0.02105663
# Iteration 127, loss = 0.02093068
# Iteration 128, loss = 0.02080246
# Iteration 129, loss = 0.02067586
# Iteration 130, loss = 0.02055129
# Iteration 131, loss = 0.02042732
# Iteration 132, loss = 0.02029809
# Iteration 133, loss = 0.02017376
# Iteration 134, loss = 0.02005032
# Iteration 135, loss = 0.01992641
# Iteration 136, loss = 0.01979767
# Iteration 137, loss = 0.01967083
# Iteration 138, loss = 0.01954684
# Iteration 139, loss = 0.01942134
# Iteration 140, loss = 0.01929491
# Iteration 141, loss = 0.01917378
# Iteration 142, loss = 0.01904792
# Iteration 143, loss = 0.01892132
# Iteration 144, loss = 0.01879632
# Iteration 145, loss = 0.01867183
# Iteration 146, loss = 0.01855115
# Iteration 147, loss = 0.01842936
# Iteration 148, loss = 0.01830876
# Iteration 149, loss = 0.01818421
# Iteration 150, loss = 0.01806553
# Iteration 151, loss = 0.01794557
# Iteration 152, loss = 0.01782065
# Iteration 153, loss = 0.01770237
# Iteration 154, loss = 0.01757875
# Iteration 155, loss = 0.01745965
# Iteration 156, loss = 0.01734138
# Iteration 157, loss = 0.01722194
# Iteration 158, loss = 0.01709986
# Iteration 159, loss = 0.01697818
# Iteration 160, loss = 0.01686088
# Iteration 161, loss = 0.01673937
# Iteration 162, loss = 0.01662334
# Iteration 163, loss = 0.01650424
# Iteration 164, loss = 0.01638254
# Iteration 165, loss = 0.01626565
# Iteration 166, loss = 0.01614884
# Iteration 167, loss = 0.01603452
# Iteration 168, loss = 0.01591713
# Iteration 169, loss = 0.01579936
# Iteration 170, loss = 0.01568178
# Iteration 171, loss = 0.01556685
# Iteration 172, loss = 0.01545796
# Iteration 173, loss = 0.01534770
# Iteration 174, loss = 0.01523257
# Iteration 175, loss = 0.01512005
# Iteration 176, loss = 0.01500374
# Iteration 177, loss = 0.01489391
# Iteration 178, loss = 0.01478442
# Iteration 179, loss = 0.01467560
# Iteration 180, loss = 0.01456403
# Iteration 181, loss = 0.01445102
# Iteration 182, loss = 0.01434409
# Iteration 183, loss = 0.01423453
# Iteration 184, loss = 0.01413005
# Iteration 185, loss = 0.01402197
# Iteration 186, loss = 0.01391313
# Iteration 187, loss = 0.01380897
# Iteration 188, loss = 0.01370365
# Iteration 189, loss = 0.01360080
# Iteration 190, loss = 0.01349703
# Iteration 191, loss = 0.01339723
# Iteration 192, loss = 0.01328805
# Iteration 193, loss = 0.01319482
# Iteration 194, loss = 0.01309425
# Iteration 195, loss = 0.01298932
# Iteration 196, loss = 0.01289190
# Iteration 197, loss = 0.01279580
# Iteration 198, loss = 0.01269547
# Iteration 199, loss = 0.01259894
# Iteration 200, loss = 0.01250161
# Iteration 201, loss = 0.01240451
# Iteration 202, loss = 0.01230824
# Iteration 203, loss = 0.01221265
# Iteration 204, loss = 0.01211658
# Iteration 205, loss = 0.01202274
# Iteration 206, loss = 0.01193075
# Iteration 207, loss = 0.01183856
# Iteration 208, loss = 0.01174762
# Iteration 209, loss = 0.01165811
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 24  R_U ...
# Iteration 1, loss = 0.03849818
# Iteration 2, loss = 0.03339148
# Iteration 3, loss = 0.02915687
# Iteration 4, loss = 0.02569093
# Iteration 5, loss = 0.02287879
# Iteration 6, loss = 0.02060314
# Iteration 7, loss = 0.01873495
# Iteration 8, loss = 0.01721910
# Iteration 9, loss = 0.01599342
# Iteration 10, loss = 0.01499262
# Iteration 11, loss = 0.01416727
# Iteration 12, loss = 0.01347951
# Iteration 13, loss = 0.01290051
# Iteration 14, loss = 0.01240423
# Iteration 15, loss = 0.01196741
# Iteration 16, loss = 0.01157862
# Iteration 17, loss = 0.01122617
# Iteration 18, loss = 0.01090729
# Iteration 19, loss = 0.01061055
# Iteration 20, loss = 0.01033173
# Iteration 21, loss = 0.01006908
# Iteration 22, loss = 0.00982337
# Iteration 23, loss = 0.00958903
# Iteration 24, loss = 0.00935643
# Iteration 25, loss = 0.00912078
# Iteration 26, loss = 0.00888454
# Iteration 27, loss = 0.00865379
# Iteration 28, loss = 0.00842899
# Iteration 29, loss = 0.00820884
# Iteration 30, loss = 0.00799635
# Iteration 31, loss = 0.00778808
# Iteration 32, loss = 0.00757974
# Iteration 33, loss = 0.00737711
# Iteration 34, loss = 0.00718049
# Iteration 35, loss = 0.00698599
# Iteration 36, loss = 0.00679418
# Iteration 37, loss = 0.00660766
# Iteration 38, loss = 0.00642390
# Iteration 39, loss = 0.00624200
# Iteration 40, loss = 0.00606138
# Iteration 41, loss = 0.00588218
# Iteration 42, loss = 0.00570412
# Iteration 43, loss = 0.00552729
# Iteration 44, loss = 0.00535156
# Iteration 45, loss = 0.00517585
# Iteration 46, loss = 0.00500147
# Iteration 47, loss = 0.00482970
# Iteration 48, loss = 0.00466195
# Iteration 49, loss = 0.00449901
# Iteration 50, loss = 0.00433851
# Iteration 51, loss = 0.00418261
# Iteration 52, loss = 0.00403167
# Iteration 53, loss = 0.00388411
# Iteration 54, loss = 0.00373987
# Iteration 55, loss = 0.00359841
# Iteration 56, loss = 0.00346044
# Iteration 57, loss = 0.00332846
# Iteration 58, loss = 0.00320413
# Iteration 59, loss = 0.00308719
# Iteration 60, loss = 0.00297727
# Iteration 61, loss = 0.00287252
# Iteration 62, loss = 0.00277204
# Iteration 63, loss = 0.00267708
# Iteration 64, loss = 0.00258836
# Iteration 65, loss = 0.00250581
# Iteration 66, loss = 0.00242975
# Iteration 67, loss = 0.00235906
# Iteration 68, loss = 0.00229303
# Iteration 69, loss = 0.00223131
# Iteration 70, loss = 0.00217322
# Iteration 71, loss = 0.00211861
# Iteration 72, loss = 0.00206724
# Iteration 73, loss = 0.00201910
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# traing hour 24  R_D ...
# Iteration 1, loss = 0.03295421
# Iteration 2, loss = 0.02775048
# Iteration 3, loss = 0.02342259
# Iteration 4, loss = 0.01986036
# Iteration 5, loss = 0.01695881
# Iteration 6, loss = 0.01460079
# Iteration 7, loss = 0.01267730
# Iteration 8, loss = 0.01110048
# Iteration 9, loss = 0.00982126
# Iteration 10, loss = 0.00877897
# Iteration 11, loss = 0.00793011
# Iteration 12, loss = 0.00724028
# Iteration 13, loss = 0.00667098
# Iteration 14, loss = 0.00619193
# Iteration 15, loss = 0.00578172
# Iteration 16, loss = 0.00542065
# Iteration 17, loss = 0.00509531
# Iteration 18, loss = 0.00479773
# Iteration 19, loss = 0.00452398
# Iteration 20, loss = 0.00427284
# Iteration 21, loss = 0.00404148
# Iteration 22, loss = 0.00383001
# Iteration 23, loss = 0.00363548
# Iteration 24, loss = 0.00345386
# Iteration 25, loss = 0.00328621
# Iteration 26, loss = 0.00313077
# Iteration 27, loss = 0.00298560
# Iteration 28, loss = 0.00285087
# Iteration 29, loss = 0.00272340
# Iteration 30, loss = 0.00260172
# Iteration 31, loss = 0.00248519
# Iteration 32, loss = 0.00237529
# Iteration 33, loss = 0.00227196
# Iteration 34, loss = 0.00217672
# Iteration 35, loss = 0.00208644
# Iteration 36, loss = 0.00200039
# Iteration 37, loss = 0.00191739
# Iteration 38, loss = 0.00183646
# Iteration 39, loss = 0.00175774
# Iteration 40, loss = 0.00168133
# Iteration 41, loss = 0.00160850
# Iteration 42, loss = 0.00153998
# Iteration 43, loss = 0.00147611
# Iteration 44, loss = 0.00141670
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
import os
import pandas as pd
import joblib
import numpy as np


test_split_dir = './test_split'  
model_output_dir = './hourly_models_scaler'  
scaler_output_dir = './hourly_scalers'  
results_output_dir = './test_results_scaler'  


os.makedirs(results_output_dir, exist_ok=True)


for hour in range(1, 25):
    
    X_test_file = os.path.join(test_split_dir, f'X_test_hour_{hour}.csv')
    if not os.path.exists(X_test_file):
        print(f"file {X_test_file} not exist, skip")
        continue
    X_test = pd.read_csv(X_test_file)
    
    
    model_P_c_file = os.path.join(model_output_dir, f'model_P_c_hour_{hour}.pkl')
    model_R_U_file = os.path.join(model_output_dir, f'model_R_U_hour_{hour}.pkl')
    model_R_D_file = os.path.join(model_output_dir, f'model_R_D_hour_{hour}.pkl')
    
    if not os.path.exists(model_P_c_file) or not os.path.exists(model_R_U_file) or not os.path.exists(model_R_D_file):
        print(f"hour {hour} skip")
        continue
    
    model_P_c = joblib.load(model_P_c_file)
    model_R_U = joblib.load(model_R_U_file)
    model_R_D = joblib.load(model_R_D_file)
    
    
    scaler_X_file = os.path.join(scaler_output_dir, f'scaler_X_hour_{hour}.pkl')
    scaler_P_c_file = os.path.join(scaler_output_dir, f'scaler_P_c_hour_{hour}.pkl')
    scaler_R_U_file = os.path.join(scaler_output_dir, f'scaler_R_U_hour_{hour}.pkl')
    scaler_R_D_file = os.path.join(scaler_output_dir, f'scaler_R_D_hour_{hour}.pkl')
    
    if not os.path.exists(scaler_X_file) or not os.path.exists(scaler_P_c_file) or not os.path.exists(scaler_R_U_file) or not os.path.exists(scaler_R_D_file):
        print(f"hour {hour} skip")
        continue
    
    scaler_X = joblib.load(scaler_X_file)
    scaler_P_c = joblib.load(scaler_P_c_file)
    scaler_R_U = joblib.load(scaler_R_U_file)
    scaler_R_D = joblib.load(scaler_R_D_file)
    
    
    X_test_scaled = scaler_X.transform(X_test)
    
 
    P_c_pred_scaled = model_P_c.predict(X_test_scaled)
    R_U_pred_scaled = model_R_U.predict(X_test_scaled)
    R_D_pred_scaled = model_R_D.predict(X_test_scaled)
    
    
    P_c_pred = scaler_P_c.inverse_transform(P_c_pred_scaled)
    R_U_pred = scaler_R_U.inverse_transform(R_U_pred_scaled)
    R_D_pred = scaler_R_D.inverse_transform(R_D_pred_scaled)
    
   
    results = pd.DataFrame({
        'P_c_pred': list(P_c_pred),
        'R_U_pred': list(R_U_pred),
        'R_D_pred': list(R_D_pred)
    })
    
  
    results_file = os.path.join(results_output_dir, f'test_results_hour_{hour}.csv')
    results.to_csv(results_file, index=False)

# %%
import pandas as pd
import os
import numpy as np


test_results_dir = './test_results_scaler'  
nodes_data_file = './118nodes_system.xlsx'  


unit_data = pd.read_excel(nodes_data_file, sheet_name='unit')


R_U_max = unit_data['Upward reserve capacity offer [MW]'].values.astype(float)  
R_D_max = unit_data['Downward reserve capacity offer [MW]'].values.astype(float)  


for hour in range(1, 25):
    
    results_file = os.path.join(test_results_dir, f'test_results_hour_{hour}.csv')
    if not os.path.exists(results_file):
        print(f"file {results_file} not exist")
        continue
    results = pd.read_csv(results_file)
    
    
    results['P_c_pred'] = results['P_c_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
    results['R_U_pred'] = results['R_U_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
    results['R_D_pred'] = results['R_D_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
    
    
    results['R_U_pred'] = results['R_U_pred'].apply(lambda x: np.minimum(x, R_U_max))  
    results['R_U_pred'] = results['R_U_pred'].apply(lambda x: np.maximum(x, 0))  
    results['R_D_pred'] = results['R_D_pred'].apply(lambda x: np.minimum(x, R_D_max))  
    results['R_D_pred'] = results['R_D_pred'].apply(lambda x: np.maximum(x, 0))  

    
    results['R_U_pred'] = results['R_U_pred'].apply(lambda x: x * 150 / np.sum(x) if np.sum(x) != 0 else x)
    results['R_D_pred'] = results['R_D_pred'].apply(lambda x: x * 150 / np.sum(x) if np.sum(x) != 0 else x)
    
    
    results.to_csv(os.path.join(test_results_dir, f'test_results_hour_{hour}_processed.csv'), index=False)

# %%
import pandas as pd
import os
import numpy as np


test_results_dir = './test_results_scaler'
nodes_data_file = './118nodes_system.xlsx' 


unit_data = pd.read_excel(nodes_data_file, sheet_name='unit')


P_max = unit_data['Installed capacity [MW]'].values.astype(float)
R_U_max = unit_data['Upward reserve capacity offer [MW]'].values.astype(float) 
R_D_max = unit_data['Downward reserve capacity offer [MW]'].values.astype(float) 


for hour in range(1, 25):
    
    results_file = os.path.join(test_results_dir, f'test_results_hour_{hour}_processed.csv')
    if not os.path.exists(results_file):
        print(f"file {results_file} not exist")
        continue
    results = pd.read_csv(results_file)

    
    results['P_c_pred'] = results['P_c_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
    results['R_U_pred'] = results['R_U_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
    results['R_D_pred'] = results['R_D_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))

    
    for i in range(len(results)):
        P_c_pred = results['P_c_pred'].iloc[i].copy()  
        R_U_pred = results['R_U_pred'].iloc[i]  
        R_D_pred = results['R_D_pred'].iloc[i] 

       
        for j in range(118): 
            P_c_pred[j] = min(P_c_pred[j], P_max[j] - R_U_pred[j])  
            P_c_pred[j] = max(P_c_pred[j], 0) 

        
        results.at[i, 'P_c_pred'] = P_c_pred

    
    results.to_csv(os.path.join(test_results_dir, f'test_results_hour_{hour}_final.csv'), index=False)

# %%
import pandas as pd
import os
import numpy as np

def combine_and_sort_predictions(test_results_dir, test_splits_dir):

   
    all_p_c = []
    all_r_u = []
    all_r_d = []
    all_trends = []

    
    for hour in range(1, 25):
        
        results_file = os.path.join(test_results_dir, f'test_results_hour_{hour}_final.csv')
        if not os.path.exists(results_file):
            print(f"file {results_file} not exist")
            continue
        results_df = pd.read_csv(results_file)
        
        
        X_test_file = os.path.join(test_splits_dir, f'X_test_hour_{hour}.csv')
        if not os.path.exists(X_test_file):
            print(f"file {results_file} not exist")
            continue
        X_test = pd.read_csv(X_test_file)
        
        
        results_df['P_c_pred'] = results_df['P_c_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
        results_df['R_U_pred'] = results_df['R_U_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
        results_df['R_D_pred'] = results_df['R_D_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
        
       
        p_c = np.vstack(results_df['P_c_pred'].values)
        r_u = np.vstack(results_df['R_U_pred'].values)
        r_d = np.vstack(results_df['R_D_pred'].values)
        
        
        trend = X_test['trend'].values
        
       
        all_p_c.append(p_c)
        all_r_u.append(r_u)
        all_r_d.append(r_d)
        all_trends.append(trend)

    
    all_p_c = np.vstack(all_p_c)
    all_r_u = np.vstack(all_r_u)
    all_r_d = np.vstack(all_r_d)
    all_trends = np.concatenate(all_trends)

    
    sorted_indices = np.argsort(all_trends)
    sorted_p_c = all_p_c[sorted_indices]
    sorted_r_u = all_r_u[sorted_indices]
    sorted_r_d = all_r_d[sorted_indices]
    sorted_trends = all_trends[sorted_indices]

    
    test_results = pd.DataFrame({
        'P_c_pred': [str(row) for row in sorted_p_c],
        'R_U_pred': [str(row) for row in sorted_r_u],
        'R_D_pred': [str(row) for row in sorted_r_d],
        'trend': sorted_trends
    })

    return test_results


test_results_dir = './test_results_scaler'  
test_splits_dir = './test_split'  


test_results = combine_and_sort_predictions(test_results_dir, test_splits_dir)


test_results.to_csv(os.path.join(test_results_dir, 'test_results_combined.csv'), index=False)

# %%
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB

def load_da_results(filename='./test_results_scaler/test_results_combined.csv'):

    da_results = pd.read_csv(filename)
    
    da_results['P_c_pred'] = da_results['P_c_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
    da_results['R_U_pred'] = da_results['R_U_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
    da_results['R_D_pred'] = da_results['R_D_pred'].apply(lambda x: np.fromstring(x[1:-1], sep=' '))
    return da_results

def calculate_obj_DA(da_results, unit, time_steps, nodes):
    
    obj_DA = 0
    for k in range(time_steps):
        for i in range(nodes):
            P_c = da_results['P_c_pred'].iloc[k][i]
            R_U = da_results['R_U_pred'].iloc[k][i]
            R_D = da_results['R_D_pred'].iloc[k][i]
            obj_DA += P_c * unit.iloc[i, 2] + R_U * unit.iloc[i, 5] + R_D * unit.iloc[i, 6]

    return obj_DA

def save_optimization_results(model_RT, time_steps, nodes, filename='optimization_results_scaler.csv'):
  
    rt_results = []
    for k in range(time_steps):
        for i in range(nodes):
            rt_results.append([
                'RT', k, i,
                model_RT.getVarByName(f'r_U[{i},{k}]').X,
                model_RT.getVarByName(f'r_D[{i},{k}]').X,
                model_RT.getVarByName(f'P_lsh[{i},{k}]').X,
                model_RT.getVarByName(f'delta_RT[{i},{k}]').X,
                model_RT.getVarByName(f's[{i},{k}]').X
            ])
    rt_columns = ['Stage', 'TimeStep', 'Node', 'r_U', 'r_D', 'P_lsh', 'delta_RT', 's']
    df_rt = pd.DataFrame(rt_results, columns=rt_columns)
    df_rt.to_csv(filename, index=False)

def calculate_optimization_cost_two_stage(Y_real, topo, unit, ratio_bus, reserve_up=150, reserve_down=150, c=9000, c_s=1750):
    

    da_results = load_da_results()
    nodes = topo.shape[0]
    time_steps = Y_real.shape[0]


    obj_DA = calculate_obj_DA(da_results, unit, time_steps, nodes)
    print(f"day_ahead cost: {obj_DA}")

    Y_real_allocated = allocate_data_to_nodes(Y_real, ratio_bus).T

    model_RT = gp.Model()
    r_U = model_RT.addVars(nodes, time_steps, lb=0, name='r_U')
    r_D = model_RT.addVars(nodes, time_steps, lb=0, name='r_D')
    P_lsh = model_RT.addVars(nodes, time_steps, lb=0, name='P_lsh')  
    delta_RT = model_RT.addVars(nodes, time_steps, lb=-180, ub=180, name='delta_RT')
    s = model_RT.addVars(nodes, time_steps, lb=0, name='s')  

    
    obj_RT = gp.quicksum(
        (r_U[i, j] - r_D[i, j]) * unit.iloc[i, 2]
        for i in range(nodes) for j in range(time_steps)
    )
    obj_RT += gp.quicksum(P_lsh[i, j] * c for i in range(nodes) for j in range(time_steps))
    obj_RT += gp.quicksum(s[i, j] * c_s for i in range(nodes) for j in range(time_steps))
    model_RT.setObjective(obj_RT, GRB.MINIMIZE)

  
    for k in range(time_steps):
      
        for t in range(nodes):
            model_RT.addConstr(
                r_U[t, k] - r_D[t, k] - s[t, k] - Y_real_allocated[t, k] + P_lsh[t, k] -
                gp.quicksum(
                    topo.iloc[t, j] * (delta_RT[t, k] - delta_RT[j, k])
                    for j in range(nodes))
                + da_results['P_c_pred'].iloc[k][t] 
                == 0
            )
       
        for i in range(nodes):
            model_RT.addConstr(r_U[i, k] <= da_results['R_U_pred'].iloc[k][i])  
            model_RT.addConstr(r_D[i, k] <= da_results['R_D_pred'].iloc[k][i])  
        model_RT.addConstr(delta_RT[0, k] == 0) 
        
        for i in range(nodes):
            for j in range(nodes):
                if i != j and topo.iloc[i, j] < -0.01:
                    model_RT.addConstr(topo.iloc[i, j] * (delta_RT[i, k] - delta_RT[j, k]) <= 175)
                    model_RT.addConstr(topo.iloc[i, j] * (delta_RT[i, k] - delta_RT[j, k]) >= -175)

    model_RT.optimize()

    total_cost = obj_DA + model_RT.ObjVal
    print(f"total cost: {total_cost}")

    save_optimization_results(model_RT, time_steps, nodes, 'optimization_results_scaler.csv')
    return total_cost


def allocate_data_to_nodes(data, ratio_bus):
    
    allocated_data = np.zeros((data.shape[0], 118))
    for i in range(data.shape[0]):
        allocated_data[i, :] = float(data[i]) * ratio_bus
    return allocated_data


if __name__ == "__main__":
    Y_real = pd.read_csv('Y_test.csv').values.flatten()

    topo = pd.read_excel('118nodes_system.xlsx', sheet_name='topology', index_col=None, header=None)
    unit = pd.read_excel('118nodes_system.xlsx', sheet_name='unit')

    mpc_bus = [
        [1, 51], [2, 20], [3, 39], [4, 39], [5, 0], [6, 52], [7, 19], [8, 28], [9, 0], [10, 0],
        [11, 70], [12, 47], [13, 34], [14, 14], [15, 90], [16, 25], [17, 11], [18, 60], [19, 45], [20, 18],
        [21, 14], [22, 10], [23, 7], [24, 13], [25, 0], [26, 0], [27, 71], [28, 17], [29, 24], [30, 0],
        [31, 43], [32, 59], [33, 23], [34, 59], [35, 33], [36, 31], [37, 0], [38, 0], [39, 27], [40, 66],
        [41, 37], [42, 96], [43, 18], [44, 16], [45, 53], [46, 28], [47, 34], [48, 20], [49, 87], [50, 17],
        [51, 17], [52, 18], [53, 23], [54, 113], [55, 63], [56, 84], [57, 12], [58, 12], [59, 277], [60, 78],
        [61, 0], [62, 77], [63, 0], [64, 0], [65, 0], [66, 39], [67, 28], [68, 0], [69, 0], [70, 66],
        [71, 0], [72, 12], [73, 6], [74, 68], [75, 47], [76, 68], [77, 61], [78, 71], [79, 39], [80, 130],
        [81, 0], [82, 54], [83, 20], [84, 11], [85, 24], [86, 21], [87, 0], [88, 48], [89, 0], [90, 163],
        [91, 10], [92, 65], [93, 12], [94, 30], [95, 42], [96, 38], [97, 15], [98, 34], [99, 42], [100, 37],
        [101, 22], [102, 5], [103, 23], [104, 38], [105, 31], [106, 43], [107, 50], [108, 2], [109, 8], [110, 39],
        [111, 0], [112, 68], [113, 6], [114, 8], [115, 22], [116, 184], [117, 20], [118, 33]
    ]
    ratio_bus = np.zeros(118)
    for i in range(118):
        ratio_bus[i] = mpc_bus[i][1] / sum(mpc_bus[j][1] for j in range(118))

    total_cost = calculate_optimization_cost_two_stage(Y_real, topo, unit, ratio_bus)
# Out:
# day_ahead cost: 45777433.59835531
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 584766 rows, 322140 columns and 1428882 nonzeros
# Model fingerprint: 0xa9ecfe5a
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 9e+03]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [3e-06, 3e+02]
# Presolve removed 426377 rows and 113120 columns
# Presolve time: 1.55s
# Presolved: 158389 rows, 305662 columns, 690783 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.08s
#
# Barrier statistics:
#  AA' NZ     : 1.266e+06
#  Factor NZ  : 2.715e+06 (roughly 200 MB of memory)
#  Factor Ops : 4.997e+07 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.78071541e+12 -2.79664917e+12  2.22e+03 0.00e+00  5.04e+07     2s
#    1   9.54494451e+11 -1.39196887e+12  2.31e+02 3.49e+03  6.82e+06     2s
#    2   6.89314552e+10 -1.71503329e+11  1.00e+01 5.99e+01  5.36e+05     2s
#    3   9.68280087e+09 -4.97191490e+10  9.04e-01 1.43e+01  1.25e+05     2s
#    4   2.24356489e+09 -6.64417685e+09  1.61e-01 7.98e-01  1.87e+04     2s
#    5   1.18559131e+09 -4.24983930e+09  7.66e-02 4.00e-01  1.14e+04     2s
#    6   6.32577976e+08 -2.27865538e+09  3.84e-02 1.49e-01  6.10e+03     3s
#    7   4.58364262e+08 -1.52648952e+09  2.57e-02 5.09e-02  4.16e+03     3s
#    8   3.58025935e+08 -9.34773380e+08  1.91e-02 7.10e-03  2.71e+03     3s
#    9   2.27593936e+08 -5.02282245e+08  1.02e-02 1.75e-10  1.53e+03     3s
#   10   1.48646094e+08 -2.61754135e+08  4.11e-03 1.75e-10  8.57e+02     3s
#   11   1.23259772e+08 -9.16243312e+07  2.20e-03 8.73e-11  4.48e+02     3s
#   12   1.10596343e+08 -3.33085708e+07  1.33e-03 1.16e-10  3.00e+02     3s
#   13   1.01846504e+08  8.03628200e+06  7.70e-04 1.16e-10  1.95e+02     3s
#   14   9.74566944e+07  3.76783315e+07  5.28e-04 8.73e-11  1.24e+02     3s
#   15   9.45434800e+07  5.20874353e+07  3.71e-04 5.82e-11  8.84e+01     3s
#   16   9.08576959e+07  6.48600935e+07  1.73e-04 8.73e-11  5.41e+01     3s
#   17   8.80478617e+07  7.76235478e+07  2.15e-05 1.02e-10  2.17e+01     4s
#   18   8.76239997e+07  8.22937015e+07  7.37e-06 5.82e-11  1.11e+01     4s
#   19   8.73921293e+07  8.42999166e+07  1.81e-06 4.94e-11  6.42e+00     4s
#   20   8.73014460e+07  8.65450226e+07  1.38e-06 5.96e-11  1.57e+00     4s
#   21   8.72630774e+07  8.70089996e+07  1.99e-06 6.03e-11  5.27e-01     4s
#   22   8.72491723e+07  8.71510398e+07  1.74e-06 5.82e-11  2.04e-01     4s
#   23   8.72420625e+07  8.72098288e+07  7.06e-06 5.82e-11  6.69e-02     4s
#   24   8.72413558e+07  8.72361438e+07  3.60e-06 5.82e-11  1.08e-02     4s
#   25   8.72407801e+07  8.72405654e+07  4.32e-07 8.73e-11  4.45e-04     5s
#   26   8.72407250e+07  8.72407186e+07  4.76e-07 5.82e-11  1.31e-05     5s
#   27   8.72407234e+07  8.72407234e+07  5.97e-08 6.05e-11  6.44e-08     5s
#   28   8.72407234e+07  8.72407234e+07  1.50e-09 5.82e-11  2.62e-10     5s
#
# Barrier solved model in 28 iterations and 5.30 seconds (4.43 work units)
# Optimal objective 8.72407234e+07
#
# Crossover log...
#
#      634 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 6s
#
#    10948 PPushes remaining with PInf 0.0000000e+00                 6s
#        0 PPushes remaining with PInf 0.0000000e+00                 6s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.7426273e-08      6s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11585    8.7240723e+07   0.000000e+00   0.000000e+00      6s
#
# Solved in 11585 iterations and 6.45 seconds (5.39 work units)
# Optimal objective  8.724072338e+07
# total cost: 133018156.97765514
