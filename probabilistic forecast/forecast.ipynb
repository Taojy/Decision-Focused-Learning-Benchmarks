# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# 数据加载
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('Y_train.csv').squeeze()
X_test = pd.read_csv('X_test.csv')
y_test = pd.read_csv('Y_test.csv').squeeze()

# 确保 X_train 和 X_test 是 DataFrame
if not isinstance(X_train, pd.DataFrame):
    X_train = pd.DataFrame(X_train)
if not isinstance(X_test, pd.DataFrame):
    X_test = pd.DataFrame(X_test)

# 添加常数项
X_train = sm.add_constant(X_train, has_constant='add')
X_test = sm.add_constant(X_test, has_constant='add')

# 检查特征维度
print("X_train 形状:", X_train.shape)  # 应该是 (n_samples, 15)
print("X_test 形状:", X_test.shape)    # 应该是 (m_samples, 15)

# 设置迭代次数和分位数
iter_num = 1000
q = [0.1 * i for i in range(2,9,2)]

# 训练模型并进行预测
quan_models = [sm.QuantReg(y_train, X_train).fit(q_i, max_iter=iter_num) for q_i in q]
y_predict = [model.predict(X_test) for model in quan_models]

# 将预测结果转换为DataFrame
y_predict_df = pd.DataFrame(np.column_stack(y_predict), columns=[f'q_{q_i:.1f}' for q_i in q])

# 将预测结果保存到CSV文件
y_predict_df.to_csv('predictions.csv', index=False)

print("预测结果已保存到 predictions.csv")
# Out:
# X_train 形状: (1638, 15)
# X_test 形状: (546, 15)
# d:\Conda\envs\NNLLL\lib\site-packages\statsmodels\regression\quantile_regression.py:191: IterationLimitWarning: Maximum number of iterations (1000) reached.
#   warnings.warn("Maximum number of iterations (" + str(max_iter) +
# 预测结果已保存到 predictions.csv

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error

mpc_bus = [
    [1, 51], [2, 20], [3, 39], [4, 39], [5, 0], [6, 52], [7, 19], [8, 28], [9, 0], [10, 0],
    [11, 70], [12, 47], [13, 34], [14, 14], [15, 90], [16, 25], [17, 11], [18, 60], [19, 45], [20, 18],
    [21, 14], [22, 10], [23, 7], [24, 13], [25, 0], [26, 0], [27, 71], [28, 17], [29, 24], [30, 0],
    [31, 43], [32, 59], [33, 23], [34, 59], [35, 33], [36, 31], [37, 0], [38, 0], [39, 27], [40, 66],
    [41, 37], [42, 96], [43, 18], [44, 16], [45, 53], [46, 28], [47, 34], [48, 20], [49, 87], [50, 17],
    [51, 17], [52, 18], [53, 23], [54, 113], [55, 63], [56, 84], [57, 12], [58, 12], [59, 277], [60, 78],
    [61, 0], [62, 77], [63, 0], [64, 0], [65, 0], [66, 39], [67, 28], [68, 0], [69, 0], [70, 66],
    [71, 0], [72, 12], [73, 6], [74, 68], [75, 47], [76, 68], [77, 61], [78, 71], [79, 39], [80, 130],
    [81, 0], [82, 54], [83, 20], [84, 11], [85, 24], [86, 21], [87, 0], [88, 48], [89, 0], [90, 163],
    [91, 10], [92, 65], [93, 12], [94, 30], [95, 42], [96, 38], [97, 15], [98, 34], [99, 42], [100, 37],
    [101, 22], [102, 5], [103, 23], [104, 38], [105, 31], [106, 43], [107, 50], [108, 2], [109, 8], [110, 39],
    [111, 0], [112, 68], [113, 6], [114, 8], [115, 22], [116, 184], [117, 20], [118, 33]
]
ratio_bus = np.zeros(118)
for i in range(118):
    ratio_bus[i] = mpc_bus[i][1]/sum(mpc_bus[j][1] for j in range(118))
print(ratio_bus)
print(sum(ratio_bus[i] for i in range(118)))
print(sum(mpc_bus[j][1] for j in range(118)))

# 读取系统参数
topo = pd.read_excel('118nodes_system.xlsx', sheet_name='topology', index_col=None, header=None) # 拓扑结构

unit = pd.read_excel('118nodes_system.xlsx', sheet_name='unit', header=0) # 每个节点机组容量、电价、上/下行备用，上/下行价格

reserve_up = 150
reserve_down = 150
nodes = 118
test_Y_splits = np.array(pd.read_csv('predictions.csv', header=0))
real_Y_splits = np.array(pd.read_csv('Y_test.csv', header=0))
print(unit.shape[0])
s = test_Y_splits.shape[0]
n = len(q)
print(real_Y_splits[100][0]*ratio_bus[1])
# Out:
# [0.01202263 0.00471476 0.00919378 0.00919378 0.         0.01225837
#  0.00447902 0.00660066 0.         0.         0.01650165 0.01107968
#  0.00801509 0.00330033 0.02121641 0.00589345 0.00259312 0.01414427
#  0.0106082  0.00424328 0.00330033 0.00235738 0.00165017 0.00306459
#  0.         0.         0.01673739 0.00400754 0.00565771 0.
#  0.01013673 0.01390853 0.00542197 0.01390853 0.00777935 0.00730787
#  0.         0.         0.00636492 0.0155587  0.0087223  0.02263083
#  0.00424328 0.00377181 0.01249411 0.00660066 0.00801509 0.00471476
#  0.02050919 0.00400754 0.00400754 0.00424328 0.00542197 0.02663838
#  0.01485149 0.01980198 0.00282885 0.00282885 0.06529939 0.01838755
#  0.         0.01815182 0.         0.         0.         0.00919378
#  0.00660066 0.         0.         0.0155587  0.         0.00282885
#  0.00141443 0.01603017 0.01107968 0.01603017 0.01438001 0.01673739
#  0.00919378 0.03064592 0.         0.01272984 0.00471476 0.00259312
#  0.00565771 0.0049505  0.         0.01131542 0.         0.03842527
#  0.00235738 0.01532296 0.00282885 0.00707214 0.00990099 0.00895804
#  0.00353607 0.00801509 0.00990099 0.0087223  0.00518623 0.00117869
#  0.00542197 0.00895804 0.00730787 0.01013673 0.01178689 0.00047148
#  0.0018859  0.00919378 0.         0.01603017 0.00141443 0.0018859
#  0.00518623 0.04337577 0.00471476 0.00777935]
# 1.0000000000000004
# 4242
# 118
# 7.2489391796322495

# %%
# 建立模型
model = gp.Model()
P_c = model.addVars(unit.shape[0], s, lb=0, vtype=GRB.CONTINUOUS, name='P_c') # 火电机组出力
R_U = model.addVars(unit.shape[0], s, lb=0, vtype=GRB.CONTINUOUS, name='R_U') # 火电机组向上备用容量
R_D = model.addVars(unit.shape[0], s, lb=0, vtype=GRB.CONTINUOUS, name='R_D') # 火电机组向下备用容量
r_U = model.addVars(unit.shape[0], s, n, lb=0, vtype=GRB.CONTINUOUS, name='r_U') # 火电机组上调功率
r_D = model.addVars(unit.shape[0], s, n, lb=0, vtype=GRB.CONTINUOUS, name='r_D') # 火电机组下调功率
P_lsh = model.addVars(topo.shape[0], s, n, lb=0, vtype=GRB.CONTINUOUS, name='P_lsh') # 切负荷
delta_DA = model.addVars(topo.shape[0], s, n, lb=-180, ub=180, vtype=GRB.CONTINUOUS, name='delta_DA')
delta_RT = model.addVars(topo.shape[0], s, n, lb=-180, ub=180, vtype=GRB.CONTINUOUS, name='delta_RT')
ss = model.addVars(topo.shape[0], s, n, lb=0, vtype=GRB.CONTINUOUS, name='ss') 

c = 9000 #切负荷成本
c_s = 1750 

# 设置目标函数
model.setObjective(gp.quicksum(R_U[i,j]*unit.iloc[i,5] + R_D[i,j]*unit.iloc[i,6] + P_c[i,j]*unit.iloc[i,2] for i in range(unit.shape[0]) for j in range(s))
                + gp.quicksum((r_U[i,j,l]-r_D[i,j,l])*unit.iloc[i,2] +(P_lsh[i,j,l] * c) + (ss[i,j,l]*c_s) for i in range(topo.shape[0]) for j in range(s) for l in range(n))/n, GRB.MINIMIZE) 

for k in range(s):
    # 设置约束
        # 备用需求约束
    model.addConstr(gp.quicksum(R_U[i,k] for i in range(unit.shape[0])) == reserve_up)
    model.addConstr(gp.quicksum(R_D[i,k] for i in range(unit.shape[0])) == reserve_down)
        # 机组上下行备用约束
    for i in range(unit.shape[0]):
        model.addConstr(R_U[i,k] <= unit.iloc[i,3])
        model.addConstr(R_D[i,k] <= unit.iloc[i,4])
        # 日前：每个节点的功率平衡约束
    for l in range(n):
        for t in range(topo.shape[0]):
            model.addConstr(P_c[t,k]-test_Y_splits[k][l]*ratio_bus[t]
            -gp.quicksum(topo.iloc[t,j]*(delta_DA[t,k,l]-delta_DA[j,k,l]) for j in range(topo.shape[0])) >= 0)       
        model.addConstr(delta_DA[0,k,l] == 0)
        # 日前：机组容量约束
    for i in range(unit.shape[0]):
        model.addConstr(P_c[i,k] <= unit.iloc[i,1]-R_U[i,k])
        model.addConstr(P_c[i,k] >= R_D[i,k])
        # 实时：每个节点的功率平衡约束
    for l in range(n):
        for t in range(topo.shape[0]):
            model.addConstr(P_c[t,k] + r_U[t,k,l] - r_D[t,k,l] - ss[t,k,l] - test_Y_splits[k][l]*ratio_bus[t]  + P_lsh[t,k,l]
            -gp.quicksum(topo.iloc[t,j]*(delta_RT[t,k,l]-delta_RT[j,k,l]) for j in range(topo.shape[0]))==0)
        # 实时：备用容量约束
        for i in range(unit.shape[0]):
            model.addConstr(r_U[i,k,l] <= R_U[i,k])
            model.addConstr(r_D[i,k,l] <= R_D[i,k])
        model.addConstr(delta_RT[0,k,l] == 0)  
        # 添加切负荷量大于等于0的约束
        for t in range(topo.shape[0]):
            model.addConstr(P_lsh[t,k,l] >= 0)  # 确保切负荷量大于等于0
        # 线路容量约束
        for i in range(nodes):
            for j in range(nodes):
                if i != j and topo.iloc[i,j] < -0.1:
                    model.addConstr(topo.iloc[i,j] * (delta_DA[i,k,l] - delta_DA[j,k,l]) <= 175)
                    model.addConstr(topo.iloc[i,j] * (delta_DA[i,k,l] - delta_DA[j,k,l]) >= -175)
        # 线路容量约束
        for i in range(nodes):
            for j in range(nodes):
                if i != j and topo.iloc[i,j] < -0.1:
                    model.addConstr(topo.iloc[i,j] * (delta_RT[i,k,l] - delta_RT[j,k,l]) <= 175)
                    model.addConstr(topo.iloc[i,j] * (delta_RT[i,k,l] - delta_RT[j,k,l]) >= -175)

# model.setParam("FeasibilityTol", 1e-9) # 设置可行性容忍度
# model.setParam("OptimalityTol", 1e-9) # 设置最优性容忍度
# model.setParam("MIPGap", 1e-18) # 设置目标间隙
# model.setParam("NumericFocus", 3) # 设置更高的数值精度    
model.optimize()
# model.computeIIS()
# model.write("model1.ilp")
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4679220 rows, 1739556 columns and 11688768 nonzeros
# Model fingerprint: 0x13976b1d
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [1e+01, 2e+03]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [2e-01, 8e+02]
# Presolve removed 2334696 rows and 399672 columns (presolve time = 5s) ...
# Presolve removed 3107832 rows and 399672 columns
# Presolve time: 24.66s
# Presolved: 1571388 rows, 2110836 columns, 5999448 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 2.61s
#
# Barrier statistics:
#  AA' NZ     : 1.273e+07
#  Factor NZ  : 6.528e+07 (roughly 2.0 GB of memory)
#  Factor Ops : 6.864e+09 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.63139318e+13 -5.19401774e+12  3.13e+04 1.53e+02  1.75e+07    35s
#    1   3.95747149e+12 -3.11911169e+12  6.84e+03 2.00e+03  4.02e+06    36s
#    2   1.78728615e+11 -9.09869987e+11  2.81e+02 4.12e+01  3.31e+05    37s
#    3   4.27991946e+10 -3.48488846e+11  5.90e+01 1.15e+01  1.02e+05    39s
#    4   9.26749234e+09 -1.49435917e+11  5.87e+00 3.06e+00  3.80e+04    41s
#    5   5.15823333e+09 -7.26576092e+10  1.39e+00 5.82e-11  1.84e+04    42s
#    6   2.30570930e+09 -3.03866980e+10  1.17e-01 5.82e-11  7.69e+03    43s
#    7   6.98137843e+08 -5.46305341e+09  1.97e-02 1.16e-10  1.45e+03    44s
#    8   2.97745726e+08 -1.47779507e+09  5.49e-03 5.82e-11  4.18e+02    45s
#    9   1.70599923e+08 -2.16670765e+08  7.24e-04 8.73e-11  9.10e+01    47s
#   10   1.44691420e+08  3.81809660e+07  1.14e-04 5.82e-11  2.50e+01    48s
#   11   1.39172287e+08  8.96429730e+07  5.61e-05 5.82e-11  1.16e+01    49s
#   12   1.36592846e+08  1.06090736e+08  3.52e-05 5.82e-11  7.17e+00    50s
#   13   1.35062070e+08  1.18687458e+08  2.33e-05 5.82e-11  3.85e+00    52s
#   14   1.33480910e+08  1.24715986e+08  1.12e-05 5.82e-11  2.06e+00    53s
#   15   1.32921982e+08  1.27734633e+08  7.19e-06 5.82e-11  1.22e+00    54s
#   16   1.32321671e+08  1.29660795e+08  2.89e-06 5.82e-11  6.25e-01    55s
#   17   1.32052435e+08  1.31134348e+08  1.04e-06 5.82e-11  2.16e-01    57s
#   18   1.31943653e+08  1.31640235e+08  2.71e-06 5.82e-11  7.13e-02    59s
#   19   1.31913102e+08  1.31759461e+08  4.45e-06 6.29e-11  3.61e-02    60s
#   20   1.31892796e+08  1.31832449e+08  1.63e-05 5.82e-11  1.42e-02    61s
#   21   1.31885022e+08  1.31858954e+08  1.10e-05 5.82e-11  6.13e-03    62s
#   22   1.31882302e+08  1.31875683e+08  9.08e-06 8.73e-11  1.56e-03    63s
#   23   1.31882053e+08  1.31881672e+08  1.18e-05 8.73e-11  8.95e-05    65s
#   24   1.31881924e+08  1.31881901e+08  6.72e-07 8.73e-11  5.37e-06    68s
#   25   1.31881913e+08  1.31881912e+08  8.34e-07 8.73e-11  3.86e-08    71s
#   26   1.31881912e+08  1.31881912e+08  3.71e-08 8.73e-11  2.38e-11    74s
#
# Barrier solved model in 26 iterations and 73.68 seconds (47.86 work units)
# Optimal objective 1.31881912e+08
#
# Crossover log...
#
#  1337610 variables added to crossover basis                       75s
#
#    69081 DPushes remaining with DInf 0.0000000e+00                76s
#     1669 DPushes remaining with DInf 0.0000000e+00                81s
#        0 DPushes remaining with DInf 0.0000000e+00                82s
#
#   342372 PPushes remaining with PInf 0.0000000e+00                82s
#   105920 PPushes remaining with PInf 0.0000000e+00                85s
#    56744 PPushes remaining with PInf 0.0000000e+00                90s
#    36798 PPushes remaining with PInf 0.0000000e+00                95s
#    22633 PPushes remaining with PInf 0.0000000e+00               101s
#    10495 PPushes remaining with PInf 0.0000000e+00               106s
#     3850 PPushes remaining with PInf 0.0000000e+00               110s
#        0 PPushes remaining with PInf 0.0000000e+00               114s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.9338108e-07    114s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   395050    1.3188191e+08   0.000000e+00   0.000000e+00    119s
#
# Solved in 395050 iterations and 118.88 seconds (64.41 work units)
# Optimal objective  1.318819125e+08

# %%
# 建立模型
model2 = gp.Model()
r_U = model2.addVars(unit.shape[0], s, lb=0, vtype=GRB.CONTINUOUS, name='r_U') # 火电机组上调功率
r_D = model2.addVars(unit.shape[0], s, lb=0, vtype=GRB.CONTINUOUS, name='r_D') # 火电机组下调功率
P_lsh = model2.addVars(topo.shape[0], s, lb=0, vtype=GRB.CONTINUOUS, name='P_lsh') # 切负荷
delta_RT = model2.addVars(topo.shape[0], s, lb=-180, ub=180, vtype=GRB.CONTINUOUS, name='delta_RT')
ss = model2.addVars(topo.shape[0], s, lb=0, vtype=GRB.CONTINUOUS, name='ss') 

c = 9000 #切负荷成本
c_s = 1750 

# 设置目标函数
model2.setObjective(gp.quicksum(R_U[i,j].x*unit.iloc[i,5] + R_D[i,j].x*unit.iloc[i,6] + P_c[i,j].x*unit.iloc[i,2] for i in range(unit.shape[0]) for j in range(s))
                + gp.quicksum((r_U[i,j]-r_D[i,j])*unit.iloc[i,2] +(P_lsh[i,j] * c) + (ss[i,j]*c_s) for i in range(topo.shape[0]) for j in range(s)), GRB.MINIMIZE) 

for k in range(s):
    # 设置约束
        # 实时：每个节点的功率平衡约束
    for t in range(topo.shape[0]):
        model2.addConstr(P_c[t,k].x + r_U[t,k] - r_D[t,k] - ss[t,k] - real_Y_splits[k][0]*ratio_bus[t] + P_lsh[t,k]
        -gp.quicksum(topo.iloc[t,j]*(delta_RT[t,k]-delta_RT[j,k]) for j in range(topo.shape[0]))==0)
        # 实时：备用容量约束
    for i in range(unit.shape[0]):
        model2.addConstr(r_U[i,k] <= R_U[i,k].x)
        model2.addConstr(r_D[i,k] <= R_D[i,k].x)
    model2.addConstr(delta_RT[0,k] == 0)  
        # 添加切负荷量大于等于0的约束
    for t in range(topo.shape[0]):
        model2.addConstr(P_lsh[t,k] >= 0)  # 确保切负荷量大于等于0
        # 线路容量约束
    for i in range(nodes):
        for j in range(nodes):
            if i != j and topo.iloc[i,j] < -0.1:
                model2.addConstr(topo.iloc[i,j] * (delta_RT[i,k] - delta_RT[j,k]) <= 175)
                model2.addConstr(topo.iloc[i,j] * (delta_RT[i,k] - delta_RT[j,k]) >= -175)

# model.setParam("FeasibilityTol", 1e-9) # 设置可行性容忍度
# model.setParam("OptimalityTol", 1e-9) # 设置最优性容忍度
# model.setParam("MIPGap", 1e-18) # 设置目标间隙
# model.setParam("NumericFocus", 3) # 设置更高的数值精度    
model2.optimize()
# model.computeIIS()
# model.write("model1.ilp")
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i5-13400F, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 649194 rows, 322140 columns and 1493310 nonzeros
# Model fingerprint: 0x7b654a91
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [4e+01, 9e+03]
#   Bounds range     [2e+02, 2e+02]
#   RHS range        [5e-02, 3e+02]
# Presolve removed 491400 rows and 131040 columns
# Presolve time: 1.91s
# Presolved: 157794 rows, 287742 columns, 672126 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.12s
#
# Barrier statistics:
#  AA' NZ     : 1.261e+06
#  Factor NZ  : 2.699e+06 (roughly 200 MB of memory)
#  Factor Ops : 4.954e+07 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.66248310e+12 -2.60549664e+12  2.20e+03 0.00e+00  4.82e+07     2s
#    1   8.81178364e+11 -1.29994794e+12  2.20e+02 3.42e+03  6.57e+06     3s
#    2   5.13541243e+10 -1.59542591e+11  6.71e+00 6.90e+01  4.96e+05     3s
#    3   6.73219424e+09 -2.58209872e+10  2.77e-01 5.02e+00  7.35e+04     3s
#    4   2.63959693e+09 -8.87001065e+09  1.10e-01 1.18e+00  2.59e+04     3s
#    5   2.16459627e+09 -5.11983999e+09  1.41e-01 4.08e-01  1.64e+04     3s
#    6   1.21463830e+09 -2.79510189e+09  4.67e-02 1.17e-01  9.01e+03     3s
#    7   8.13252147e+08 -1.42156755e+09  5.11e-02 1.16e-02  5.02e+03     3s
#    8   4.95180719e+08 -5.13592081e+08  1.96e-02 5.82e-11  2.27e+03     3s
#    9   3.67090795e+08 -2.11364036e+08  9.71e-03 5.82e-11  1.30e+03     3s
#   10   2.74279771e+08  3.39958044e+07  3.62e-03 5.82e-11  5.39e+02     3s
#   11   2.46522414e+08  8.83098312e+07  2.24e-03 5.82e-11  3.55e+02     3s
#   12   2.23878866e+08  1.36670013e+08  1.12e-03 5.23e-11  1.96e+02     3s
#   13   2.17255362e+08  1.59737750e+08  7.99e-04 3.96e-11  1.29e+02     4s
#   14   2.07851745e+08  1.75460493e+08  4.61e-04 5.82e-11  7.27e+01     4s
#   15   2.02810075e+08  1.86759200e+08  1.07e-04 5.82e-11  3.60e+01     4s
#   16   2.01128125e+08  1.92617608e+08  2.87e-05 5.82e-11  1.91e+01     4s
#   17   2.00717727e+08  1.95721247e+08  1.26e-05 5.82e-11  1.12e+01     4s
#   18   2.00499210e+08  1.97143256e+08  5.22e-06 5.82e-11  7.53e+00     4s
#   19   2.00356249e+08  1.98935792e+08  1.83e-06 5.82e-11  3.19e+00     4s
#   20   2.00322612e+08  2.00040288e+08  8.64e-06 5.82e-11  6.33e-01     4s
#   21   2.00309680e+08  2.00263284e+08  7.09e-06 5.82e-11  1.04e-01     4s
#   22   2.00302864e+08  2.00301268e+08  4.20e-06 5.82e-11  3.57e-03     4s
#   23   2.00301656e+08  2.00301560e+08  2.93e-07 5.82e-11  2.16e-04     5s
#   24   2.00301576e+08  2.00301576e+08  1.32e-08 5.82e-11  2.19e-07     5s
#   25   2.00301576e+08  2.00301576e+08  6.13e-10 5.82e-11  3.87e-10     5s
#
# Barrier solved model in 25 iterations and 4.88 seconds (3.84 work units)
# Optimal objective 2.00301576e+08
#
# Crossover log...
#
#   117043 variables added to crossover basis                        5s
#
#      367 DPushes remaining with DInf 0.0000000e+00                 5s
#        0 DPushes remaining with DInf 0.0000000e+00                 5s
#
#    43179 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 7s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.0035147e-08      7s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    43549    2.0030158e+08   0.000000e+00   0.000000e+00      7s
#
# Solved in 43549 iterations and 7.14 seconds (5.21 work units)
# Optimal objective  2.003015761e+08

# %%
if model2.status == GRB.Status.OPTIMAL:
    # 输出目标函数值
    objective_value = model2.ObjVal
    print(f"优化完成，目标函数的最优值为: {objective_value}")

    # 遍历每个时段
    for k in range(s):  # s 是时段数
        # 计算单个时段下所有机组的出力累加
        total_power_generation = sum(P_c[i,k].X for i in range(unit.shape[0]))
        
        # 计算单个时段下所有负荷的需求累加
        total_load_demand = sum(real_Y_splits[k][0] * ratio_bus[t] for t in range(topo.shape[0]))
        
        # 计算单个时段下所有负荷的切负荷量累加
        total_load_shedding = sum(P_lsh[t,k].X for t in range(topo.shape[0]))
        
        # 输出结果
        print(f"\n时段 {k} 的统计结果:")
        print(f"所有机组的出力累加: {total_power_generation}")
        print(f"所有负荷的需求累加: {total_load_demand}")
        print(f"所有负荷的切负荷量累加: {total_load_shedding}")
else:
    print("优化未完成或未找到最优解。")
# Out:
# 优化完成，目标函数的最优值为: 171183152.82642257
#
# 时段 0 的统计结果:
# 所有机组的出力累加: 1918.49054759929
# 所有负荷的需求累加: 2173.500000000001
# 所有负荷的切负荷量累加: 142.08477656502725
#
# 时段 1 的统计结果:
# 所有机组的出力累加: 2036.7395785618041
# 所有负荷的需求累加: 2095.0
# 所有负荷的切负荷量累加: 26.853768018233325
#
# 时段 2 的统计结果:
# 所有机组的出力累加: 1875.7317277193674
# 所有负荷的需求累加: 1846.3333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 3 的统计结果:
# 所有机组的出力累加: 1683.6537419180381
# 所有负荷的需求累加: 1577.5833339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 4 的统计结果:
# 所有机组的出力累加: 1657.6370356982097
# 所有负荷的需求累加: 1446.2499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 5 的统计结果:
# 所有机组的出力累加: 1607.729503186153
# 所有负荷的需求累加: 1370.7499999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 6 的统计结果:
# 所有机组的出力累加: 1516.9598243668356
# 所有负荷的需求累加: 1285.7500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 7 的统计结果:
# 所有机组的出力累加: 1581.199402413736
# 所有负荷的需求累加: 1244.8333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 8 的统计结果:
# 所有机组的出力累加: 1576.4024311236592
# 所有负荷的需求累加: 1203.2500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 9 的统计结果:
# 所有机组的出力累加: 1482.7760325142358
# 所有负荷的需求累加: 1257.7499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 10 的统计结果:
# 所有机组的出力累加: 1546.1182659810975
# 所有负荷的需求累加: 1395.5000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 11 的统计结果:
# 所有机组的出力累加: 1503.5593082385367
# 所有负荷的需求累加: 1561.833334
# 所有负荷的切负荷量累加: 11.698375971169185
#
# 时段 12 的统计结果:
# 所有机组的出力累加: 1568.3590159224682
# 所有负荷的需求累加: 1720.4166670000004
# 所有负荷的切负荷量累加: 59.04922319185249
#
# 时段 13 的统计结果:
# 所有机组的出力累加: 1617.9283815164342
# 所有负荷的需求累加: 1777.8333340000001
# 所有负荷的切负荷量累加: 65.12994401396406
#
# 时段 14 的统计结果:
# 所有机组的出力累加: 1553.4997167560277
# 所有负荷的需求累加: 1756.0833340000001
# 所有负荷的切负荷量累加: 98.20080902100898
#
# 时段 15 的统计结果:
# 所有机组的出力累加: 1621.8596337990732
# 所有负荷的需求累加: 1692.333334
# 所有负荷的切负荷量累加: 13.95271251184522
#
# 时段 16 的统计结果:
# 所有机组的出力累加: 1648.724087050589
# 所有负荷的需求累加: 1574.5833339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 17 的统计结果:
# 所有机组的出力累加: 1719.5297889923477
# 所有负荷的需求累加: 1461.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 18 的统计结果:
# 所有机组的出力累加: 1675.1562961974487
# 所有负荷的需求累加: 1413.5000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 19 的统计结果:
# 所有机组的出力累加: 1746.5652160079053
# 所有负荷的需求累加: 1397.4166670000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 20 的统计结果:
# 所有机组的出力累加: 1767.285610786146
# 所有负荷的需求累加: 1406.4166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 21 的统计结果:
# 所有机组的出力累加: 1804.2972789023358
# 所有负荷的需求累加: 1426.583334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 22 的统计结果:
# 所有机组的出力累加: 1765.8187296855372
# 所有负荷的需求累加: 1495.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 23 的统计结果:
# 所有机组的出力累加: 1770.215536182621
# 所有负荷的需求累加: 1696.9166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 24 的统计结果:
# 所有机组的出力累加: 1801.6720181795868
# 所有负荷的需求累加: 1961.1666669999997
# 所有负荷的切负荷量累加: 64.87896125018676
#
# 时段 25 的统计结果:
# 所有机组的出力累加: 1852.7789162231688
# 所有负荷的需求累加: 1990.9166670000004
# 所有负荷的切负荷量累加: 61.0987378511706
#
# 时段 26 的统计结果:
# 所有机组的出力累加: 1840.288391694285
# 所有负荷的需求累加: 1833.833334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 27 的统计结果:
# 所有机组的出力累加: 1679.0307499035448
# 所有负荷的需求累加: 1639.1666670000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 28 的统计结果:
# 所有机组的出力累加: 1636.3210024236314
# 所有负荷的需求累加: 1535.750000000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 29 的统计结果:
# 所有机组的出力累加: 1582.161681303746
# 所有负荷的需求累加: 1419.4166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 30 的统计结果:
# 所有机组的出力累加: 1486.6965081985727
# 所有负荷的需求累加: 1305.4999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 31 的统计结果:
# 所有机组的出力累加: 1399.831700719019
# 所有负荷的需求累加: 1265.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 32 的统计结果:
# 所有机组的出力累加: 1494.3372143000859
# 所有负荷的需求累加: 1225.416666999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 33 的统计结果:
# 所有机组的出力累加: 1509.479824045455
# 所有负荷的需求累加: 1242.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 34 的统计结果:
# 所有机组的出力累加: 1464.011850541741
# 所有负荷的需求累加: 1264.8333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 35 的统计结果:
# 所有机组的出力累加: 1518.338895046462
# 所有负荷的需求累加: 1405.3333339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 36 的统计结果:
# 所有机组的出力累加: 1593.4975599310135
# 所有负荷的需求累加: 1630.916667
# 所有负荷的切负荷量累加: 7.392073345709889
#
# 时段 37 的统计结果:
# 所有机组的出力累加: 1719.3412624010791
# 所有负荷的需求累加: 1793.1666670000004
# 所有负荷的切负荷量累加: 14.617955101854989
#
# 时段 38 的统计结果:
# 所有机组的出力累加: 1833.7492158886143
# 所有负荷的需求累加: 1853.1666669999997
# 所有负荷的切负荷量累加: 5.516498293594793
#
# 时段 39 的统计结果:
# 所有机组的出力累加: 1986.4280010584778
# 所有负荷的需求累加: 1821.2500000000007
# 所有负荷的切负荷量累加: 0.0
#
# 时段 40 的统计结果:
# 所有机组的出力累加: 2015.670363961143
# 所有负荷的需求累加: 1737.3333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 41 的统计结果:
# 所有机组的出力累加: 2060.9262672840864
# 所有负荷的需求累加: 1644.333334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 42 的统计结果:
# 所有机组的出力累加: 1939.0384481175822
# 所有负荷的需求累加: 1639.4999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 43 的统计结果:
# 所有机组的出力累加: 1980.4104522419877
# 所有负荷的需求累加: 1689.9166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 44 的统计结果:
# 所有机组的出力累加: 2042.7226727944044
# 所有负荷的需求累加: 1762.0000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 45 的统计结果:
# 所有机组的出力累加: 2055.5643204398702
# 所有负荷的需求累加: 1811.4999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 46 的统计结果:
# 所有机组的出力累加: 2075.2334823780557
# 所有负荷的需求累加: 1929.583334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 47 的统计结果:
# 所有机组的出力累加: 2163.765583371085
# 所有负荷的需求累加: 2154.0833339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 48 的统计结果:
# 所有机组的出力累加: 2167.4659538672304
# 所有负荷的需求累加: 2440.916667000001
# 所有负荷的切负荷量累加: 154.86361553825589
#
# 时段 49 的统计结果:
# 所有机组的出力累加: 2132.4694468711696
# 所有负荷的需求累加: 2323.75
# 所有负荷的切负荷量累加: 97.92394864935517
#
# 时段 50 的统计结果:
# 所有机组的出力累加: 1943.448948347638
# 所有负荷的需求累加: 1872.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 51 的统计结果:
# 所有机组的出力累加: 1697.7789220651125
# 所有负荷的需求累加: 1562.9166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 52 的统计结果:
# 所有机组的出力累加: 1513.5699066886075
# 所有负荷的需求累加: 1377.9166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 53 的统计结果:
# 所有机组的出力累加: 1325.1561728230424
# 所有负荷的需求累加: 1263.3333340000008
# 所有负荷的切负荷量累加: 0.0
#
# 时段 54 的统计结果:
# 所有机组的出力累加: 1260.9695459165202
# 所有负荷的需求累加: 1144.666667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 55 的统计结果:
# 所有机组的出力累加: 1198.9129037507178
# 所有负荷的需求累加: 1082.0000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 56 的统计结果:
# 所有机组的出力累加: 1116.4021091016627
# 所有负荷的需求累加: 1034.9166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 57 的统计结果:
# 所有机组的出力累加: 1123.1544258843787
# 所有负荷的需求累加: 1050.9166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 58 的统计结果:
# 所有机组的出力累加: 1134.673911900236
# 所有负荷的需求累加: 1112.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 59 的统计结果:
# 所有机组的出力累加: 1129.0457764331968
# 所有负荷的需求累加: 1227.5833340000001
# 所有负荷的切负荷量累加: 16.333509233950508
#
# 时段 60 的统计结果:
# 所有机组的出力累加: 1263.9965633141717
# 所有负荷的需求累加: 1407.4166669999997
# 所有负荷的切负荷量累加: 51.51900917488774
#
# 时段 61 的统计结果:
# 所有机组的出力累加: 1390.658077255842
# 所有负荷的需求累加: 1522.2499999999998
# 所有负荷的切负荷量累加: 42.349142619885015
#
# 时段 62 的统计结果:
# 所有机组的出力累加: 1361.956237271526
# 所有负荷的需求累加: 1478.0000000000002
# 所有负荷的切负荷量累加: 30.295340499105805
#
# 时段 63 的统计结果:
# 所有机组的出力累加: 1414.6777519765378
# 所有负荷的需求累加: 1426.583334
# 所有负荷的切负荷量累加: 2.367547343233923
#
# 时段 64 的统计结果:
# 所有机组的出力累加: 1435.7376531202647
# 所有负荷的需求累加: 1315.0833340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 65 的统计结果:
# 所有机组的出力累加: 1520.8730127335577
# 所有负荷的需求累加: 1180.5833339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 66 的统计结果:
# 所有机组的出力累加: 1287.9478472959854
# 所有负荷的需求累加: 1105.9166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 67 的统计结果:
# 所有机组的出力累加: 1369.2029121178955
# 所有负荷的需求累加: 1114.833334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 68 的统计结果:
# 所有机组的出力累加: 1483.873182077884
# 所有负荷的需求累加: 1130.75
# 所有负荷的切负荷量累加: 0.0
#
# 时段 69 的统计结果:
# 所有机组的出力累加: 1455.674035775528
# 所有负荷的需求累加: 1182.9999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 70 的统计结果:
# 所有机组的出力累加: 1534.999268120595
# 所有负荷的需求累加: 1246.3333339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 71 的统计结果:
# 所有机组的出力累加: 1510.126498219224
# 所有负荷的需求累加: 1414.6666669999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 72 的统计结果:
# 所有机组的出力累加: 1609.5305588009119
# 所有负荷的需求累加: 1722.0833340000001
# 所有负荷的切负荷量累加: 36.18908708289564
#
# 时段 73 的统计结果:
# 所有机组的出力累加: 1593.994974728704
# 所有负荷的需求累加: 1697.8333339999995
# 所有负荷的切负荷量累加: 31.178775596859964
#
# 时段 74 的统计结果:
# 所有机组的出力累加: 1458.6607961859283
# 所有负荷的需求累加: 1490.3333340000004
# 所有负荷的切负荷量累加: 6.342258513981619
#
# 时段 75 的统计结果:
# 所有机组的出力累加: 1495.8658970614078
# 所有负荷的需求累加: 1332.9166670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 76 的统计结果:
# 所有机组的出力累加: 1434.832564718066
# 所有负荷的需求累加: 1249.8333340000008
# 所有负荷的切负荷量累加: 0.0
#
# 时段 77 的统计结果:
# 所有机组的出力累加: 1364.8111339751415
# 所有负荷的需求累加: 1175.1666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 78 的统计结果:
# 所有机组的出力累加: 1371.0408686543851
# 所有负荷的需求累加: 1132.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 79 的统计结果:
# 所有机组的出力累加: 1318.5297531967055
# 所有负荷的需求累加: 1079.8333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 80 的统计结果:
# 所有机组的出力累加: 1252.7818209341306
# 所有负荷的需求累加: 1041.083334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 81 的统计结果:
# 所有机组的出力累加: 1244.1826756857427
# 所有负荷的需求累加: 1047.9999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 82 的统计结果:
# 所有机组的出力累加: 1191.3708925177223
# 所有负荷的需求累加: 1101.0000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 83 的统计结果:
# 所有机组的出力累加: 1203.3953487404679
# 所有负荷的需求累加: 1159.4999999999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 84 的统计结果:
# 所有机组的出力累加: 1269.1754946144852
# 所有负荷的需求累加: 1314.75
# 所有负荷的切负荷量累加: 9.141371531492268
#
# 时段 85 的统计结果:
# 所有机组的出力累加: 1403.5457682272765
# 所有负荷的需求累加: 1458.3333339999997
# 所有负荷的切负荷量累加: 10.996389328677594
#
# 时段 86 的统计结果:
# 所有机组的出力累加: 1493.3378935856758
# 所有负荷的需求累加: 1493.0833339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 87 的统计结果:
# 所有机组的出力累加: 1617.0011303041838
# 所有负荷的需求累加: 1465.9166669999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 88 的统计结果:
# 所有机组的出力累加: 1444.2138108499873
# 所有负荷的需求累加: 1424.0833340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 89 的统计结果:
# 所有机组的出力累加: 1484.2613461486712
# 所有负荷的需求累加: 1363.4166669999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 90 的统计结果:
# 所有机组的出力累加: 1460.0696904076865
# 所有负荷的需求累加: 1331.833334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 91 的统计结果:
# 所有机组的出力累加: 1365.5721214024836
# 所有负荷的需求累加: 1339.9166670000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 92 的统计结果:
# 所有机组的出力累加: 1516.7999969601005
# 所有负荷的需求累加: 1379.4166670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 93 的统计结果:
# 所有机组的出力累加: 1713.6320061097622
# 所有负荷的需求累加: 1448.2499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 94 的统计结果:
# 所有机组的出力累加: 1782.3449576859548
# 所有负荷的需求累加: 1541.9999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 95 的统计结果:
# 所有机组的出力累加: 1853.2916523372453
# 所有负荷的需求累加: 1664.6666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 96 的统计结果:
# 所有机组的出力累加: 1916.0362900404398
# 所有负荷的需求累加: 1834.333334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 97 的统计结果:
# 所有机组的出力累加: 1898.5665757625734
# 所有负荷的需求累加: 1912.2499999999986
# 所有负荷的切负荷量累加: 3.2510135409273175
#
# 时段 98 的统计结果:
# 所有机组的出力累加: 1702.1628147830022
# 所有负荷的需求累加: 1872.3333339999986
# 所有负荷的切负荷量累加: 73.08453147746599
#
# 时段 99 的统计结果:
# 所有机组的出力累加: 1675.0866201485176
# 所有负荷的需求累加: 1734.750000000001
# 所有负荷的切负荷量累加: 11.80709205904293
#
# 时段 100 的统计结果:
# 所有机组的出力累加: 1615.3677415135842
# 所有负荷的需求累加: 1537.5000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 101 的统计结果:
# 所有机组的出力累加: 1477.5597679279037
# 所有负荷的需求累加: 1402.666667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 102 的统计结果:
# 所有机组的出力累加: 1429.9707815216238
# 所有负荷的需求累加: 1317.3333339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 103 的统计结果:
# 所有机组的出力累加: 1348.9183321725468
# 所有负荷的需求累加: 1234.3333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 104 的统计结果:
# 所有机组的出力累加: 1340.9519034196558
# 所有负荷的需求累加: 1141.2500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 105 的统计结果:
# 所有机组的出力累加: 1288.869034473414
# 所有负荷的需求累加: 1124.7500000000007
# 所有负荷的切负荷量累加: 0.0
#
# 时段 106 的统计结果:
# 所有机组的出力累加: 1277.7100769720328
# 所有负荷的需求累加: 1189.5833339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 107 的统计结果:
# 所有机组的出力累加: 1261.429978765946
# 所有负荷的需求累加: 1227.7500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 108 的统计结果:
# 所有机组的出力累加: 1374.3390576597392
# 所有负荷的需求累加: 1404.7500000000005
# 所有负荷的切负荷量累加: 6.088240635186253
#
# 时段 109 的统计结果:
# 所有机组的出力累加: 1597.5094664683197
# 所有负荷的需求累加: 1545.6666669999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 110 的统计结果:
# 所有机组的出力累加: 1637.9016625188115
# 所有负荷的需求累加: 1534.5833339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 111 的统计结果:
# 所有机组的出力累加: 1694.183089421941
# 所有负荷的需求累加: 1518.833333999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 112 的统计结果:
# 所有机组的出力累加: 1768.8028191232552
# 所有负荷的需求累加: 1494.0833339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 113 的统计结果:
# 所有机组的出力累加: 1811.4081189360595
# 所有负荷的需求累加: 1417.5833339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 114 的统计结果:
# 所有机组的出力累加: 1643.0771629505157
# 所有负荷的需求累加: 1340.8333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 115 的统计结果:
# 所有机组的出力累加: 1635.0002027917074
# 所有负荷的需求累加: 1325.7500000000007
# 所有负荷的切负荷量累加: 0.0
#
# 时段 116 的统计结果:
# 所有机组的出力累加: 1630.0095607371156
# 所有负荷的需求累加: 1339.5
# 所有负荷的切负荷量累加: 0.0
#
# 时段 117 的统计结果:
# 所有机组的出力累加: 1723.1484969006485
# 所有负荷的需求累加: 1342.2500000000007
# 所有负荷的切负荷量累加: 0.0
#
# 时段 118 的统计结果:
# 所有机组的出力累加: 1669.2200565295007
# 所有负荷的需求累加: 1373.9166670000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 119 的统计结果:
# 所有机组的出力累加: 1611.6542222989858
# 所有负荷的需求累加: 1416.9999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 120 的统计结果:
# 所有机组的出力累加: 1609.0383144443229
# 所有负荷的需求累加: 1528.6666670000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 121 的统计结果:
# 所有机组的出力累加: 1645.2709084468659
# 所有负荷的需求累加: 1683.833334
# 所有负荷的切负荷量累加: 7.618997936694086
#
# 时段 122 的统计结果:
# 所有机组的出力累加: 1677.6045747119722
# 所有负荷的需求累加: 1740.9166669999997
# 所有负荷的切负荷量累加: 12.531284476769088
#
# 时段 123 的统计结果:
# 所有机组的出力累加: 1610.2901039570245
# 所有负荷的需求累加: 1573.5000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 124 的统计结果:
# 所有机组的出力累加: 1509.4259204754856
# 所有负荷的需求累加: 1383.6666669999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 125 的统计结果:
# 所有机组的出力累加: 1432.4191573522514
# 所有负荷的需求累加: 1267.5833340000008
# 所有负荷的切负荷量累加: 0.0
#
# 时段 126 的统计结果:
# 所有机组的出力累加: 1304.4414098216444
# 所有负荷的需求累加: 1203.1666669999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 127 的统计结果:
# 所有机组的出力累加: 1206.9791608628855
# 所有负荷的需求累加: 1131.666667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 128 的统计结果:
# 所有机组的出力累加: 1153.1934252461933
# 所有负荷的需求累加: 1067.5000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 129 的统计结果:
# 所有机组的出力累加: 1086.9146772531117
# 所有负荷的需求累加: 1022.0833339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 130 的统计结果:
# 所有机组的出力累加: 1028.9113042250299
# 所有负荷的需求累加: 1054.3333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 131 的统计结果:
# 所有机组的出力累加: 1025.1796751106153
# 所有负荷的需求累加: 1150.4999999999998
# 所有负荷的切负荷量累加: 2.828394764291602
#
# 时段 132 的统计结果:
# 所有机组的出力累加: 1138.5270264174544
# 所有负荷的需求累加: 1297.1666669999997
# 所有负荷的切负荷量累加: 49.14796458260196
#
# 时段 133 的统计结果:
# 所有机组的出力累加: 1236.8192447362323
# 所有负荷的需求累加: 1410.3333340000004
# 所有负荷的切负荷量累加: 74.55792266435594
#
# 时段 134 的统计结果:
# 所有机组的出力累加: 1284.1486794168961
# 所有负荷的需求累加: 1347.5833340000001
# 所有负荷的切负荷量累加: 12.737450709256905
#
# 时段 135 的统计结果:
# 所有机组的出力累加: 1285.527637035685
# 所有负荷的需求累加: 1213.7499999999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 136 的统计结果:
# 所有机组的出力累加: 1327.944425385339
# 所有负荷的需求累加: 1098.4999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 137 的统计结果:
# 所有机组的出力累加: 1370.8403003593025
# 所有负荷的需求累加: 985.6666664999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 138 的统计结果:
# 所有机组的出力累加: 1130.4939305330472
# 所有负荷的需求累加: 913.0833335000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 139 的统计结果:
# 所有机组的出力累加: 1121.698667175689
# 所有负荷的需求累加: 901.9166665000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 140 的统计结果:
# 所有机组的出力累加: 1209.056307575463
# 所有负荷的需求累加: 893.1666665000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 141 的统计结果:
# 所有机组的出力累加: 1193.1532958864916
# 所有负荷的需求累加: 913.6666665000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 142 的统计结果:
# 所有机组的出力累加: 1230.7724832692297
# 所有负荷的需求累加: 969.1666665000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 143 的统计结果:
# 所有机组的出力累加: 1393.654473890238
# 所有负荷的需求累加: 1147.5
# 所有负荷的切负荷量累加: 0.0
#
# 时段 144 的统计结果:
# 所有机组的出力累加: 1424.2970057811426
# 所有负荷的需求累加: 1404.2500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 145 的统计结果:
# 所有机组的出力累加: 1464.4153523690143
# 所有负荷的需求累加: 1452.6666670000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 146 的统计结果:
# 所有机组的出力累加: 1358.5332833088019
# 所有负荷的需求累加: 1364.5833340000004
# 所有负荷的切负荷量累加: 1.1920341858117354
#
# 时段 147 的统计结果:
# 所有机组的出力累加: 1324.8972496867932
# 所有负荷的需求累加: 1256.4166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 148 的统计结果:
# 所有机组的出力累加: 1243.8785266916816
# 所有负荷的需求累加: 1150.25
# 所有负荷的切负荷量累加: 0.0
#
# 时段 149 的统计结果:
# 所有机组的出力累加: 1214.673911259421
# 所有负荷的需求累加: 1067.9999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 150 的统计结果:
# 所有机组的出力累加: 1237.228186199663
# 所有负荷的需求累加: 1015.7499999999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 151 的统计结果:
# 所有机组的出力累加: 1220.79968231284
# 所有负荷的需求累加: 1018.3333339999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 152 的统计结果:
# 所有机组的出力累加: 1149.0425514359024
# 所有负荷的需求累加: 997.9166664999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 153 的统计结果:
# 所有机组的出力累加: 1070.0165892400946
# 所有负荷的需求累加: 1005.0000000000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 154 的统计结果:
# 所有机组的出力累加: 1059.1026696618428
# 所有负荷的需求累加: 1073.0833340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 155 的统计结果:
# 所有机组的出力累加: 1125.2007151610885
# 所有负荷的需求累加: 1151.4999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 156 的统计结果:
# 所有机组的出力累加: 1185.0645937731206
# 所有负荷的需求累加: 1310.4166670000002
# 所有负荷的切负荷量累加: 30.39331210795217
#
# 时段 157 的统计结果:
# 所有机组的出力累加: 1303.298993601396
# 所有负荷的需求累加: 1420.6666670000004
# 所有负荷的切负荷量累加: 31.321710000528356
#
# 时段 158 的统计结果:
# 所有机组的出力累加: 1320.8797238266623
# 所有负荷的需求累加: 1371.4166669999997
# 所有负荷的切负荷量累加: 10.140541191402917
#
# 时段 159 的统计结果:
# 所有机组的出力累加: 1291.4149615375932
# 所有负荷的需求累加: 1277.0000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 160 的统计结果:
# 所有机组的出力累加: 1375.8953989138133
# 所有负荷的需求累加: 1135.833334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 161 的统计结果:
# 所有机组的出力累加: 1439.643072957935
# 所有负荷的需求累加: 1000.3333339999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 162 的统计结果:
# 所有机组的出力累加: 1222.0618909173486
# 所有负荷的需求累加: 897.4999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 163 的统计结果:
# 所有机组的出力累加: 1188.0789956837816
# 所有负荷的需求累加: 876.6666664999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 164 的统计结果:
# 所有机组的出力累加: 1252.0437194077083
# 所有负荷的需求累加: 887.5833334999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 165 的统计结果:
# 所有机组的出力累加: 1261.3897127817477
# 所有负荷的需求累加: 908.1666664999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 166 的统计结果:
# 所有机组的出力累加: 1270.9258885385354
# 所有负荷的需求累加: 954.8333335000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 167 的统计结果:
# 所有机组的出力累加: 1347.9467424145632
# 所有负荷的需求累加: 1134.0000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 168 的统计结果:
# 所有机组的出力累加: 1389.7946316211385
# 所有负荷的需求累加: 1412.3333339999997
# 所有负荷的切负荷量累加: 4.503192386463866
#
# 时段 169 的统计结果:
# 所有机组的出力累加: 1386.8800566450584
# 所有负荷的需求累加: 1468.4166669999997
# 所有负荷的切负荷量累加: 16.618147267386234
#
# 时段 170 的统计结果:
# 所有机组的出力累加: 1395.6370458926967
# 所有负荷的需求累加: 1411.3333340000001
# 所有负荷的切负荷量累加: 3.128541457111055
#
# 时段 171 的统计结果:
# 所有机组的出力累加: 1422.7481369936277
# 所有负荷的需求累加: 1405.0833339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 172 的统计结果:
# 所有机组的出力累加: 1386.675257808147
# 所有负荷的需求累加: 1407.1666670000002
# 所有负荷的切负荷量累加: 4.0911744969617985
#
# 时段 173 的统计结果:
# 所有机组的出力累加: 1417.9011631445546
# 所有负荷的需求累加: 1409.5833339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 174 的统计结果:
# 所有机组的出力累加: 1450.7136451717265
# 所有负荷的需求累加: 1414.333334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 175 的统计结果:
# 所有机组的出力累加: 1524.7463094569484
# 所有负荷的需求累加: 1398.0833340000008
# 所有负荷的切负荷量累加: 0.0
#
# 时段 176 的统计结果:
# 所有机组的出力累加: 1578.692549747408
# 所有负荷的需求累加: 1423.0833340000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 177 的统计结果:
# 所有机组的出力累加: 1671.2956261493432
# 所有负荷的需求累加: 1459.5833340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 178 的统计结果:
# 所有机组的出力累加: 1726.9616342265683
# 所有负荷的需求累加: 1548.4166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 179 的统计结果:
# 所有机组的出力累加: 1764.470644837477
# 所有负荷的需求累加: 1674.9166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 180 的统计结果:
# 所有机组的出力累加: 1819.5687931377272
# 所有负荷的需求累加: 1747.4166670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 181 的统计结果:
# 所有机组的出力累加: 1833.7276663256907
# 所有负荷的需求累加: 1809.9166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 182 的统计结果:
# 所有机组的出力累加: 1834.489314129236
# 所有负荷的需求累加: 1769.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 183 的统计结果:
# 所有机组的出力累加: 1883.705262063889
# 所有负荷的需求累加: 1655.0833339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 184 的统计结果:
# 所有机组的出力累加: 1854.9325334015439
# 所有负荷的需求累加: 1490.416666999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 185 的统计结果:
# 所有机组的出力累加: 1864.4371120806006
# 所有负荷的需求累加: 1361.1666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 186 的统计结果:
# 所有机组的出力累加: 1610.775698021874
# 所有负荷的需求累加: 1294.5000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 187 的统计结果:
# 所有机组的出力累加: 1694.4240357025153
# 所有负荷的需求累加: 1302.083334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 188 的统计结果:
# 所有机组的出力累加: 1707.587889960013
# 所有负荷的需求累加: 1322.7500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 189 的统计结果:
# 所有机组的出力累加: 1708.4253765110311
# 所有负荷的需求累加: 1326.4999999999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 190 的统计结果:
# 所有机组的出力累加: 1734.2163427247222
# 所有负荷的需求累加: 1376.6666669999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 191 的统计结果:
# 所有机组的出力累加: 1753.5613152214619
# 所有负荷的需求累加: 1568.0000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 192 的统计结果:
# 所有机组的出力累加: 1791.4202623074498
# 所有负荷的需求累加: 1854.6666669999981
# 所有负荷的切负荷量累加: 12.51824687531007
#
# 时段 193 的统计结果:
# 所有机组的出力累加: 1814.1472824618406
# 所有负荷的需求累加: 1826.0833339999997
# 所有负荷的切负荷量累加: 2.3392308661551624
#
# 时段 194 的统计结果:
# 所有机组的出力累加: 1870.506696433063
# 所有负荷的需求累加: 1621.8333339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 195 的统计结果:
# 所有机组的出力累加: 1833.9657514315809
# 所有负荷的需求累加: 1491.6666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 196 的统计结果:
# 所有机组的出力累加: 1840.38121491516
# 所有负荷的需求累加: 1442.5
# 所有负荷的切负荷量累加: 0.0
#
# 时段 197 的统计结果:
# 所有机组的出力累加: 1739.4122190640298
# 所有负荷的需求累加: 1392.4166670000009
# 所有负荷的切负荷量累加: 0.0
#
# 时段 198 的统计结果:
# 所有机组的出力累加: 1685.159044606591
# 所有负荷的需求累加: 1349.0833340000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 199 的统计结果:
# 所有机组的出力累加: 1646.6274767354846
# 所有负荷的需求累加: 1265.9166669999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 200 的统计结果:
# 所有机组的出力累加: 1632.2111872071025
# 所有负荷的需求累加: 1235.25
# 所有负荷的切负荷量累加: 0.0
#
# 时段 201 的统计结果:
# 所有机组的出力累加: 1653.4211833983654
# 所有负荷的需求累加: 1329.8333340000008
# 所有负荷的切负荷量累加: 0.0
#
# 时段 202 的统计结果:
# 所有机组的出力累加: 1641.5227647686193
# 所有负荷的需求累加: 1391.25
# 所有负荷的切负荷量累加: 0.0
#
# 时段 203 的统计结果:
# 所有机组的出力累加: 1666.3372855929147
# 所有负荷的需求累加: 1553.083334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 204 的统计结果:
# 所有机组的出力累加: 1702.4830713536594
# 所有负荷的需求累加: 1693.2500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 205 的统计结果:
# 所有机组的出力累加: 1725.8306805184156
# 所有负荷的需求累加: 1799.9166670000004
# 所有负荷的切负荷量累加: 14.66967510635061
#
# 时段 206 的统计结果:
# 所有机组的出力累加: 1809.4485704161432
# 所有负荷的需求累加: 1804.1666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 207 的统计结果:
# 所有机组的出力累加: 1864.2236912704118
# 所有负荷的需求累加: 1768.7500000000007
# 所有负荷的切负荷量累加: 0.0
#
# 时段 208 的统计结果:
# 所有机组的出力累加: 2026.147819004163
# 所有负荷的需求累加: 1650.0833340000008
# 所有负荷的切负荷量累加: 0.0
#
# 时段 209 的统计结果:
# 所有机组的出力累加: 1972.2548309159156
# 所有负荷的需求累加: 1539.333334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 210 的统计结果:
# 所有机组的出力累加: 1753.921561858557
# 所有负荷的需求累加: 1503.2499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 211 的统计结果:
# 所有机组的出力累加: 1736.5270801376428
# 所有负荷的需求累加: 1522.2499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 212 的统计结果:
# 所有机组的出力累加: 1816.223173789856
# 所有负荷的需求累加: 1510.4166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 213 的统计结果:
# 所有机组的出力累加: 1824.923750636537
# 所有负荷的需求累加: 1534.833334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 214 的统计结果:
# 所有机组的出力累加: 1770.3450557309068
# 所有负荷的需求累加: 1648.8333340000008
# 所有负荷的切负荷量累加: 0.0
#
# 时段 215 的统计结果:
# 所有机组的出力累加: 1826.9461102043483
# 所有负荷的需求累加: 1835.4999999999995
# 所有负荷的切负荷量累加: 1.6700224561736832
#
# 时段 216 的统计结果:
# 所有机组的出力累加: 1872.7291164898907
# 所有负荷的需求累加: 2034.833334
# 所有负荷的切负荷量累加: 77.70625854032807
#
# 时段 217 的统计结果:
# 所有机组的出力累加: 1827.7747443924343
# 所有负荷的需求累加: 1937.916666999999
# 所有负荷的切负荷量累加: 48.85192413512698
#
# 时段 218 的统计结果:
# 所有机组的出力累加: 1710.4862560624924
# 所有负荷的需求累加: 1618.75
# 所有负荷的切负荷量累加: 0.0
#
# 时段 219 的统计结果:
# 所有机组的出力累加: 1600.0763856688914
# 所有负荷的需求累加: 1390.4999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 220 的统计结果:
# 所有机组的出力累加: 1392.8540488144154
# 所有负荷的需求累加: 1230.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 221 的统计结果:
# 所有机组的出力累加: 1319.128629463456
# 所有负荷的需求累加: 1158.1666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 222 的统计结果:
# 所有机组的出力累加: 1307.3726317210444
# 所有负荷的需求累加: 1092.166667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 223 的统计结果:
# 所有机组的出力累加: 1357.137049979983
# 所有负荷的需求累加: 1044.5
# 所有负荷的切负荷量累加: 0.0
#
# 时段 224 的统计结果:
# 所有机组的出力累加: 1320.8280466316776
# 所有负荷的需求累加: 1048.8333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 225 的统计结果:
# 所有机组的出力累加: 1369.1999771897
# 所有负荷的需求累加: 1055.4166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 226 的统计结果:
# 所有机组的出力累加: 1412.034867103076
# 所有负荷的需求累加: 1126.4166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 227 的统计结果:
# 所有机组的出力累加: 1389.9135057672688
# 所有负荷的需求累加: 1273.75
# 所有负荷的切负荷量累加: 0.0
#
# 时段 228 的统计结果:
# 所有机组的出力累加: 1420.474379252786
# 所有负荷的需求累加: 1442.5833339999997
# 所有负荷的切负荷量累加: 4.416664189372852
#
# 时段 229 的统计结果:
# 所有机组的出力累加: 1467.5694063224128
# 所有负荷的需求累加: 1525.5833339999997
# 所有负荷的切负荷量累加: 11.646006122897063
#
# 时段 230 的统计结果:
# 所有机组的出力累加: 1493.6875914026314
# 所有负荷的需求累加: 1539.5833340000001
# 所有负荷的切负荷量累加: 9.206051531411049
#
# 时段 231 的统计结果:
# 所有机组的出力累加: 1539.5997956754359
# 所有负荷的需求累加: 1450.333334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 232 的统计结果:
# 所有机组的出力累加: 1560.2732304853307
# 所有负荷的需求累加: 1307.8333339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 233 的统计结果:
# 所有机组的出力累加: 1618.6921300760537
# 所有负荷的需求累加: 1164.5833340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 234 的统计结果:
# 所有机组的出力累加: 1341.071042691246
# 所有负荷的需求累加: 1092.6666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 235 的统计结果:
# 所有机组的出力累加: 1383.3579420805622
# 所有负荷的需求累加: 1085.9166670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 236 的统计结果:
# 所有机组的出力累加: 1405.4687615342325
# 所有负荷的需求累加: 1105.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 237 的统计结果:
# 所有机组的出力累加: 1403.3631204216322
# 所有负荷的需求累加: 1126.3333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 238 的统计结果:
# 所有机组的出力累加: 1353.4305775967846
# 所有负荷的需求累加: 1223.666667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 239 的统计结果:
# 所有机组的出力累加: 1377.8479763726177
# 所有负荷的需求累加: 1404.6666670000006
# 所有负荷的切负荷量累加: 5.364953195475891
#
# 时段 240 的统计结果:
# 所有机组的出力累加: 1518.40779637969
# 所有负荷的需求累加: 1689.2499999999993
# 所有负荷的切负荷量累加: 73.6050066224596
#
# 时段 241 的统计结果:
# 所有机组的出力累加: 1494.230583600038
# 所有负荷的需求累加: 1625.583334
# 所有负荷的切负荷量累加: 43.91825172461614
#
# 时段 242 的统计结果:
# 所有机组的出力累加: 1426.6756839984223
# 所有负荷的需求累加: 1404.916667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 243 的统计结果:
# 所有机组的出力累加: 1401.323586450063
# 所有负荷的需求累加: 1300.6666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 244 的统计结果:
# 所有机组的出力累加: 1316.8803568786159
# 所有负荷的需求累加: 1214.6666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 245 的统计结果:
# 所有机组的出力累加: 1277.1072055219413
# 所有负荷的需求累加: 1136.1666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 246 的统计结果:
# 所有机组的出力累加: 1231.2894220644548
# 所有负荷的需求累加: 1083.2499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 247 的统计结果:
# 所有机组的出力累加: 1233.8138858301866
# 所有负荷的需求累加: 1047.9999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 248 的统计结果:
# 所有机组的出力累加: 1197.2414558315604
# 所有负荷的需求累加: 1017.75
# 所有负荷的切负荷量累加: 0.0
#
# 时段 249 的统计结果:
# 所有机组的出力累加: 1154.1233956857222
# 所有负荷的需求累加: 1009.583334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 250 的统计结果:
# 所有机组的出力累加: 1142.9529330925056
# 所有负荷的需求累加: 1043.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 251 的统计结果:
# 所有机组的出力累加: 1191.3874436685576
# 所有负荷的需求累加: 1108.7500000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 252 的统计结果:
# 所有机组的出力累加: 1288.356797281706
# 所有负荷的需求累加: 1247.3333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 253 的统计结果:
# 所有机组的出力累加: 1438.837567889
# 所有负荷的需求累加: 1381.9999999999984
# 所有负荷的切负荷量累加: 0.0
#
# 时段 254 的统计结果:
# 所有机组的出力累加: 1601.3988634684067
# 所有负荷的需求累加: 1417.9166670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 255 的统计结果:
# 所有机组的出力累加: 1633.7696705193475
# 所有负荷的需求累加: 1408.7500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 256 的统计结果:
# 所有机组的出力累加: 1737.37431310638
# 所有负荷的需求累加: 1348.2500000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 257 的统计结果:
# 所有机组的出力累加: 1675.6796777543332
# 所有负荷的需求累加: 1274.916667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 258 的统计结果:
# 所有机组的出力累加: 1415.2750397630448
# 所有负荷的需求累加: 1238.1666670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 259 的统计结果:
# 所有机组的出力累加: 1569.8413142363947
# 所有负荷的需求累加: 1262.8333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 260 的统计结果:
# 所有机组的出力累加: 1666.4574107824562
# 所有负荷的需求累加: 1329.6666669999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 261 的统计结果:
# 所有机组的出力累加: 1668.2434931240607
# 所有负荷的需求累加: 1415.6666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 262 的统计结果:
# 所有机组的出力累加: 1782.4984778556711
# 所有负荷的需求累加: 1489.2499999999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 263 的统计结果:
# 所有机组的出力累加: 1829.1686146767872
# 所有负荷的需求累加: 1625.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 264 的统计结果:
# 所有机组的出力累加: 1863.0090145767003
# 所有负荷的需求累加: 1826.916667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 265 的统计结果:
# 所有机组的出力累加: 1830.4147679268804
# 所有负荷的需求累加: 1885.583334
# 所有负荷的切负荷量累加: 23.492345115495993
#
# 时段 266 的统计结果:
# 所有机组的出力累加: 1648.1313371764068
# 所有负荷的需求累加: 1759.0000000000007
# 所有负荷的切负荷量累加: 35.22081478001019
#
# 时段 267 的统计结果:
# 所有机组的出力累加: 1575.0920341529934
# 所有负荷的需求累加: 1590.0000000000005
# 所有负荷的切负荷量累加: 2.927266034378249
#
# 时段 268 的统计结果:
# 所有机组的出力累加: 1480.6410704485263
# 所有负荷的需求累加: 1466.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 269 的统计结果:
# 所有机组的出力累加: 1339.3481684800647
# 所有负荷的需求累加: 1342.666667
# 所有负荷的切负荷量累加: 0.5915797024713356
#
# 时段 270 的统计结果:
# 所有机组的出力累加: 1231.988239232058
# 所有负荷的需求累加: 1249.4999999999995
# 所有负荷的切负荷量累加: 3.955067171821156
#
# 时段 271 的统计结果:
# 所有机组的出力累加: 1096.1987900007334
# 所有负荷的需求累加: 1186.9166669999993
# 所有负荷的切负荷量累加: 9.125475351435739
#
# 时段 272 的统计结果:
# 所有机组的出力累加: 1003.6163955412042
# 所有负荷的需求累加: 1129.6666669999997
# 所有负荷的切负荷量累加: 7.9684727342387305
#
# 时段 273 的统计结果:
# 所有机组的出力累加: 968.213191443715
# 所有负荷的需求累加: 1109.7499999999995
# 所有负荷的切负荷量累加: 6.9734337667900945
#
# 时段 274 的统计结果:
# 所有机组的出力累加: 921.8527371071734
# 所有负荷的需求累加: 1135.4166669999997
# 所有负荷的切负荷量累加: 83.17764174984706
#
# 时段 275 的统计结果:
# 所有机组的出力累加: 966.8394860342719
# 所有负荷的需求累加: 1173.0000000000002
# 所有负荷的切负荷量累加: 78.6844491171023
#
# 时段 276 的统计结果:
# 所有机组的出力累加: 1040.2345810543593
# 所有负荷的需求累加: 1268.9166669999981
# 所有负荷的切负荷量累加: 97.3678929609664
#
# 时段 277 的统计结果:
# 所有机组的出力累加: 1102.0041847067978
# 所有负荷的需求累加: 1361.8333340000001
# 所有负荷的切负荷量累加: 123.42484558825515
#
# 时段 278 的统计结果:
# 所有机组的出力累加: 1174.9779985786704
# 所有负荷的需求累加: 1340.1666670000004
# 所有负荷的切负荷量累加: 49.28522767032723
#
# 时段 279 的统计结果:
# 所有机组的出力累加: 1143.3026967487904
# 所有负荷的需求累加: 1238.9999999999989
# 所有负荷的切负荷量累加: 16.578435759840772
#
# 时段 280 的统计结果:
# 所有机组的出力累加: 1199.4580610939156
# 所有负荷的需求累加: 1089.166667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 281 的统计结果:
# 所有机组的出力累加: 1260.8288143055602
# 所有负荷的需求累加: 972.5833335000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 282 的统计结果:
# 所有机组的出力累加: 930.7949385307564
# 所有负荷的需求累加: 880.3333334999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 283 的统计结果:
# 所有机组的出力累加: 1003.2942210581057
# 所有负荷的需求累加: 839.9999999999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 284 的统计结果:
# 所有机组的出力累加: 966.8815862245697
# 所有负荷的需求累加: 814.0833335000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 285 的统计结果:
# 所有机组的出力累加: 987.3325984178158
# 所有负荷的需求累加: 822.8333335000003
# 所有负荷的切负荷量累加: 0.0
#
# 时段 286 的统计结果:
# 所有机组的出力累加: 1104.0502082172466
# 所有负荷的需求累加: 855.9166664999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 287 的统计结果:
# 所有机组的出力累加: 1146.7072918066863
# 所有负荷的需求累加: 911.2499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 288 的统计结果:
# 所有机组的出力累加: 1167.295507399926
# 所有负荷的需求累加: 1051.0000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 289 的统计结果:
# 所有机组的出力累加: 1198.9068390249267
# 所有负荷的需求累加: 1256.2499999999998
# 所有负荷的切负荷量累加: 14.061995890894082
#
# 时段 290 的统计结果:
# 所有机组的出力累加: 1334.8173202935113
# 所有负荷的需求累加: 1411.6666670000006
# 所有负荷的切负荷量累加: 15.438452503103349
#
# 时段 291 的统计结果:
# 所有机组的出力累加: 1329.8316888239474
# 所有负荷的需求累加: 1442.4166670000004
# 所有负荷的切负荷量累加: 27.613897516061343
#
# 时段 292 的统计结果:
# 所有机组的出力累加: 1280.0170062640361
# 所有负荷的需求累加: 1388.9166670000004
# 所有负荷的切负荷量累加: 24.75683358500669
#
# 时段 293 的统计结果:
# 所有机组的出力累加: 1355.8162342988044
# 所有负荷的需求累加: 1316.0833339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 294 的统计结果:
# 所有机组的出力累加: 1406.473632189636
# 所有负荷的需求累加: 1303.8333340000013
# 所有负荷的切负荷量累加: 0.0
#
# 时段 295 的统计结果:
# 所有机组的出力累加: 1372.442576812889
# 所有负荷的需求累加: 1266.5833339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 296 的统计结果:
# 所有机组的出力累加: 1414.1751914152042
# 所有负荷的需求累加: 1229.3333340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 297 的统计结果:
# 所有机组的出力累加: 1441.2084081514427
# 所有负荷的需求累加: 1244.3333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 298 的统计结果:
# 所有机组的出力累加: 1498.1620585507333
# 所有负荷的需求累加: 1286.4166669999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 299 的统计结果:
# 所有机组的出力累加: 1630.339224748232
# 所有负荷的需求累加: 1430.5833340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 300 的统计结果:
# 所有机组的出力累加: 1732.2131332919396
# 所有负荷的需求累加: 1655.2499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 301 的统计结果:
# 所有机组的出力累加: 1833.1323049777698
# 所有负荷的需求累加: 1824.3333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 302 的统计结果:
# 所有机组的出力累加: 1861.9511135602743
# 所有负荷的需求累加: 1817.6666669999988
# 所有负荷的切负荷量累加: 0.0
#
# 时段 303 的统计结果:
# 所有机组的出力累加: 1962.976770184059
# 所有负荷的需求累加: 1728.3333339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 304 的统计结果:
# 所有机组的出力累加: 1983.1447598513237
# 所有负荷的需求累加: 1630.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 305 的统计结果:
# 所有机组的出力累加: 2018.5698295926495
# 所有负荷的需求累加: 1556.666667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 306 的统计结果:
# 所有机组的出力累加: 1699.668602653745
# 所有负荷的需求累加: 1518.3333339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 307 的统计结果:
# 所有机组的出力累加: 1797.2680926485152
# 所有负荷的需求累加: 1520.4166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 308 的统计结果:
# 所有机组的出力累加: 1783.37077395787
# 所有负荷的需求累加: 1546.0833340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 309 的统计结果:
# 所有机组的出力累加: 1838.5473008079537
# 所有负荷的需求累加: 1596.8333340000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 310 的统计结果:
# 所有机组的出力累加: 1985.6754475563528
# 所有负荷的需求累加: 1704.833334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 311 的统计结果:
# 所有机组的出力累加: 1957.6562122008206
# 所有负荷的需求累加: 1910.9166670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 312 的统计结果:
# 所有机组的出力累加: 1912.427002080967
# 所有负荷的需求累加: 2177.0000000000005
# 所有负荷的切负荷量累加: 148.71181849927893
#
# 时段 313 的统计结果:
# 所有机组的出力累加: 1894.290036665175
# 所有负荷的需求累加: 2151.3333340000013
# 所有负荷的切负荷量累加: 143.4941258111113
#
# 时段 314 的统计结果:
# 所有机组的出力累加: 1886.108274529818
# 所有负荷的需求累加: 2041.0
# 所有负荷的切负荷量累加: 72.70837495128927
#
# 时段 315 的统计结果:
# 所有机组的出力累加: 1879.5569113255929
# 所有负荷的需求累加: 1887.4999999999993
# 所有负荷的切负荷量累加: 0.299752146741298
#
# 时段 316 的统计结果:
# 所有机组的出力累加: 1823.8046863358343
# 所有负荷的需求累加: 1719.5833339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 317 的统计结果:
# 所有机组的出力累加: 1744.0547347103848
# 所有负荷的需求累加: 1580.3333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 318 的统计结果:
# 所有机组的出力累加: 1774.7834235295636
# 所有负荷的需求累加: 1489.3333339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 319 的统计结果:
# 所有机组的出力累加: 1623.7226185146642
# 所有负荷的需求累加: 1408.333334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 320 的统计结果:
# 所有机组的出力累加: 1646.1540593694533
# 所有负荷的需求累加: 1350.3333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 321 的统计结果:
# 所有机组的出力累加: 1726.3744698076832
# 所有负荷的需求累加: 1330.3333339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 322 的统计结果:
# 所有机组的出力累加: 1707.990006938485
# 所有负荷的需求累加: 1381.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 323 的统计结果:
# 所有机组的出力累加: 1719.6782103549263
# 所有负荷的需求累加: 1521.0833340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 324 的统计结果:
# 所有机组的出力累加: 1797.131256635521
# 所有负荷的需求累加: 1797.9166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 325 的统计结果:
# 所有机组的出力累加: 1842.9489351029526
# 所有负荷的需求累加: 2016.7500000000005
# 所有负荷的切负荷量累加: 85.81156822733226
#
# 时段 326 的统计结果:
# 所有机组的出力累加: 2032.3600464899973
# 所有负荷的需求累加: 2051.666666999999
# 所有负荷的切负荷量累加: 6.228399397620763
#
# 时段 327 的统计结果:
# 所有机组的出力累加: 1937.3542634429923
# 所有负荷的需求累加: 1996.6666670000006
# 所有负荷的切负荷量累加: 27.410774483993293
#
# 时段 328 的统计结果:
# 所有机组的出力累加: 2117.3364073557736
# 所有负荷的需求累加: 1883.8333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 329 的统计结果:
# 所有机组的出力累加: 2200.0464821833075
# 所有负荷的需求累加: 1804.3333340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 330 的统计结果:
# 所有机组的出力累加: 1834.472338690698
# 所有负荷的需求累加: 1790.8333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 331 的统计结果:
# 所有机组的出力累加: 1965.7043801610569
# 所有负荷的需求累加: 1837.8333339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 332 的统计结果:
# 所有机组的出力累加: 1958.2043158081017
# 所有负荷的需求累加: 1884.0833339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 333 的统计结果:
# 所有机组的出力累加: 2047.4800792274148
# 所有负荷的需求累加: 1946.666667000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 334 的统计结果:
# 所有机组的出力累加: 2053.031229806422
# 所有负荷的需求累加: 2047.1666669999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 335 的统计结果:
# 所有机组的出力累加: 2064.384473066331
# 所有负荷的需求累加: 2279.5
# 所有负荷的切负荷量累加: 114.44035154656325
#
# 时段 336 的统计结果:
# 所有机组的出力累加: 2074.0917164245543
# 所有负荷的需求累加: 2571.5000000000005
# 所有负荷的切负荷量累加: 354.816290555554
#
# 时段 337 的统计结果:
# 所有机组的出力累加: 2100.488407811542
# 所有负荷的需求累加: 2346.083334
# 所有负荷的切负荷量累加: 135.56099729507378
#
# 时段 338 的统计结果:
# 所有机组的出力累加: 1899.2933209153089
# 所有负荷的需求累加: 1926.0833339999995
# 所有负荷的切负荷量累加: 10.19072725030469
#
# 时段 339 的统计结果:
# 所有机组的出力累加: 1812.627789168133
# 所有负荷的需求累加: 1666.0000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 340 的统计结果:
# 所有机组的出力累加: 1754.2561782530547
# 所有负荷的需求累加: 1491.4999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 341 的统计结果:
# 所有机组的出力累加: 1642.1442186037016
# 所有负荷的需求累加: 1317.9166669999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 342 的统计结果:
# 所有机组的出力累加: 1619.1306060189393
# 所有负荷的需求累加: 1225.9166670000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 343 的统计结果:
# 所有机组的出力累加: 1529.0892078821744
# 所有负荷的需求累加: 1175.7500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 344 的统计结果:
# 所有机组的出力累加: 1454.1995974495626
# 所有负荷的需求累加: 1110.7499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 345 的统计结果:
# 所有机组的出力累加: 1411.4722928852154
# 所有负荷的需求累加: 1100.1666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 346 的统计结果:
# 所有机组的出力累加: 1385.734485558116
# 所有负荷的需求累加: 1150.8333340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 347 的统计结果:
# 所有机组的出力累加: 1368.7723942994144
# 所有负荷的需求累加: 1239.333334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 348 的统计结果:
# 所有机组的出力累加: 1428.3928706401969
# 所有负荷的需求累加: 1451.9166670000002
# 所有负荷的切负荷量累加: 4.701537647402688
#
# 时段 349 的统计结果:
# 所有机组的出力累加: 1754.6601201555668
# 所有负荷的需求累加: 1666.9166670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 350 的统计结果:
# 所有机组的出力累加: 1862.6845194198518
# 所有负荷的需求累加: 1706.5833339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 351 的统计结果:
# 所有机组的出力累加: 1917.3608191452277
# 所有负荷的需求累加: 1673.6666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 352 的统计结果:
# 所有机组的出力累加: 1993.7217777244955
# 所有负荷的需求累加: 1568.0833339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 353 的统计结果:
# 所有机组的出力累加: 2102.7058597517475
# 所有负荷的需求累加: 1471.1666669999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 354 的统计结果:
# 所有机组的出力累加: 1721.543635689848
# 所有负荷的需求累加: 1460.2500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 355 的统计结果:
# 所有机组的出力累加: 1747.7355448890398
# 所有负荷的需求累加: 1487.5833340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 356 的统计结果:
# 所有机组的出力累加: 1734.0411640581146
# 所有负荷的需求累加: 1539.75
# 所有负荷的切负荷量累加: 0.0
#
# 时段 357 的统计结果:
# 所有机组的出力累加: 1782.3336963439765
# 所有负荷的需求累加: 1605.0833339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 358 的统计结果:
# 所有机组的出力累加: 1785.8410002207186
# 所有负荷的需求累加: 1703.7499999999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 359 的统计结果:
# 所有机组的出力累加: 1862.0646446405297
# 所有负荷的需求累加: 1886.0833339999995
# 所有负荷的切负荷量累加: 8.723358930966924
#
# 时段 360 的统计结果:
# 所有机组的出力累加: 1935.9667478318347
# 所有负荷的需求累加: 2155.333334
# 所有负荷的切负荷量累加: 117.38611551642282
#
# 时段 361 的统计结果:
# 所有机组的出力累加: 1953.2255340522595
# 所有负荷的需求累加: 2053.5
# 所有负荷的切负荷量累加: 48.057246110851395
#
# 时段 362 的统计结果:
# 所有机组的出力累加: 1655.2477792112463
# 所有负荷的需求累加: 1701.3333339999995
# 所有负荷的切负荷量累加: 9.112180324934798
#
# 时段 363 的统计结果:
# 所有机组的出力累加: 1526.4916041905258
# 所有负荷的需求累加: 1467.9999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 364 的统计结果:
# 所有机组的出力累加: 1360.3367546527818
# 所有负荷的需求累加: 1299.083334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 365 的统计结果:
# 所有机组的出力累加: 1223.261823217336
# 所有负荷的需求累加: 1213.9999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 366 的统计结果:
# 所有机组的出力累加: 1179.5430238096621
# 所有负荷的需求累加: 1121.9166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 367 的统计结果:
# 所有机组的出力累加: 1147.1372653655526
# 所有负荷的需求累加: 1073.5
# 所有负荷的切负荷量累加: 0.0
#
# 时段 368 的统计结果:
# 所有机组的出力累加: 1067.2479794705173
# 所有负荷的需求累加: 1041.833334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 369 的统计结果:
# 所有机组的出力累加: 1065.5115521845569
# 所有负荷的需求累加: 1071.416667000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 370 的统计结果:
# 所有机组的出力累加: 1039.2206187520692
# 所有负荷的需求累加: 1132.8333340000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 371 的统计结果:
# 所有机组的出力累加: 1133.9288696067483
# 所有负荷的需求累加: 1196.7499999999993
# 所有负荷的切负荷量累加: 8.933866387300213
#
# 时段 372 的统计结果:
# 所有机组的出力累加: 1194.8407526404121
# 所有负荷的需求累加: 1349.2500000000002
# 所有负荷的切负荷量累加: 41.336424247468244
#
# 时段 373 的统计结果:
# 所有机组的出力累加: 1348.9550048897945
# 所有负荷的需求累加: 1494.0833339999995
# 所有负荷的切负荷量累加: 52.84332094054753
#
# 时段 374 的统计结果:
# 所有机组的出力累加: 1565.1685364160494
# 所有负荷的需求累加: 1486.083334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 375 的统计结果:
# 所有机组的出力累加: 1582.689887944626
# 所有负荷的需求累加: 1444.3333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 376 的统计结果:
# 所有机组的出力累加: 1599.476899553644
# 所有负荷的需求累加: 1308.7499999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 377 的统计结果:
# 所有机组的出力累加: 1626.9150452524284
# 所有负荷的需求累加: 1178.4999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 378 的统计结果:
# 所有机组的出力累加: 1269.2760101660965
# 所有负荷的需求累加: 1131.916667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 379 的统计结果:
# 所有机组的出力累加: 1254.9568345707141
# 所有负荷的需求累加: 1119.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 380 的统计结果:
# 所有机组的出力累加: 1272.3304783413719
# 所有负荷的需求累加: 1128.1666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 381 的统计结果:
# 所有机组的出力累加: 1390.2405794584022
# 所有负荷的需求累加: 1135.3333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 382 的统计结果:
# 所有机组的出力累加: 1358.3896276940368
# 所有负荷的需求累加: 1182.7500000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 383 的统计结果:
# 所有机组的出力累加: 1424.407657402756
# 所有负荷的需求累加: 1326.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 384 的统计结果:
# 所有机组的出力累加: 1478.802024559228
# 所有负荷的需求累加: 1595.0833340000001
# 所有负荷的切负荷量累加: 31.256119674453203
#
# 时段 385 的统计结果:
# 所有机组的出力累加: 1493.496700200462
# 所有负荷的需求累加: 1557.833334
# 所有负荷的切负荷量累加: 12.919061100252463
#
# 时段 386 的统计结果:
# 所有机组的出力累加: 1434.8208019252174
# 所有负荷的需求累加: 1314.9166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 387 的统计结果:
# 所有机组的出力累加: 1351.7160306691987
# 所有负荷的需求累加: 1145.4166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 388 的统计结果:
# 所有机组的出力累加: 1182.279043088694
# 所有负荷的需求累加: 1063.3333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 389 的统计结果:
# 所有机组的出力累加: 1017.0357816532469
# 所有负荷的需求累加: 1034.4999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 390 的统计结果:
# 所有机组的出力累加: 918.445043413016
# 所有负荷的需求累加: 997.1666665000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 391 的统计结果:
# 所有机组的出力累加: 877.6153024175477
# 所有负荷的需求累加: 977.75
# 所有负荷的切负荷量累加: 0.0
#
# 时段 392 的统计结果:
# 所有机组的出力累加: 807.5205680621712
# 所有负荷的需求累加: 960.4166664999999
# 所有负荷的切负荷量累加: 11.603884693670352
#
# 时段 393 的统计结果:
# 所有机组的出力累加: 828.3356725441486
# 所有负荷的需求累加: 986.4166665000001
# 所有负荷的切负荷量累加: 12.441959422419131
#
# 时段 394 的统计结果:
# 所有机组的出力累加: 852.1180607110699
# 所有负荷的需求累加: 1042.916667
# 所有负荷的切负荷量累加: 63.60130297659225
#
# 时段 395 的统计结果:
# 所有机组的出力累加: 832.3696865554639
# 所有负荷的需求累加: 1115.1666670000002
# 所有负荷的切负荷量累加: 132.79698044453858
#
# 时段 396 的统计结果:
# 所有机组的出力累加: 943.2052947667328
# 所有负荷的需求累加: 1206.666667
# 所有负荷的切负荷量累加: 127.48672620347014
#
# 时段 397 的统计结果:
# 所有机组的出力累加: 1171.7714324753483
# 所有负荷的需求累加: 1352.9166669999997
# 所有负荷的切负荷量累加: 59.48982930721763
#
# 时段 398 的统计结果:
# 所有机组的出力累加: 1301.6415698938588
# 所有负荷的需求累加: 1341.083334
# 所有负荷的切负荷量累加: 7.906565317198556
#
# 时段 399 的统计结果:
# 所有机组的出力累加: 1362.3419120495523
# 所有负荷的需求累加: 1244.8333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 400 的统计结果:
# 所有机组的出力累加: 1455.7525682803152
# 所有负荷的需求累加: 1079.4166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 401 的统计结果:
# 所有机组的出力累加: 1407.2877206530625
# 所有负荷的需求累加: 931.9166664999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 402 的统计结果:
# 所有机组的出力累加: 1008.7838857813649
# 所有负荷的需求累加: 842.4166665000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 403 的统计结果:
# 所有机组的出力累加: 1086.4852753801615
# 所有负荷的需求累加: 810.6666665
# 所有负荷的切负荷量累加: 0.0
#
# 时段 404 的统计结果:
# 所有机组的出力累加: 1151.2329795868864
# 所有负荷的需求累加: 807.1666664999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 405 的统计结果:
# 所有机组的出力累加: 1249.165357565491
# 所有负荷的需求累加: 824.3333335
# 所有负荷的切负荷量累加: 0.0
#
# 时段 406 的统计结果:
# 所有机组的出力累加: 1370.8505736305422
# 所有负荷的需求累加: 882.3333335
# 所有负荷的切负荷量累加: 0.0
#
# 时段 407 的统计结果:
# 所有机组的出力累加: 1373.0527489721778
# 所有负荷的需求累加: 1077.083334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 408 的统计结果:
# 所有机组的出力累加: 1491.384517725993
# 所有负荷的需求累加: 1365.7499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 409 的统计结果:
# 所有机组的出力累加: 1469.3955639830886
# 所有负荷的需求累加: 1358.1666670000009
# 所有负荷的切负荷量累加: 0.0
#
# 时段 410 的统计结果:
# 所有机组的出力累加: 1265.38043158942
# 所有负荷的需求累加: 1208.8333340000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 411 的统计结果:
# 所有机组的出力累加: 1103.9518756693053
# 所有负荷的需求累加: 1116.5
# 所有负荷的切负荷量累加: 0.0
#
# 时段 412 的统计结果:
# 所有机组的出力累加: 951.6519408743754
# 所有负荷的需求累加: 1059.2499999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 413 的统计结果:
# 所有机组的出力累加: 864.7210092949742
# 所有负荷的需求累加: 989.4166664999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 414 的统计结果:
# 所有机组的出力累加: 814.8387206791557
# 所有负荷的需求累加: 975.8333334999998
# 所有负荷的切负荷量累加: 16.90865952271315
#
# 时段 415 的统计结果:
# 所有机组的出力累加: 763.134559950332
# 所有负荷的需求累加: 983.3333334999996
# 所有负荷的切负荷量累加: 72.37447940688048
#
# 时段 416 的统计结果:
# 所有机组的出力累加: 801.9513996150538
# 所有负荷的需求累加: 1006.5833340000001
# 所有负荷的切负荷量累加: 66.50441190811307
#
# 时段 417 的统计结果:
# 所有机组的出力累加: 770.0509634484883
# 所有负荷的需求累加: 1014.2500000000002
# 所有负荷的切负荷量累加: 94.86671529271916
#
# 时段 418 的统计结果:
# 所有机组的出力累加: 780.7991586504816
# 所有负荷的需求累加: 1057.5833339999997
# 所有负荷的切负荷量累加: 126.7841753495236
#
# 时段 419 的统计结果:
# 所有机组的出力累加: 809.3679565282614
# 所有负荷的需求累加: 1104.75
# 所有负荷的切负荷量累加: 145.38204347174204
#
# 时段 420 的统计结果:
# 所有机组的出力累加: 855.2255210577691
# 所有负荷的需求累加: 1192.0000000000002
# 所有负荷的切负荷量累加: 186.77447894223354
#
# 时段 421 的统计结果:
# 所有机组的出力累加: 1064.8609604486223
# 所有负荷的需求累加: 1305.5833339999995
# 所有负荷的切负荷量累加: 94.71857501109793
#
# 时段 422 的统计结果:
# 所有机组的出力累加: 1211.8468345556853
# 所有负荷的需求累加: 1267.1666670000006
# 所有负荷的切负荷量累加: 13.31878041245534
#
# 时段 423 的统计结果:
# 所有机组的出力累加: 1210.4827135066928
# 所有负荷的需求累加: 1175.6666669999993
# 所有负荷的切负荷量累加: 0.0
#
# 时段 424 的统计结果:
# 所有机组的出力累加: 1293.2399346881868
# 所有负荷的需求累加: 1047.9999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 425 的统计结果:
# 所有机组的出力累加: 1375.064020343271
# 所有负荷的需求累加: 919.9166664999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 426 的统计结果:
# 所有机组的出力累加: 996.9926781580295
# 所有负荷的需求累加: 846.1666665
# 所有负荷的切负荷量累加: 0.0
#
# 时段 427 的统计结果:
# 所有机组的出力累加: 1076.9449468918917
# 所有负荷的需求累加: 789.0833334999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 428 的统计结果:
# 所有机组的出力累加: 1078.9659424327656
# 所有负荷的需求累加: 764.0000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 429 的统计结果:
# 所有机组的出力累加: 1111.0887537466078
# 所有负荷的需求累加: 771.7500000000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 430 的统计结果:
# 所有机组的出力累加: 1090.7177552170278
# 所有负荷的需求累加: 784.75
# 所有负荷的切负荷量累加: 0.0
#
# 时段 431 的统计结果:
# 所有机组的出力累加: 1064.8022826159336
# 所有负荷的需求累加: 856.1666665
# 所有负荷的切负荷量累加: 0.0
#
# 时段 432 的统计结果:
# 所有机组的出力累加: 1195.975805441038
# 所有负荷的需求累加: 968.5000000000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 433 的统计结果:
# 所有机组的出力累加: 1170.1508146934502
# 所有负荷的需求累加: 1125.5
# 所有负荷的切负荷量累加: 0.0
#
# 时段 434 的统计结果:
# 所有机组的出力累加: 1101.749582065572
# 所有负荷的需求累加: 1221.166667
# 所有负荷的切负荷量累加: 13.93051752213114
#
# 时段 435 的统计结果:
# 所有机组的出力累加: 995.6686452573523
# 所有负荷的需求累加: 1253.8333340000001
# 所有负荷的切负荷量累加: 120.15373434718458
#
# 时段 436 的统计结果:
# 所有机组的出力累加: 944.599351833625
# 所有负荷的需求累加: 1279.5833340000004
# 所有负荷的切负荷量累加: 184.98398216637707
#
# 时段 437 的统计结果:
# 所有机组的出力累加: 1025.5998753525291
# 所有负荷的需求累加: 1244.0833339999986
# 所有负荷的切负荷量累加: 76.69967862092199
#
# 时段 438 的统计结果:
# 所有机组的出力累加: 959.4769494841255
# 所有负荷的需求累加: 1215.5000000000005
# 所有负荷的切负荷量累加: 106.02305051587864
#
# 时段 439 的统计结果:
# 所有机组的出力累加: 911.919839012094
# 所有负荷的需求累加: 1177.5833340000004
# 所有负荷的切负荷量累加: 119.15855142813842
#
# 时段 440 的统计结果:
# 所有机组的出力累加: 951.3663195696864
# 所有负荷的需求累加: 1162.3333339999997
# 所有负荷的切负荷量累加: 61.99261579060828
#
# 时段 441 的统计结果:
# 所有机组的出力累加: 1021.6357727165994
# 所有负荷的需求累加: 1183.5
# 所有负荷的切负荷量累加: 35.66239026785155
#
# 时段 442 的统计结果:
# 所有机组的出力累加: 1080.829948869086
# 所有负荷的需求累加: 1220.083334
# 所有负荷的切负荷量累加: 21.51409132625065
#
# 时段 443 的统计结果:
# 所有机组的出力累加: 1108.7004031780532
# 所有负荷的需求累加: 1247.083334
# 所有负荷的切负荷量累加: 22.74654320597017
#
# 时段 444 的统计结果:
# 所有机组的出力累加: 1137.261981231954
# 所有负荷的需求累加: 1290.5833340000008
# 所有负荷的切负荷量累加: 37.20613416490335
#
# 时段 445 的统计结果:
# 所有机组的出力累加: 1148.2321530976274
# 所有负荷的需求累加: 1328.5833340000004
# 所有负荷的切负荷量累加: 58.443462106347965
#
# 时段 446 的统计结果:
# 所有机组的出力累加: 1142.5161195789926
# 所有负荷的需求累加: 1270.5000000000002
# 所有负荷的切负荷量累加: 23.180610125312
#
# 时段 447 的统计结果:
# 所有机组的出力累加: 1150.6374712264655
# 所有负荷的需求累加: 1173.083334
# 所有负荷的切负荷量累加: 1.886374374738807
#
# 时段 448 的统计结果:
# 所有机组的出力累加: 1230.5579693339964
# 所有负荷的需求累加: 1087.2500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 449 的统计结果:
# 所有机组的出力累加: 1285.8290068968395
# 所有负荷的需求累加: 984.0833335000003
# 所有负荷的切负荷量累加: 0.0
#
# 时段 450 的统计结果:
# 所有机组的出力累加: 836.443745614019
# 所有负荷的需求累加: 866.5000000000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 451 的统计结果:
# 所有机组的出力累加: 948.0705007651466
# 所有负荷的需求累加: 816.4166664999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 452 的统计结果:
# 所有机组的出力累加: 1057.1792424568957
# 所有负荷的需求累加: 802.3333335000003
# 所有负荷的切负荷量累加: 0.0
#
# 时段 453 的统计结果:
# 所有机组的出力累加: 1187.6127707839487
# 所有负荷的需求累加: 812.25
# 所有负荷的切负荷量累加: 0.0
#
# 时段 454 的统计结果:
# 所有机组的出力累加: 1183.7185052665259
# 所有负荷的需求累加: 836.5000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 455 的统计结果:
# 所有机组的出力累加: 1065.7023643218122
# 所有负荷的需求累加: 869.75
# 所有负荷的切负荷量累加: 0.0
#
# 时段 456 的统计结果:
# 所有机组的出力累加: 1097.1727199320876
# 所有负荷的需求累加: 981.3333335
# 所有负荷的切负荷量累加: 0.0
#
# 时段 457 的统计结果:
# 所有机组的出力累加: 1101.5777622685387
# 所有负荷的需求累加: 1148.3333339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 458 的统计结果:
# 所有机组的出力累加: 1116.1298515444778
# 所有负荷的需求累加: 1278.9166670000002
# 所有负荷的切负荷量累加: 42.43756761836539
#
# 时段 459 的统计结果:
# 所有机组的出力累加: 1103.7988496670523
# 所有负荷的需求累加: 1266.7499999999998
# 所有负荷的切负荷量累加: 39.889406663407954
#
# 时段 460 的统计结果:
# 所有机组的出力累加: 1090.4916277842149
# 所有负荷的需求累加: 1198.8333339999992
# 所有负荷的切负荷量累加: 9.953879945610197
#
# 时段 461 的统计结果:
# 所有机组的出力累加: 1011.5606843832651
# 所有负荷的需求累加: 1164.1666670000006
# 所有负荷的切负荷量累加: 20.78629191781198
#
# 时段 462 的统计结果:
# 所有机组的出力累加: 984.6544458220164
# 所有负荷的需求累加: 1141.2500000000002
# 所有负荷的切负荷量累加: 24.660977472583795
#
# 时段 463 的统计结果:
# 所有机组的出力累加: 985.5854859368375
# 所有负荷的需求累加: 1103.3333339999992
# 所有负荷的切负荷量累加: 10.691522618508316
#
# 时段 464 的统计结果:
# 所有机组的出力累加: 979.5280708375291
# 所有负荷的需求累加: 1066.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 465 的统计结果:
# 所有机组的出力累加: 876.2752060586674
# 所有负荷的需求累加: 1029.6666670000002
# 所有负荷的切负荷量累加: 7.140085713592953
#
# 时段 466 的统计结果:
# 所有机组的出力累加: 902.4136235779529
# 所有负荷的需求累加: 1026.4166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 467 的统计结果:
# 所有机组的出力累加: 999.1240182085629
# 所有负荷的需求累加: 1106.0
# 所有负荷的切负荷量累加: 0.0
#
# 时段 468 的统计结果:
# 所有机组的出力累加: 1040.6097925124852
# 所有负荷的需求累加: 1196.6666670000002
# 所有负荷的切负荷量累加: 33.941925179099144
#
# 时段 469 的统计结果:
# 所有机组的出力累加: 1290.3001218103034
# 所有负荷的需求累加: 1337.166667
# 所有负荷的切负荷量累加: 9.401519270755102
#
# 时段 470 的统计结果:
# 所有机组的出力累加: 1404.4659260921658
# 所有负荷的需求累加: 1311.0833340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 471 的统计结果:
# 所有机组的出力累加: 1504.153514322437
# 所有负荷的需求累加: 1196.4166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 472 的统计结果:
# 所有机组的出力累加: 1616.339761638796
# 所有负荷的需求累加: 1082.0833340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 473 的统计结果:
# 所有机组的出力累加: 1719.4707530855455
# 所有负荷的需求累加: 967.4166665
# 所有负荷的切负荷量累加: 0.0
#
# 时段 474 的统计结果:
# 所有机组的出力累加: 1264.2554559180464
# 所有负荷的需求累加: 915.2500000000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 475 的统计结果:
# 所有机组的出力累加: 1339.0499977636862
# 所有负荷的需求累加: 893.8333334999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 476 的统计结果:
# 所有机组的出力累加: 1403.300823982702
# 所有负荷的需求累加: 919.9166664999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 477 的统计结果:
# 所有机组的出力累加: 1439.6754204336542
# 所有负荷的需求累加: 967.0000000000003
# 所有负荷的切负荷量累加: 0.0
#
# 时段 478 的统计结果:
# 所有机组的出力累加: 1434.8742149342283
# 所有负荷的需求累加: 1046.0000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 479 的统计结果:
# 所有机组的出力累加: 1537.700756139618
# 所有负荷的需求累加: 1277.9999999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 480 的统计结果:
# 所有机组的出力累加: 1593.6192941621132
# 所有负荷的需求累加: 1588.5000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 481 的统计结果:
# 所有机组的出力累加: 1564.6129150689067
# 所有负荷的需求累加: 1571.4166670000004
# 所有负荷的切负荷量累加: 1.323732991993495
#
# 时段 482 的统计结果:
# 所有机组的出力累加: 1490.4879746563706
# 所有负荷的需求累加: 1433.5833339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 483 的统计结果:
# 所有机组的出力累加: 1412.2393538764188
# 所有负荷的需求累加: 1249.416667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 484 的统计结果:
# 所有机组的出力累加: 1299.5224194088723
# 所有负荷的需求累加: 1124.8333339999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 485 的统计结果:
# 所有机组的出力累加: 1323.9716472106863
# 所有负荷的需求累加: 1045.4999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 486 的统计结果:
# 所有机组的出力累加: 1273.8151871597238
# 所有负荷的需求累加: 1028.6666670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 487 的统计结果:
# 所有机组的出力累加: 1199.8724535892256
# 所有负荷的需求累加: 1011.3333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 488 的统计结果:
# 所有机组的出力累加: 1166.969686368274
# 所有负荷的需求累加: 1019.1666669999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 489 的统计结果:
# 所有机组的出力累加: 1068.9087785458012
# 所有负荷的需求累加: 1015.1666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 490 的统计结果:
# 所有机组的出力累加: 1159.0154570107431
# 所有负荷的需求累加: 1044.166667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 491 的统计结果:
# 所有机组的出力累加: 1211.3029691194124
# 所有负荷的需求累加: 1107.3333339999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 492 的统计结果:
# 所有机组的出力累加: 1342.6831941078563
# 所有负荷的需求累加: 1224.8333340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 493 的统计结果:
# 所有机组的出力累加: 1511.7901417855978
# 所有负荷的需求累加: 1425.1666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 494 的统计结果:
# 所有机组的出力累加: 1552.2593917562733
# 所有负荷的需求累加: 1387.666667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 495 的统计结果:
# 所有机组的出力累加: 1663.4708822458047
# 所有负荷的需求累加: 1279.5
# 所有负荷的切负荷量累加: 0.0
#
# 时段 496 的统计结果:
# 所有机组的出力累加: 1730.731638058704
# 所有负荷的需求累加: 1122.333334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 497 的统计结果:
# 所有机组的出力累加: 1812.3859898750195
# 所有负荷的需求累加: 1019.8333339999999
# 所有负荷的切负荷量累加: 0.0
#
# 时段 498 的统计结果:
# 所有机组的出力累加: 1422.5199927675335
# 所有负荷的需求累加: 975.1666664999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 499 的统计结果:
# 所有机组的出力累加: 1461.7684347202476
# 所有负荷的需求累加: 963.0000000000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 500 的统计结果:
# 所有机组的出力累加: 1491.7122576657214
# 所有负荷的需求累加: 979.4166664999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 501 的统计结果:
# 所有机组的出力累加: 1592.8846762884186
# 所有负荷的需求累加: 1016.25
# 所有负荷的切负荷量累加: 0.0
#
# 时段 502 的统计结果:
# 所有机组的出力累加: 1580.2683200149825
# 所有负荷的需求累加: 1097.166667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 503 的统计结果:
# 所有机组的出力累加: 1598.445194626024
# 所有负荷的需求累加: 1296.6666669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 504 的统计结果:
# 所有机组的出力累加: 1614.1866855792946
# 所有负荷的需求累加: 1599.9166670000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 505 的统计结果:
# 所有机组的出力累加: 1638.0375008394835
# 所有负荷的需求累加: 1642.1666670000002
# 所有负荷的切负荷量累加: 0.7945284692299879
#
# 时段 506 的统计结果:
# 所有机组的出力累加: 1692.3018689149048
# 所有负荷的需求累加: 1538.9166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 507 的统计结果:
# 所有机组的出力累加: 1696.9445354873822
# 所有负荷的需求累加: 1467.3333340000001
# 所有负荷的切负荷量累加: 0.0
#
# 时段 508 的统计结果:
# 所有机组的出力累加: 1711.9694040439904
# 所有负荷的需求累加: 1439.7500000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 509 的统计结果:
# 所有机组的出力累加: 1671.1430648894852
# 所有负荷的需求累加: 1368.0833339999992
# 所有负荷的切负荷量累加: 0.0
#
# 时段 510 的统计结果:
# 所有机组的出力累加: 1633.6311508977535
# 所有负荷的需求累加: 1323.4166670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 511 的统计结果:
# 所有机组的出力累加: 1536.3519730032174
# 所有负荷的需求累加: 1344.7499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 512 的统计结果:
# 所有机组的出力累加: 1503.9875176120572
# 所有负荷的需求累加: 1339.1666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 513 的统计结果:
# 所有机组的出力累加: 1497.2417580311153
# 所有负荷的需求累加: 1432.9166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 514 的统计结果:
# 所有机组的出力累加: 1560.8560350364605
# 所有负荷的需求累加: 1521.4166669999988
# 所有负荷的切负荷量累加: 0.0
#
# 时段 515 的统计结果:
# 所有机组的出力累加: 1574.167681311346
# 所有负荷的需求累加: 1673.8333339999995
# 所有负荷的切负荷量累加: 28.779698034790442
#
# 时段 516 的统计结果:
# 所有机组的出力累加: 1613.0904205868082
# 所有负荷的需求累加: 1770.4166670000004
# 所有负荷的切负荷量累加: 63.13175496974196
#
# 时段 517 的统计结果:
# 所有机组的出力累加: 1609.974326191011
# 所有负荷的需求累加: 1814.5833340000001
# 所有负荷的切负荷量累加: 99.77024467084215
#
# 时段 518 的统计结果:
# 所有机组的出力累加: 1701.9508795040722
# 所有负荷的需求累加: 1715.3333340000001
# 所有负荷的切负荷量累加: 2.625422094499811
#
# 时段 519 的统计结果:
# 所有机组的出力累加: 1719.3051943866908
# 所有负荷的需求累加: 1568.0000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 520 的统计结果:
# 所有机组的出力累加: 1752.9320975277046
# 所有负荷的需求累加: 1386.8333340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 521 的统计结果:
# 所有机组的出力累加: 1779.1329366873163
# 所有负荷的需求累加: 1265.5000000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 522 的统计结果:
# 所有机组的出力累加: 1343.0125316958024
# 所有负荷的需求累加: 1188.75
# 所有负荷的切负荷量累加: 0.0
#
# 时段 523 的统计结果:
# 所有机组的出力累加: 1347.8592289797334
# 所有负荷的需求累加: 1167.6666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 524 的统计结果:
# 所有机组的出力累加: 1370.3468193897797
# 所有负荷的需求累加: 1180.7499999999998
# 所有负荷的切负荷量累加: 0.0
#
# 时段 525 的统计结果:
# 所有机组的出力累加: 1402.1325437033825
# 所有负荷的需求累加: 1167.5000000000005
# 所有负荷的切负荷量累加: 0.0
#
# 时段 526 的统计结果:
# 所有机组的出力累加: 1406.661697301654
# 所有负荷的需求累加: 1205.6666670000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 527 的统计结果:
# 所有机组的出力累加: 1467.67486307719
# 所有负荷的需求累加: 1369.7500000000007
# 所有负荷的切负荷量累加: 0.0
#
# 时段 528 的统计结果:
# 所有机组的出力累加: 1503.7596778453258
# 所有负荷的需求累加: 1631.0833339999997
# 所有负荷的切负荷量累加: 44.028722765498344
#
# 时段 529 的统计结果:
# 所有机组的出力累加: 1476.190026026054
# 所有负荷的需求累加: 1674.166667
# 所有负荷的切负荷量累加: 93.93943050439572
#
# 时段 530 的统计结果:
# 所有机组的出力累加: 1476.2226524535806
# 所有负荷的需求累加: 1588.8333340000004
# 所有负荷的切负荷量累加: 28.473912436703756
#
# 时段 531 的统计结果:
# 所有机组的出力累加: 1500.6667585174716
# 所有负荷的需求累加: 1523.1666670000002
# 所有负荷的切负荷量累加: 4.495381369809081
#
# 时段 532 的统计结果:
# 所有机组的出力累加: 1511.0769369244153
# 所有负荷的需求累加: 1450.2500000000007
# 所有负荷的切负荷量累加: 0.0
#
# 时段 533 的统计结果:
# 所有机组的出力累加: 1429.3502209511896
# 所有负荷的需求累加: 1402.166667
# 所有负荷的切负荷量累加: 0.0
#
# 时段 534 的统计结果:
# 所有机组的出力累加: 1395.1350480844167
# 所有负荷的需求累加: 1364.2500000000002
# 所有负荷的切负荷量累加: 0.0
#
# 时段 535 的统计结果:
# 所有机组的出力累加: 1400.6084440790244
# 所有负荷的需求累加: 1375.083334
# 所有负荷的切负荷量累加: 0.0
#
# 时段 536 的统计结果:
# 所有机组的出力累加: 1409.67995841732
# 所有负荷的需求累加: 1357.4999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 537 的统计结果:
# 所有机组的出力累加: 1480.9937445730648
# 所有负荷的需求累加: 1379.5833340000004
# 所有负荷的切负荷量累加: 0.0
#
# 时段 538 的统计结果:
# 所有机组的出力累加: 1501.4017637151994
# 所有负荷的需求累加: 1479.9166669999997
# 所有负荷的切负荷量累加: 0.0
#
# 时段 539 的统计结果:
# 所有机组的出力累加: 1506.6266136524482
# 所有负荷的需求累加: 1596.0000000000002
# 所有负荷的切负荷量累加: 22.862209049474075
#
# 时段 540 的统计结果:
# 所有机组的出力累加: 1509.5988879063884
# 所有负荷的需求累加: 1685.7499999999998
# 所有负荷的切负荷量累加: 77.71877626452829
#
# 时段 541 的统计结果:
# 所有机组的出力累加: 1570.7998023147436
# 所有负荷的需求累加: 1691.8333339999995
# 所有负荷的切负荷量累加: 41.06505719782115
#
# 时段 542 的统计结果:
# 所有机组的出力累加: 1622.3580375586355
# 所有负荷的需求累加: 1672.2500000000002
# 所有负荷的切负荷量累加: 9.867671915112908
#
# 时段 543 的统计结果:
# 所有机组的出力累加: 1643.7146460165516
# 所有负荷的需求累加: 1582.9999999999995
# 所有负荷的切负荷量累加: 0.0
#
# 时段 544 的统计结果:
# 所有机组的出力累加: 1684.3852736401045
# 所有负荷的需求累加: 1416.0833340000006
# 所有负荷的切负荷量累加: 0.0
#
# 时段 545 的统计结果:
# 所有机组的出力累加: 1735.3843778000873
# 所有负荷的需求累加: 1250.8333340000001
# 所有负荷的切负荷量累加: 0.0

# %%
import pandas as pd

# 获取目标函数值
objective_value = model2.ObjVal

# 将目标函数值存储到 DataFrame 中
data = {'Objective Value': [objective_value]}
df = pd.DataFrame(data)

# 将 DataFrame 保存到 CSV 文件中
df.to_csv('objective_value.csv', index=False)
